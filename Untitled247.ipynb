# %%
# ============================================================
# EXPANSION-HISTORY ACTIVATED MATTER COUPLING
# Canonical diagnostics cell (self-contained)
# No external data required
# ============================================================

import numpy as np
from scipy.integrate import solve_ivp

# ------------------------------------------------------------
# 1. Core model definitions
# ------------------------------------------------------------

def u_eq(Om):
    return (1.0 / 3.0) * np.log((1.0 - Om) / Om)

def x_of_z(z, Om, alpha):
    return np.log(1.0 + z) / (alpha * u_eq(Om))

def M_of_z(z, Om, alpha, nu):
    x = x_of_z(z, Om, alpha)
    return np.where(x > 0.0, x**nu, 0.0)

def S_of_z(z, Om, alpha, nu):
    # inactive fraction / survival fraction
    return np.exp(-M_of_z(z, Om, alpha, nu))

def g_of_z(z, Om, alpha, nu):
    # activated fraction
    return 1.0 - S_of_z(z, Om, alpha, nu)

def z_s_exact(Om, alpha):
    # x(z_s) = 1
    return np.exp(alpha * u_eq(Om)) - 1.0

def z_at_activation_fraction(p, Om, alpha, nu):
    # solve g(z_p) = p exactly
    # p must be in (0,1)
    if not (0.0 < p < 1.0):
        raise ValueError("p must lie in (0,1)")
    x = (-np.log(1.0 - p))**(1.0 / nu)
    return np.exp(alpha * u_eq(Om) * x) - 1.0

# ------------------------------------------------------------
# 2. Background expansion
# ------------------------------------------------------------

def E2_bg(z, H0, Om, alpha, nu):
    g = g_of_z(z, Om, alpha, nu)
    return Om * (1.0 + z)**3 * g + (1.0 - Om)

def E_bg(z, H0, Om, alpha, nu):
    return np.sqrt(E2_bg(z, H0, Om, alpha, nu))

def dg_dz(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    x = x_of_z(z, Om, alpha)
    out = np.zeros_like(z)

    mask = x > 0.0
    if np.any(mask):
        xm = x[mask]
        gm = g_of_z(z[mask], Om, alpha, nu)
        out[mask] = (
            nu * xm**(nu - 1.0) * (1.0 - gm)
            / ((1.0 + z[mask]) * alpha * u_eq(Om))
        )
    return out

def dE2_dz(z, H0, Om, alpha, nu):
    g = g_of_z(z, Om, alpha, nu)
    dg = dg_dz(z, Om, alpha, nu)
    return Om * (3.0 * (1.0 + z)**2 * g + (1.0 + z)**3 * dg)

def q_of_z(z, H0, Om, alpha, nu):
    # deceleration parameter
    E2 = E2_bg(z, H0, Om, alpha, nu)
    dE2 = dE2_dz(z, H0, Om, alpha, nu)
    return -1.0 + (1.0 + z) * dE2 / (2.0 * E2)

def rho_de_eff(z, Om, alpha, nu):
    g = g_of_z(z, Om, alpha, nu)
    return (1.0 - Om) - Om * (1.0 + z)**3 * (1.0 - g)

def drho_de_eff_dz(z, Om, alpha, nu):
    g = g_of_z(z, Om, alpha, nu)
    dg = dg_dz(z, Om, alpha, nu)
    return -Om * (3.0 * (1.0 + z)**2 * (1.0 - g) - (1.0 + z)**3 * dg)

def w_de_eff(z, Om, alpha, nu):
    rho = rho_de_eff(z, Om, alpha, nu)
    drho = drho_de_eff_dz(z, Om, alpha, nu)
    return -1.0 + (1.0 + z) * drho / (3.0 * rho)

def Omega_m_bg(z, Om, alpha, nu):
    return Om * (1.0 + z)**3 * g_of_z(z, Om, alpha, nu) / E2_bg(z, 1.0, Om, alpha, nu)

# ------------------------------------------------------------
# 3. Perturbation-sector closures
# ------------------------------------------------------------

def g_pert_additive(z, Om, alpha, nu, eps):
    # OLD rough closure: can exceed 1 at high z
    return g_of_z(z, Om, alpha, nu) + eps

def g_pert_survival_floor(z, Om, alpha, nu, eps):
    # NEW canonical bounded closure:
    # g_pert = 1 - (1-eps) exp(-x^nu)
    #        = eps + (1-eps) g
    #        = g + eps * (1-g)
    return 1.0 - (1.0 - eps) * S_of_z(z, Om, alpha, nu)

def Omega_m_pert_minimal(z, Om, alpha, nu):
    return Om * (1.0 + z)**3 * g_of_z(z, Om, alpha, nu) / E2_bg(z, 1.0, Om, alpha, nu)

def Omega_m_pert_survival_floor(z, Om, alpha, nu, eps):
    return Om * (1.0 + z)**3 * g_pert_survival_floor(z, Om, alpha, nu, eps) / E2_bg(z, 1.0, Om, alpha, nu)

# ------------------------------------------------------------
# 4. Linear growth solver in N = ln(a)
# ------------------------------------------------------------

def z_of_a(a):
    return 1.0 / a - 1.0

def dlnH_dN(a, H0, Om, alpha, nu):
    # N = ln a, z = a^{-1} - 1
    z = z_of_a(a)
    E2 = E2_bg(z, H0, Om, alpha, nu)
    dE2dz = dE2_dz(z, H0, Om, alpha, nu)
    dzdN = -(1.0 + z)
    dE2dN = dE2dz * dzdN
    return 0.5 * dE2dN / E2

def growth_rhs_minimal(N, y, H0, Om, alpha, nu):
    D, Dn = y
    a = np.exp(N)
    src = Omega_m_pert_minimal(z_of_a(a), Om, alpha, nu)
    friction = 2.0 + dlnH_dN(a, H0, Om, alpha, nu)
    Dnn = -(friction * Dn) + 1.5 * src * D
    return [Dn, Dnn]

def growth_rhs_survival_floor(N, y, H0, Om, alpha, nu, eps):
    D, Dn = y
    a = np.exp(N)
    src = Omega_m_pert_survival_floor(z_of_a(a), Om, alpha, nu, eps)
    friction = 2.0 + dlnH_dN(a, H0, Om, alpha, nu)
    Dnn = -(friction * Dn) + 1.5 * src * D
    return [Dn, Dnn]

def solve_growth(H0, Om, alpha, nu, eps=None, a_ini=1e-3, a_fin=1.0, n_eval=500):
    N_ini = np.log(a_ini)
    N_fin = np.log(a_fin)
    N_eval = np.linspace(N_ini, N_fin, n_eval)

    # growing-mode IC in matter era: D ~ a, so D_N = D
    y0 = [a_ini, a_ini]

    if eps is None:
        sol = solve_ivp(
            growth_rhs_minimal, [N_ini, N_fin], y0,
            t_eval=N_eval, args=(H0, Om, alpha, nu),
            rtol=1e-8, atol=1e-10
        )
    else:
        sol = solve_ivp(
            growth_rhs_survival_floor, [N_ini, N_fin], y0,
            t_eval=N_eval, args=(H0, Om, alpha, nu, eps),
            rtol=1e-8, atol=1e-10
        )

    N = sol.t
    a = np.exp(N)
    z = z_of_a(a)
    D = sol.y[0]
    Dn = sol.y[1]

    # normalize to D(z=0)=1
    D /= D[-1]
    Dn /= sol.y[0][-1]

    f = Dn / D
    return {
        "N": N,
        "a": a,
        "z": z,
        "D": D,
        "f": f,
        "fs8_over_sigma8_0": f * D
    }

# ------------------------------------------------------------
# 5. Fiducial parameter set from the draft
# ------------------------------------------------------------

H0 = 74.0
Om = 0.231
alpha = 0.483
nu = 0.886
eps = 0.08

# ------------------------------------------------------------
# 6. Diagnostics
# ------------------------------------------------------------

print("=== Canonical equality-tied activation diagnostics ===")
print(f"Omega_m       = {Om:.6f}")
print(f"alpha         = {alpha:.6f}")
print(f"nu            = {nu:.6f}")
print(f"u_eq          = {u_eq(Om):.6f}")
print(f"u_s           = {alpha * u_eq(Om):.6f}")
print(f"z_s (x=1)     = {z_s_exact(Om, alpha):.6f}")
print(f"z_50 (g=0.5)  = {z_at_activation_fraction(0.5, Om, alpha, nu):.6f}")
print(f"z_90 (g=0.9)  = {z_at_activation_fraction(0.9, Om, alpha, nu):.6f}")
print()

# exact threshold slope diagnostics
slope_x1 = nu / np.e
slope_ln1pz_x1 = nu / (np.e * alpha * u_eq(Om))
print("=== Transition sharpness ===")
print(f"(dg/dx)_(x=1)                = {slope_x1:.6f}")
print(f"(dg/dln(1+z))_(x=1)          = {slope_ln1pz_x1:.6f}")
print()

# asymptotic tests
z_test = np.array([0.0, 0.1, 0.21, 0.5, 1.0, 3.0, 10.0, 1100.0])
g_bg_vals = g_of_z(z_test, Om, alpha, nu)
g_add_vals = g_pert_additive(z_test, Om, alpha, nu, eps)
g_surv_vals = g_pert_survival_floor(z_test, Om, alpha, nu, eps)

print("=== Perturbation closure comparison ===")
print("   z        g_bg        g+eps      g_survival_floor")
for zi, gb, ga, gs in zip(z_test, g_bg_vals, g_add_vals, g_surv_vals):
    print(f"{zi:7.2f}   {gb:9.6f}   {ga:9.6f}   {gs:16.6f}")
print()

print("Note: g+eps exceeds 1 at high z; survival-floor closure remains bounded by 1.")
print()

# background and growth test
bg = solve_growth(H0, Om, alpha, nu, eps=None)
bg_eps = solve_growth(H0, Om, alpha, nu, eps=eps)

print("=== Growth-sector proxy (relative only; sigma8_0 not inserted) ===")
print(f"Minimal closure:       fD(z=0) = {bg['fs8_over_sigma8_0'][-1]:.6f}")
print(f"With survival floor:   fD(z=0) = {bg_eps['fs8_over_sigma8_0'][-1]:.6f}")
print()

# small table at selected redshifts
sample_z = [0.0, 0.5, 1.0]
print("=== Selected background diagnostics ===")
print("   z       g(z)      E(z)      q(z)      w_DE_eff(z)")
for zi in sample_z:
    print(
        f"{zi:6.2f}   "
        f"{g_of_z(zi, Om, alpha, nu):8.5f}   "
        f"{E_bg(zi, H0, Om, alpha, nu):8.5f}   "
        f"{q_of_z(zi, H0, Om, alpha, nu):8.5f}   "
        f"{w_de_eff(zi, Om, alpha, nu):12.6f}"
    )
# Out:
# === Canonical equality-tied activation diagnostics ===
# Omega_m       = 0.231000
# alpha         = 0.483000
# nu            = 0.886000
# u_eq          = 0.400891
# u_s           = 0.193630
# z_s (x=1)     = 0.213648
# z_50 (g=0.5)  = 0.136589
# z_90 (g=0.9)  = 0.642727
#
# === Transition sharpness ===
# (dg/dx)_(x=1)                = 0.325941
# (dg/dln(1+z))_(x=1)          = 1.683316
#
# === Perturbation closure comparison ===
#    z        g_bg        g+eps      g_survival_floor
#    0.00    0.000000    0.080000           0.080000
#    0.10    0.413541    0.493541           0.460458
#    0.21    0.627014    0.707014           0.656853
#    0.50    0.854097    0.934097           0.865769
#    1.00    0.954742    1.034742           0.958362
#    3.00    0.996722    1.076722           0.996984
#   10.00    0.999908    1.079908           0.999916
# 1100.00    1.000000    1.080000           1.000000
#
# Note: g+eps exceeds 1 at high z; survival-floor closure remains bounded by 1.
#
# === Growth-sector proxy (relative only; sigma8_0 not inserted) ===
# Minimal closure:       fD(z=0) = 0.319293
# With survival floor:   fD(z=0) = 0.324411
#
# === Selected background diagnostics ===
#    z       g(z)      E(z)      q(z)      w_DE_eff(z)
#   0.00    0.00000    0.87693   -1.00000      -1.429368
#   0.50    0.85410    1.19786   -0.13719      -0.930214
#   1.00    0.95474    1.59165    0.10999      -0.961088

# %%
# ============================================================
# EXPANSION-HISTORY ACTIVATED MATTER COUPLING
# Renormalised equality-tied model diagnostics (self-contained)
# ============================================================

import numpy as np
from scipy.integrate import solve_ivp

# ------------------------------------------------------------
# 1. Core control variables
# ------------------------------------------------------------

def u_eq(Om):
    return (1.0 / 3.0) * np.log((1.0 - Om) / Om)

def x_of_z(z, Om, alpha):
    return np.log(1.0 + z) / (alpha * u_eq(Om))

def M_of_z(z, Om, alpha, nu):
    x = x_of_z(z, Om, alpha)
    return np.where(x > 0.0, x**nu, 0.0)

def S_of_z(z, Om, alpha, nu):
    return np.exp(-M_of_z(z, Om, alpha, nu))

def g_of_z(z, Om, alpha, nu):
    return 1.0 - S_of_z(z, Om, alpha, nu)

def z_s_exact(Om, alpha):
    return np.exp(alpha * u_eq(Om)) - 1.0

def z_at_activation_fraction(p, Om, alpha, nu):
    if not (0.0 < p < 1.0):
        raise ValueError("p must lie in (0,1)")
    x = (-np.log(1.0 - p))**(1.0 / nu)
    return np.exp(alpha * u_eq(Om) * x) - 1.0

# ------------------------------------------------------------
# 2. Renormalised background
#    E^2(z) = 1 + Om[(1+z)^3 g(z) - 1]
# ------------------------------------------------------------

def E2_bg(z, H0, Om, alpha, nu):
    g = g_of_z(z, Om, alpha, nu)
    return 1.0 + Om * ((1.0 + z)**3 * g - 1.0)

def E_bg(z, H0, Om, alpha, nu):
    return np.sqrt(E2_bg(z, H0, Om, alpha, nu))

def dg_dz(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    x = x_of_z(z, Om, alpha)
    out = np.zeros_like(z)

    mask = x > 0.0
    if np.any(mask):
        xm = x[mask]
        gm = g_of_z(z[mask], Om, alpha, nu)
        out[mask] = (
            nu * xm**(nu - 1.0) * (1.0 - gm)
            / ((1.0 + z[mask]) * alpha * u_eq(Om))
        )
    return out

def dE2_dz(z, H0, Om, alpha, nu):
    g = g_of_z(z, Om, alpha, nu)
    dg = dg_dz(z, Om, alpha, nu)
    return Om * (3.0 * (1.0 + z)**2 * g + (1.0 + z)**3 * dg)

def q_of_z(z, H0, Om, alpha, nu):
    E2 = E2_bg(z, H0, Om, alpha, nu)
    dE2 = dE2_dz(z, H0, Om, alpha, nu)
    return -1.0 + (1.0 + z) * dE2 / (2.0 * E2)

# effective DE defined by E^2 = Om(1+z)^3 + rho_DE_eff
def rho_de_eff(z, Om, alpha, nu):
    g = g_of_z(z, Om, alpha, nu)
    return 1.0 - Om + Om * (1.0 + z)**3 * (g - 1.0)

def drho_de_eff_dz(z, Om, alpha, nu):
    g = g_of_z(z, Om, alpha, nu)
    dg = dg_dz(z, Om, alpha, nu)
    return Om * (3.0 * (1.0 + z)**2 * (g - 1.0) + (1.0 + z)**3 * dg)

def w_de_eff(z, Om, alpha, nu):
    rho = rho_de_eff(z, Om, alpha, nu)
    drho = drho_de_eff_dz(z, Om, alpha, nu)
    return -1.0 + (1.0 + z) * drho / (3.0 * rho)

def Omega_m_bg(z, Om, alpha, nu):
    return Om * (1.0 + z)**3 * g_of_z(z, Om, alpha, nu) / E2_bg(z, 1.0, Om, alpha, nu)

# ------------------------------------------------------------
# 3. Perturbation-sector closure
#    bounded survival-floor version
# ------------------------------------------------------------

def g_pert_survival_floor(z, Om, alpha, nu, eps):
    return 1.0 - (1.0 - eps) * S_of_z(z, Om, alpha, nu)

def Omega_m_pert_survival_floor(z, Om, alpha, nu, eps):
    return Om * (1.0 + z)**3 * g_pert_survival_floor(z, Om, alpha, nu, eps) / E2_bg(z, 1.0, Om, alpha, nu)

def Omega_m_pert_minimal(z, Om, alpha, nu):
    return Om * (1.0 + z)**3 * g_of_z(z, Om, alpha, nu) / E2_bg(z, 1.0, Om, alpha, nu)

# ------------------------------------------------------------
# 4. Growth solver in N = ln a
# ------------------------------------------------------------

def z_of_a(a):
    return 1.0 / a - 1.0

def dlnH_dN(a, H0, Om, alpha, nu):
    z = z_of_a(a)
    E2 = E2_bg(z, H0, Om, alpha, nu)
    dE2dz = dE2_dz(z, H0, Om, alpha, nu)
    dzdN = -(1.0 + z)
    dE2dN = dE2dz * dzdN
    return 0.5 * dE2dN / E2

def growth_rhs_minimal(N, y, H0, Om, alpha, nu):
    D, Dn = y
    a = np.exp(N)
    src = Omega_m_pert_minimal(z_of_a(a), Om, alpha, nu)
    friction = 2.0 + dlnH_dN(a, H0, Om, alpha, nu)
    Dnn = -(friction * Dn) + 1.5 * src * D
    return [Dn, Dnn]

def growth_rhs_survival_floor(N, y, H0, Om, alpha, nu, eps):
    D, Dn = y
    a = np.exp(N)
    src = Omega_m_pert_survival_floor(z_of_a(a), Om, alpha, nu, eps)
    friction = 2.0 + dlnH_dN(a, H0, Om, alpha, nu)
    Dnn = -(friction * Dn) + 1.5 * src * D
    return [Dn, Dnn]

def solve_growth(H0, Om, alpha, nu, eps=None, a_ini=1e-3, a_fin=1.0, n_eval=500):
    N_ini = np.log(a_ini)
    N_fin = np.log(a_fin)
    N_eval = np.linspace(N_ini, N_fin, n_eval)

    y0 = [a_ini, a_ini]

    if eps is None:
        sol = solve_ivp(
            growth_rhs_minimal, [N_ini, N_fin], y0,
            t_eval=N_eval, args=(H0, Om, alpha, nu),
            rtol=1e-8, atol=1e-10
        )
    else:
        sol = solve_ivp(
            growth_rhs_survival_floor, [N_ini, N_fin], y0,
            t_eval=N_eval, args=(H0, Om, alpha, nu, eps),
            rtol=1e-8, atol=1e-10
        )

    N = sol.t
    a = np.exp(N)
    z = z_of_a(a)
    D_raw = sol.y[0].copy()
    Dn_raw = sol.y[1].copy()

    D = D_raw / D_raw[-1]
    Dn = Dn_raw / D_raw[-1]
    f = Dn / D

    return {
        "N": N,
        "a": a,
        "z": z,
        "D": D,
        "f": f,
        "fs8_over_sigma8_0": f * D
    }

# ------------------------------------------------------------
# 5. Fiducial parameters
# ------------------------------------------------------------

H0 = 74.0
Om = 0.231
alpha = 0.483
nu = 0.886
eps = 0.08

# ------------------------------------------------------------
# 6. Diagnostics
# ------------------------------------------------------------

print("=== Renormalised equality-tied activation diagnostics ===")
print(f"Omega_m       = {Om:.6f}")
print(f"alpha         = {alpha:.6f}")
print(f"nu            = {nu:.6f}")
print(f"u_eq          = {u_eq(Om):.6f}")
print(f"u_s           = {alpha * u_eq(Om):.6f}")
print(f"z_s (x=1)     = {z_s_exact(Om, alpha):.6f}")
print(f"z_50 (g=0.5)  = {z_at_activation_fraction(0.5, Om, alpha, nu):.6f}")
print(f"z_90 (g=0.9)  = {z_at_activation_fraction(0.9, Om, alpha, nu):.6f}")
print()

print("=== Normalisation check ===")
print(f"E(0)          = {E_bg(0.0, H0, Om, alpha, nu):.6f}")
print(f"E^2(0)        = {E2_bg(0.0, H0, Om, alpha, nu):.6f}")
print()

print("=== Perturbation closure (bounded) ===")
for zi in [0.0, 0.1, 0.21, 0.5, 1.0, 3.0, 10.0]:
    gb = g_of_z(zi, Om, alpha, nu)
    gp = g_pert_survival_floor(zi, Om, alpha, nu, eps)
    print(f"z={zi:5.2f}   g_bg={gb:9.6f}   g_pert={gp:9.6f}")
print()

bg = solve_growth(H0, Om, alpha, nu, eps=None)
bg_eps = solve_growth(H0, Om, alpha, nu, eps=eps)

print("=== Growth-sector proxy (relative only) ===")
print(f"Minimal closure:       fD(z=0) = {bg['fs8_over_sigma8_0'][-1]:.6f}")
print(f"With survival floor:   fD(z=0) = {bg_eps['fs8_over_sigma8_0'][-1]:.6f}")
print()

print("=== Selected background diagnostics ===")
print("   z       g(z)      E(z)      q(z)      w_DE_eff(z)")
for zi in [0.0, 0.5, 1.0]:
    print(
        f"{zi:6.2f}   "
        f"{g_of_z(zi, Om, alpha, nu):8.5f}   "
        f"{E_bg(zi, H0, Om, alpha, nu):8.5f}   "
        f"{q_of_z(zi, H0, Om, alpha, nu):8.5f}   "
        f"{w_de_eff(zi, Om, alpha, nu):12.6f}"
    )
# Out:
# === Renormalised equality-tied activation diagnostics ===
# Omega_m       = 0.231000
# alpha         = 0.483000
# nu            = 0.886000
# u_eq          = 0.400891
# u_s           = 0.193630
# z_s (x=1)     = 0.213648
# z_50 (g=0.5)  = 0.136589
# z_90 (g=0.9)  = 0.642727
#
# === Normalisation check ===
# E(0)          = 0.876926
# E^2(0)        = 0.769000
#
# === Perturbation closure (bounded) ===
# z= 0.00   g_bg= 0.000000   g_pert= 0.080000
# z= 0.10   g_bg= 0.413541   g_pert= 0.460458
# z= 0.21   g_bg= 0.627014   g_pert= 0.656853
# z= 0.50   g_bg= 0.854097   g_pert= 0.865769
# z= 1.00   g_bg= 0.954742   g_pert= 0.958362
# z= 3.00   g_bg= 0.996722   g_pert= 0.996984
# z=10.00   g_bg= 0.999908   g_pert= 0.999916
#
# === Growth-sector proxy (relative only) ===
# Minimal closure:       fD(z=0) = 0.433771
# With survival floor:   fD(z=0) = 0.439891
#
# === Selected background diagnostics ===
#    z       g(z)      E(z)      q(z)      w_DE_eff(z)
#   0.00    0.00000    0.87693   -1.00000      -1.429368
#   0.50    0.85410    1.19786   -0.13719      -0.930214
#   1.00    0.95474    1.59165    0.10999      -0.961088

# %%
# ============================================================
# EXPANSION-HISTORY ACTIVATED MATTER COUPLING
# Corrected self-normalised equality-tied model diagnostics
# ============================================================

import numpy as np
from scipy.integrate import solve_ivp

# ------------------------------------------------------------
# 1. Canonical control variables
# ------------------------------------------------------------

def u_eq(Om):
    return (1.0 / 3.0) * np.log((1.0 - Om) / Om)

def u_s(Om, alpha):
    return alpha * u_eq(Om)

def x_of_z(z, Om, alpha):
    return np.log(1.0 + z) / u_s(Om, alpha)

def M_of_z(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    x = x_of_z(z, Om, alpha)
    out = np.zeros_like(x)
    mask = x > 0.0
    out[mask] = x[mask] ** nu
    return out

def S_of_z(z, Om, alpha, nu):
    return np.exp(-M_of_z(z, Om, alpha, nu))

def g_of_z(z, Om, alpha, nu):
    return 1.0 - S_of_z(z, Om, alpha, nu)

def z_s_exact(Om, alpha):
    # x(z_s)=1
    return np.exp(u_s(Om, alpha)) - 1.0

def z_at_activation_fraction(p, Om, alpha, nu):
    if not (0.0 < p < 1.0):
        raise ValueError("p must lie in (0,1)")
    x = (-np.log(1.0 - p)) ** (1.0 / nu)
    return np.exp(u_s(Om, alpha) * x) - 1.0

# ------------------------------------------------------------
# 2. Corrected self-normalised background
#
# E^2(z) = 1 + Om * g(z) * [ (1+z)^3 - 1 ]
#
# This satisfies:
#   E(0)=1
#   E^2 -> Om(1+z)^3 + (1-Om) as g->1
# ------------------------------------------------------------

def E2_bg(z, H0, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    g = g_of_z(z, Om, alpha, nu)
    return 1.0 + Om * g * ((1.0 + z)**3 - 1.0)

def E_bg(z, H0, Om, alpha, nu):
    return np.sqrt(E2_bg(z, H0, Om, alpha, nu))

def dg_dz_safe(z, Om, alpha, nu):
    """
    Safe dg/dz away from z=0.
    Note: for nu<1, dg/dz diverges as z->0, so do not use this
    directly at z=0 for physics. Use dE2_dz_safe instead.
    """
    z = np.asarray(z, dtype=float)
    x = x_of_z(z, Om, alpha)
    g = g_of_z(z, Om, alpha, nu)
    out = np.zeros_like(z)

    mask = z > 0.0
    if np.any(mask):
        xm = x[mask]
        gm = g[mask]
        out[mask] = (
            nu * xm**(nu - 1.0) * (1.0 - gm)
            / ((1.0 + z[mask]) * u_s(Om, alpha))
        )
    return out

def dE2_dz_safe(z, H0, Om, alpha, nu):
    """
    Stable derivative of E^2.
    At z=0, the exact limit is 0 because E^2 = 1 + O(z^(nu+1)).
    """
    z = np.asarray(z, dtype=float)
    g = g_of_z(z, Om, alpha, nu)
    dg = dg_dz_safe(z, Om, alpha, nu)

    out = Om * (
        dg * ((1.0 + z)**3 - 1.0)
        + g * 3.0 * (1.0 + z)**2
    )

    # exact limit at z=0
    out = np.where(z == 0.0, 0.0, out)
    return out

def q_of_z(z, H0, Om, alpha, nu):
    E2 = E2_bg(z, H0, Om, alpha, nu)
    dE2 = dE2_dz_safe(z, H0, Om, alpha, nu)
    return -1.0 + (1.0 + z) * dE2 / (2.0 * E2)

# ------------------------------------------------------------
# 3. Effective dark-energy interpretation
#
# E^2 = Om(1+z)^3 + rho_DE_eff(z)
# ------------------------------------------------------------

def rho_de_eff(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    return E2_bg(z, 1.0, Om, alpha, nu) - Om * (1.0 + z)**3

def drho_de_eff_dz(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    return dE2_dz_safe(z, 1.0, Om, alpha, nu) - 3.0 * Om * (1.0 + z)**2

def w_de_eff(z, Om, alpha, nu):
    rho = rho_de_eff(z, Om, alpha, nu)
    drho = drho_de_eff_dz(z, Om, alpha, nu)
    return -1.0 + (1.0 + z) * drho / (3.0 * rho)

# ------------------------------------------------------------
# 4. Perturbation-sector closure
#
# Preferred bounded version:
# g_pert = 1 - (1-eps) * exp(-x^nu)
#        = eps + (1-eps) g
# ------------------------------------------------------------

def g_pert_survival_floor(z, Om, alpha, nu, eps):
    return 1.0 - (1.0 - eps) * S_of_z(z, Om, alpha, nu)

def Omega_m_pert_minimal(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    return Om * (1.0 + z)**3 * g_of_z(z, Om, alpha, nu) / E2_bg(z, 1.0, Om, alpha, nu)

def Omega_m_pert_survival_floor(z, Om, alpha, nu, eps):
    z = np.asarray(z, dtype=float)
    return Om * (1.0 + z)**3 * g_pert_survival_floor(z, Om, alpha, nu, eps) / E2_bg(z, 1.0, Om, alpha, nu)

# ------------------------------------------------------------
# 5. Growth solver in N = ln(a)
# ------------------------------------------------------------

def z_of_a(a):
    return 1.0 / a - 1.0

def dlnH_dN(a, H0, Om, alpha, nu):
    z = z_of_a(a)
    E2 = E2_bg(z, H0, Om, alpha, nu)
    dE2dz = dE2_dz_safe(z, H0, Om, alpha, nu)
    dzdN = -(1.0 + z)
    dE2dN = dE2dz * dzdN
    return 0.5 * dE2dN / E2

def growth_rhs_minimal(N, y, H0, Om, alpha, nu):
    D, Dn = y
    a = np.exp(N)
    src = Omega_m_pert_minimal(z_of_a(a), Om, alpha, nu)
    friction = 2.0 + dlnH_dN(a, H0, Om, alpha, nu)
    Dnn = -(friction * Dn) + 1.5 * src * D
    return [Dn, Dnn]

def growth_rhs_survival_floor(N, y, H0, Om, alpha, nu, eps):
    D, Dn = y
    a = np.exp(N)
    src = Omega_m_pert_survival_floor(z_of_a(a), Om, alpha, nu, eps)
    friction = 2.0 + dlnH_dN(a, H0, Om, alpha, nu)
    Dnn = -(friction * Dn) + 1.5 * src * D
    return [Dn, Dnn]

def solve_growth(H0, Om, alpha, nu, eps=None, a_ini=1e-3, a_fin=1.0, n_eval=500):
    N_ini = np.log(a_ini)
    N_fin = np.log(a_fin)
    N_eval = np.linspace(N_ini, N_fin, n_eval)

    # growing-mode IC: D ~ a in matter era
    y0 = [a_ini, a_ini]

    if eps is None:
        sol = solve_ivp(
            growth_rhs_minimal, [N_ini, N_fin], y0,
            t_eval=N_eval, args=(H0, Om, alpha, nu),
            rtol=1e-8, atol=1e-10
        )
    else:
        sol = solve_ivp(
            growth_rhs_survival_floor, [N_ini, N_fin], y0,
            t_eval=N_eval, args=(H0, Om, alpha, nu, eps),
            rtol=1e-8, atol=1e-10
        )

    N = sol.t
    a = np.exp(N)
    z = z_of_a(a)

    D_raw = sol.y[0].copy()
    Dn_raw = sol.y[1].copy()

    D = D_raw / D_raw[-1]
    Dn = Dn_raw / D_raw[-1]
    f = Dn / D

    return {
        "N": N,
        "a": a,
        "z": z,
        "D": D,
        "f": f,
        "fs8_over_sigma8_0": f * D
    }

# ------------------------------------------------------------
# 6. Fiducial parameters
# ------------------------------------------------------------

H0 = 74.0
Om = 0.231
alpha = 0.483
nu = 0.886
eps = 0.08

# ------------------------------------------------------------
# 7. Diagnostics
# ------------------------------------------------------------

print("=== Corrected self-normalised equality-tied diagnostics ===")
print(f"Omega_m       = {Om:.6f}")
print(f"alpha         = {alpha:.6f}")
print(f"nu            = {nu:.6f}")
print(f"u_eq          = {u_eq(Om):.6f}")
print(f"u_s           = {u_s(Om, alpha):.6f}")
print(f"z_s (x=1)     = {z_s_exact(Om, alpha):.6f}")
print(f"z_50 (g=0.5)  = {z_at_activation_fraction(0.5, Om, alpha, nu):.6f}")
print(f"z_90 (g=0.9)  = {z_at_activation_fraction(0.9, Om, alpha, nu):.6f}")
print()

print("=== Normalisation check ===")
print(f"E(0)          = {E_bg(0.0, H0, Om, alpha, nu):.6f}")
print(f"E^2(0)        = {E2_bg(0.0, H0, Om, alpha, nu):.6f}")
print(f"rho_DE_eff(0) = {rho_de_eff(0.0, Om, alpha, nu):.6f}")
print()

print("=== Perturbation closure (bounded) ===")
for zi in [0.0, 0.1, 0.21, 0.5, 1.0, 3.0, 10.0]:
    gb = g_of_z(zi, Om, alpha, nu)
    gp = g_pert_survival_floor(zi, Om, alpha, nu, eps)
    print(f"z={zi:5.2f}   g_bg={gb:9.6f}   g_pert={gp:9.6f}")
print()

bg = solve_growth(H0, Om, alpha, nu, eps=None)
bg_eps = solve_growth(H0, Om, alpha, nu, eps=eps)

print("=== Growth-sector proxy (relative only) ===")
print(f"Minimal closure:       fD(z=0) = {bg['fs8_over_sigma8_0'][-1]:.6f}")
print(f"With survival floor:   fD(z=0) = {bg_eps['fs8_over_sigma8_0'][-1]:.6f}")
print()

print("=== Selected background diagnostics ===")
print("   z       g(z)      E(z)      q(z)      w_DE_eff(z)")
for zi in [0.0, 0.5, 1.0]:
    print(
        f"{zi:6.2f}   "
        f"{g_of_z(zi, Om, alpha, nu):8.5f}   "
        f"{E_bg(zi, H0, Om, alpha, nu):8.5f}   "
        f"{q_of_z(zi, H0, Om, alpha, nu):8.5f}   "
        f"{w_de_eff(zi, Om, alpha, nu):12.6f}"
    )
# Out:
# === Corrected self-normalised equality-tied diagnostics ===
# Omega_m       = 0.231000
# alpha         = 0.483000
# nu            = 0.886000
# u_eq          = 0.400891
# u_s           = 0.193630
# z_s (x=1)     = 0.213648
# z_50 (g=0.5)  = 0.136589
# z_90 (g=0.9)  = 0.642727
#
# === Normalisation check ===
# E(0)          = 1.000000
# E^2(0)        = 1.000000
# rho_DE_eff(0) = 0.769000
#
# === Perturbation closure (bounded) ===
# z= 0.00   g_bg= 0.000000   g_pert= 0.080000
# z= 0.10   g_bg= 0.413541   g_pert= 0.460458
# z= 0.21   g_bg= 0.627014   g_pert= 0.656853
# z= 0.50   g_bg= 0.854097   g_pert= 0.865769
# z= 1.00   g_bg= 0.954742   g_pert= 0.958362
# z= 3.00   g_bg= 0.996722   g_pert= 0.996984
# z=10.00   g_bg= 0.999908   g_pert= 0.999916
#
# === Growth-sector proxy (relative only) ===
# Minimal closure:       fD(z=0) = 0.380710
# With survival floor:   fD(z=0) = 0.385818
#
# === Selected background diagnostics ===
#    z       g(z)      E(z)      q(z)      w_DE_eff(z)
#   0.00    0.00000    1.00000   -1.00000      -1.300390
#   0.50    0.85410    1.21185   -0.20525      -1.002214
#   1.00    0.95474    1.59493    0.09730      -0.981489

# %%
# ============================================================
# EXPANSION-HISTORY ACTIVATED MATTER COUPLING
# Structural kinematics scan for the corrected self-normalised model
# Self-contained
# ============================================================

import numpy as np
from scipy.integrate import solve_ivp
from scipy.optimize import brentq

# ------------------------------------------------------------
# 1. Canonical control variables
# ------------------------------------------------------------

def u_eq(Om):
    return (1.0 / 3.0) * np.log((1.0 - Om) / Om)

def u_s(Om, alpha):
    return alpha * u_eq(Om)

def x_of_z(z, Om, alpha):
    return np.log(1.0 + z) / u_s(Om, alpha)

def M_of_z(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    x = x_of_z(z, Om, alpha)
    out = np.zeros_like(x)
    mask = x > 0.0
    out[mask] = x[mask] ** nu
    return out

def S_of_z(z, Om, alpha, nu):
    return np.exp(-M_of_z(z, Om, alpha, nu))

def g_of_z(z, Om, alpha, nu):
    return 1.0 - S_of_z(z, Om, alpha, nu)

def z_s_exact(Om, alpha):
    return np.exp(u_s(Om, alpha)) - 1.0

def z_at_activation_fraction(p, Om, alpha, nu):
    if not (0.0 < p < 1.0):
        raise ValueError("p must lie in (0,1)")
    x = (-np.log(1.0 - p)) ** (1.0 / nu)
    return np.exp(u_s(Om, alpha) * x) - 1.0

# ------------------------------------------------------------
# 2. Corrected self-normalised background
# ------------------------------------------------------------

def E2_bg(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    g = g_of_z(z, Om, alpha, nu)
    return 1.0 + Om * g * ((1.0 + z)**3 - 1.0)

def E_bg(z, Om, alpha, nu):
    return np.sqrt(E2_bg(z, Om, alpha, nu))

def dg_dz_safe(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    x = x_of_z(z, Om, alpha)
    g = g_of_z(z, Om, alpha, nu)
    out = np.zeros_like(z)

    mask = z > 0.0
    if np.any(mask):
        xm = x[mask]
        gm = g[mask]
        out[mask] = (
            nu * xm**(nu - 1.0) * (1.0 - gm)
            / ((1.0 + z[mask]) * u_s(Om, alpha))
        )
    return out

def dE2_dz_safe(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    g = g_of_z(z, Om, alpha, nu)
    dg = dg_dz_safe(z, Om, alpha, nu)

    out = Om * (
        dg * ((1.0 + z)**3 - 1.0)
        + g * 3.0 * (1.0 + z)**2
    )
    out = np.where(z == 0.0, 0.0, out)
    return out

def q_of_z(z, Om, alpha, nu):
    E2 = E2_bg(z, Om, alpha, nu)
    dE2 = dE2_dz_safe(z, Om, alpha, nu)
    return -1.0 + (1.0 + z) * dE2 / (2.0 * E2)

def rho_de_eff(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    return E2_bg(z, Om, alpha, nu) - Om * (1.0 + z)**3

def drho_de_eff_dz(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    return dE2_dz_safe(z, Om, alpha, nu) - 3.0 * Om * (1.0 + z)**2

def w_de_eff(z, Om, alpha, nu):
    rho = rho_de_eff(z, Om, alpha, nu)
    drho = drho_de_eff_dz(z, Om, alpha, nu)
    return -1.0 + (1.0 + z) * drho / (3.0 * rho)

# ------------------------------------------------------------
# 3. Perturbation-sector closure
# ------------------------------------------------------------

def g_pert_survival_floor(z, Om, alpha, nu, eps):
    return 1.0 - (1.0 - eps) * S_of_z(z, Om, alpha, nu)

# ------------------------------------------------------------
# 4. Growth solver
# ------------------------------------------------------------

def z_of_a(a):
    return 1.0 / a - 1.0

def Omega_m_pert_minimal(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    return Om * (1.0 + z)**3 * g_of_z(z, Om, alpha, nu) / E2_bg(z, Om, alpha, nu)

def Omega_m_pert_survival_floor(z, Om, alpha, nu, eps):
    z = np.asarray(z, dtype=float)
    return Om * (1.0 + z)**3 * g_pert_survival_floor(z, Om, alpha, nu, eps) / E2_bg(z, Om, alpha, nu)

def dlnH_dN(a, Om, alpha, nu):
    z = z_of_a(a)
    E2 = E2_bg(z, Om, alpha, nu)
    dE2dz = dE2_dz_safe(z, Om, alpha, nu)
    dzdN = -(1.0 + z)
    dE2dN = dE2dz * dzdN
    return 0.5 * dE2dN / E2

def growth_rhs_minimal(N, y, Om, alpha, nu):
    D, Dn = y
    a = np.exp(N)
    src = Omega_m_pert_minimal(z_of_a(a), Om, alpha, nu)
    friction = 2.0 + dlnH_dN(a, Om, alpha, nu)
    Dnn = -(friction * Dn) + 1.5 * src * D
    return [Dn, Dnn]

def growth_rhs_survival_floor(N, y, Om, alpha, nu, eps):
    D, Dn = y
    a = np.exp(N)
    src = Omega_m_pert_survival_floor(z_of_a(a), Om, alpha, nu, eps)
    friction = 2.0 + dlnH_dN(a, Om, alpha, nu)
    Dnn = -(friction * Dn) + 1.5 * src * D
    return [Dn, Dnn]

def solve_growth(Om, alpha, nu, eps=None, a_ini=1e-3, a_fin=1.0, n_eval=600):
    N_ini = np.log(a_ini)
    N_fin = np.log(a_fin)
    N_eval = np.linspace(N_ini, N_fin, n_eval)
    y0 = [a_ini, a_ini]

    if eps is None:
        sol = solve_ivp(
            growth_rhs_minimal, [N_ini, N_fin], y0,
            t_eval=N_eval, args=(Om, alpha, nu),
            rtol=1e-8, atol=1e-10
        )
    else:
        sol = solve_ivp(
            growth_rhs_survival_floor, [N_ini, N_fin], y0,
            t_eval=N_eval, args=(Om, alpha, nu, eps),
            rtol=1e-8, atol=1e-10
        )

    N = sol.t
    a = np.exp(N)
    z = z_of_a(a)

    D_raw = sol.y[0].copy()
    Dn_raw = sol.y[1].copy()

    D = D_raw / D_raw[-1]
    Dn = Dn_raw / D_raw[-1]
    f = Dn / D

    return {"z": z, "D": D, "f": f, "fD": f * D}

# ------------------------------------------------------------
# 5. Structural markers
# ------------------------------------------------------------

def find_root_scan(func, zmin, zmax, n=2000):
    zz = np.linspace(zmin, zmax, n)
    yy = np.array([func(z) for z in zz], dtype=float)
    for i in range(len(zz) - 1):
        y0, y1 = yy[i], yy[i + 1]
        if np.isfinite(y0) and np.isfinite(y1) and y0 == 0.0:
            return zz[i]
        if np.isfinite(y0) and np.isfinite(y1) and y0 * y1 < 0.0:
            return brentq(func, zz[i], zz[i + 1])
    return None

def finite_slope_g0(Om, alpha, nu, dz=1e-6):
    # safe finite-difference slope of g near z=0
    return (g_of_z(dz, Om, alpha, nu) - g_of_z(0.0, Om, alpha, nu)) / dz

# ------------------------------------------------------------
# 6. Fiducial parameters
# ------------------------------------------------------------

Om = 0.231
alpha = 0.483
nu = 0.886
eps = 0.08

# ------------------------------------------------------------
# 7. Derived markers
# ------------------------------------------------------------

z_s = z_s_exact(Om, alpha)
z_50 = z_at_activation_fraction(0.5, Om, alpha, nu)
z_90 = z_at_activation_fraction(0.9, Om, alpha, nu)

z_acc = find_root_scan(lambda z: q_of_z(z, Om, alpha, nu), 0.0, 3.0)
z_wm1 = find_root_scan(lambda z: w_de_eff(z, Om, alpha, nu) + 1.0, 0.0, 3.0)

print("=== Derived structural markers ===")
print(f"z_s    (x=1)      = {z_s:.6f}")
print(f"z_50   (g=0.5)    = {z_50:.6f}")
print(f"z_90   (g=0.9)    = {z_90:.6f}")
print(f"z_acc  (q=0)      = {z_acc if z_acc is not None else 'None'}")
print(f"z_w=-1 crossing   = {z_wm1 if z_wm1 is not None else 'None'}")
print()

print("=== Transition ordering ===")
markers = [("z_50", z_50), ("z_s", z_s), ("z_acc", z_acc), ("z_90", z_90)]
markers = [(k, v) for k, v in markers if v is not None]
markers.sort(key=lambda kv: kv[1])
for k, v in markers:
    print(f"{k:8s} = {v:.6f}")
print()

print("=== Activation finite-difference near z=0 ===")
for dz in [1e-2, 1e-4, 1e-6, 1e-8]:
    print(f"dz={dz:10.1e}   [g(dz)-g(0)]/dz = {finite_slope_g0(Om, alpha, nu, dz):.6f}")
print()

print("=== Background diagnostics table ===")
print("   z        g(z)      E(z)      q(z)      w_DE_eff(z)")
for zi in [0.0, 0.1, 0.2, 0.5, 1.0, 2.0]:
    print(
        f"{zi:6.2f}   "
        f"{g_of_z(zi, Om, alpha, nu):8.5f}   "
        f"{E_bg(zi, Om, alpha, nu):8.5f}   "
        f"{q_of_z(zi, Om, alpha, nu):8.5f}   "
        f"{w_de_eff(zi, Om, alpha, nu):12.6f}"
    )
print()

# Growth comparison at a few redshifts
gmin = solve_growth(Om, alpha, nu, eps=None)
gflr = solve_growth(Om, alpha, nu, eps=eps)

# helper interpolation onto requested z points
def interp_desc(z_target, z_arr, y_arr):
    order = np.argsort(z_arr)
    return np.interp(z_target, z_arr[order], y_arr[order])

print("=== Growth comparison (relative proxy fD = f * D) ===")
print("   z      minimal      floor      delta")
for zi in [0.0, 0.3, 0.5, 1.0, 2.0]:
    y0 = interp_desc(zi, gmin["z"], gmin["fD"])
    y1 = interp_desc(zi, gflr["z"], gflr["fD"])
    print(f"{zi:6.2f}   {y0:9.6f}   {y1:9.6f}   {y1-y0:+9.6f}")
# Out:
# === Derived structural markers ===
# z_s    (x=1)      = 0.213648
# z_50   (g=0.5)    = 0.136589
# z_90   (g=0.9)    = 0.642727
# z_acc  (q=0)      = 0.8023472779787867
# z_w=-1 crossing   = 0.5214789612643969
#
# === Transition ordering ===
# z_50     = 0.136589
# z_s      = 0.213648
# z_90     = 0.642727
# z_acc    = 0.802347
#
# === Activation finite-difference near z=0 ===
# dz=   1.0e-02   [g(dz)-g(0)]/dz = 6.954520
# dz=   1.0e-04   [g(dz)-g(0)]/dz = 12.230846
# dz=   1.0e-06   [g(dz)-g(0)]/dz = 20.688870
# dz=   1.0e-08   [g(dz)-g(0)]/dz = 34.973683
#
# === Background diagnostics table ===
#    z        g(z)      E(z)      q(z)      w_DE_eff(z)
#   0.00    0.00000    1.00000   -1.00000      -1.300390
#   0.10    0.41354    1.01569   -0.70731      -1.146602
#   0.20    0.61251    1.05024   -0.53141      -1.077573
#   0.50    0.85410    1.21185   -0.20525      -1.002214
#   1.00    0.95474    1.59493    0.09730      -0.981489
#   2.00    0.99049    2.63607    0.34896      -0.982909
#
# === Growth comparison (relative proxy fD = f * D) ===
#    z      minimal      floor      delta
#   0.00    0.380710    0.385818   +0.005108
#   0.30    0.518783    0.520505   +0.001722
#   0.50    0.549743    0.550386   +0.000643
#   1.00    0.535503    0.535090   -0.000412
#   2.00    0.421932    0.421277   -0.000654

# %%
# ============================================================
# Compare loading choices:
#   1) log loading: u = ln(1+z)/u_s
#   2) linear loading: u = z/u_s
#
# Same corrected self-normalised background:
#   E^2 = 1 + Om * g(z) * [ (1+z)^3 - 1 ]
# ============================================================

import numpy as np
from scipy.integrate import solve_ivp
from scipy.optimize import brentq

# ------------------------------------------------------------
# 1. Shared utilities
# ------------------------------------------------------------

def u_eq(Om):
    return (1.0 / 3.0) * np.log((1.0 - Om) / Om)

def u_s(Om, alpha):
    return alpha * u_eq(Om)

def find_root_scan(func, zmin, zmax, n=2000):
    zz = np.linspace(zmin, zmax, n)
    yy = np.array([func(z) for z in zz], dtype=float)
    for i in range(len(zz) - 1):
        y0, y1 = yy[i], yy[i + 1]
        if np.isfinite(y0) and np.isfinite(y1) and y0 == 0.0:
            return zz[i]
        if np.isfinite(y0) and np.isfinite(y1) and y0 * y1 < 0.0:
            return brentq(func, zz[i], zz[i + 1])
    return None

def finite_slope_g0(gfunc, Om, alpha, nu, dz=1e-6):
    return (gfunc(dz, Om, alpha, nu) - gfunc(0.0, Om, alpha, nu)) / dz

# ------------------------------------------------------------
# 2. Two loading models
# ------------------------------------------------------------

def x_log(z, Om, alpha):
    return np.log(1.0 + z) / u_s(Om, alpha)

def x_lin(z, Om, alpha):
    return z / u_s(Om, alpha)

def g_from_x(x, nu):
    x = np.asarray(x, dtype=float)
    out = np.zeros_like(x)
    mask = x > 0.0
    out[mask] = 1.0 - np.exp(-(x[mask] ** nu))
    return out

def g_log(z, Om, alpha, nu):
    return g_from_x(x_log(z, Om, alpha), nu)

def g_lin(z, Om, alpha, nu):
    return g_from_x(x_lin(z, Om, alpha), nu)

def dg_dz_log_safe(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    x = x_log(z, Om, alpha)
    g = g_log(z, Om, alpha, nu)
    out = np.zeros_like(z)
    mask = z > 0.0
    if np.any(mask):
        out[mask] = (
            nu * x[mask]**(nu - 1.0) * (1.0 - g[mask])
            / ((1.0 + z[mask]) * u_s(Om, alpha))
        )
    return out

def dg_dz_lin_safe(z, Om, alpha, nu):
    z = np.asarray(z, dtype=float)
    x = x_lin(z, Om, alpha)
    g = g_lin(z, Om, alpha, nu)
    out = np.zeros_like(z)
    mask = z > 0.0
    if np.any(mask):
        out[mask] = (
            nu * x[mask]**(nu - 1.0) * (1.0 - g[mask])
            / u_s(Om, alpha)
        )
    return out

# ------------------------------------------------------------
# 3. Background and diagnostics builder
# ------------------------------------------------------------

def make_model(gfunc, dgfunc, label):
    def E2_bg(z, Om, alpha, nu):
        z = np.asarray(z, dtype=float)
        g = gfunc(z, Om, alpha, nu)
        return 1.0 + Om * g * ((1.0 + z)**3 - 1.0)

    def E_bg(z, Om, alpha, nu):
        return np.sqrt(E2_bg(z, Om, alpha, nu))

    def dE2_dz_safe(z, Om, alpha, nu):
        z = np.asarray(z, dtype=float)
        g = gfunc(z, Om, alpha, nu)
        dg = dgfunc(z, Om, alpha, nu)
        out = Om * (dg * ((1.0 + z)**3 - 1.0) + g * 3.0 * (1.0 + z)**2)
        out = np.where(z == 0.0, 0.0, out)
        return out

    def q_of_z(z, Om, alpha, nu):
        E2 = E2_bg(z, Om, alpha, nu)
        dE2 = dE2_dz_safe(z, Om, alpha, nu)
        return -1.0 + (1.0 + z) * dE2 / (2.0 * E2)

    def rho_de_eff(z, Om, alpha, nu):
        z = np.asarray(z, dtype=float)
        return E2_bg(z, Om, alpha, nu) - Om * (1.0 + z)**3

    def drho_de_eff_dz(z, Om, alpha, nu):
        z = np.asarray(z, dtype=float)
        return dE2_dz_safe(z, Om, alpha, nu) - 3.0 * Om * (1.0 + z)**2

    def w_de_eff(z, Om, alpha, nu):
        rho = rho_de_eff(z, Om, alpha, nu)
        drho = drho_de_eff_dz(z, Om, alpha, nu)
        return -1.0 + (1.0 + z) * drho / (3.0 * rho)

    def z_s_exact(Om, alpha):
        # x(z_s)=1
        if label == "log":
            return np.exp(u_s(Om, alpha)) - 1.0
        elif label == "linear":
            return u_s(Om, alpha)
        else:
            raise ValueError("unknown label")

    def z_at_activation_fraction(p, Om, alpha, nu):
        x = (-np.log(1.0 - p)) ** (1.0 / nu)
        if label == "log":
            return np.exp(u_s(Om, alpha) * x) - 1.0
        elif label == "linear":
            return u_s(Om, alpha) * x
        else:
            raise ValueError("unknown label")

    def z_of_a(a):
        return 1.0 / a - 1.0

    def Omega_m_pert(z, Om, alpha, nu, eps=None):
        z = np.asarray(z, dtype=float)
        g = gfunc(z, Om, alpha, nu)
        if eps is not None:
            g = eps + (1.0 - eps) * g
        return Om * (1.0 + z)**3 * g / E2_bg(z, Om, alpha, nu)

    def dlnH_dN(a, Om, alpha, nu):
        z = z_of_a(a)
        E2 = E2_bg(z, Om, alpha, nu)
        dE2dz = dE2_dz_safe(z, Om, alpha, nu)
        dE2dN = dE2dz * (-(1.0 + z))
        return 0.5 * dE2dN / E2

    def growth_rhs(N, y, Om, alpha, nu, eps):
        D, Dn = y
        a = np.exp(N)
        src = Omega_m_pert(z_of_a(a), Om, alpha, nu, eps)
        friction = 2.0 + dlnH_dN(a, Om, alpha, nu)
        Dnn = -(friction * Dn) + 1.5 * src * D
        return [Dn, Dnn]

    def solve_growth(Om, alpha, nu, eps=None, a_ini=1e-3, a_fin=1.0, n_eval=600):
        N_ini = np.log(a_ini)
        N_fin = np.log(a_fin)
        N_eval = np.linspace(N_ini, N_fin, n_eval)
        y0 = [a_ini, a_ini]
        sol = solve_ivp(
            growth_rhs, [N_ini, N_fin], y0,
            t_eval=N_eval, args=(Om, alpha, nu, eps),
            rtol=1e-8, atol=1e-10
        )
        N = sol.t
        a = np.exp(N)
        z = z_of_a(a)
        D_raw = sol.y[0].copy()
        Dn_raw = sol.y[1].copy()
        D = D_raw / D_raw[-1]
        Dn = Dn_raw / D_raw[-1]
        f = Dn / D
        return {"z": z, "fD": f * D}

    return {
        "label": label,
        "g": gfunc,
        "E_bg": E_bg,
        "q": q_of_z,
        "w": w_de_eff,
        "z_s": z_s_exact,
        "z_p": z_at_activation_fraction,
        "solve_growth": solve_growth,
    }

# ------------------------------------------------------------
# 4. Build models
# ------------------------------------------------------------

model_log = make_model(g_log, dg_dz_log_safe, "log")
model_lin = make_model(g_lin, dg_dz_lin_safe, "linear")

# ------------------------------------------------------------
# 5. Fiducial parameters
# ------------------------------------------------------------

Om = 0.231
alpha = 0.483
nu = 0.886
eps = 0.08

# ------------------------------------------------------------
# 6. Report function
# ------------------------------------------------------------

def report_model(model):
    g = model["g"]
    E = model["E_bg"]
    q = model["q"]
    w = model["w"]
    z_s = model["z_s"](Om, alpha)
    z_50 = model["z_p"](0.5, Om, alpha, nu)
    z_90 = model["z_p"](0.9, Om, alpha, nu)
    z_acc = find_root_scan(lambda z: q(z, Om, alpha, nu), 0.0, 3.0)
    z_wm1 = find_root_scan(lambda z: w(z, Om, alpha, nu) + 1.0, 0.0, 3.0)

    print(f"=== {model['label'].upper()} loading ===")
    print(f"z_s    = {z_s:.6f}")
    print(f"z_50   = {z_50:.6f}")
    print(f"z_90   = {z_90:.6f}")
    print(f"z_acc  = {z_acc if z_acc is not None else 'None'}")
    print(f"z_w=-1 = {z_wm1 if z_wm1 is not None else 'None'}")
    print()

    print("finite-difference [g(dz)-g(0)]/dz")
    for dz in [1e-2, 1e-4, 1e-6, 1e-8]:
        print(f"dz={dz:10.1e}   {finite_slope_g0(g, Om, alpha, nu, dz):.6f}")
    print()

    print("   z        g(z)      E(z)      q(z)      w_DE_eff(z)")
    for zi in [0.0, 0.1, 0.2, 0.5, 1.0, 2.0]:
        print(
            f"{zi:6.2f}   "
            f"{g(zi, Om, alpha, nu):8.5f}   "
            f"{E(zi, Om, alpha, nu):8.5f}   "
            f"{q(zi, Om, alpha, nu):8.5f}   "
            f"{w(zi, Om, alpha, nu):12.6f}"
        )
    print()

    gmin = model["solve_growth"](Om, alpha, nu, eps=None)
    gflr = model["solve_growth"](Om, alpha, nu, eps=eps)

    def interp_desc(z_target, z_arr, y_arr):
        order = np.argsort(z_arr)
        return np.interp(z_target, z_arr[order], y_arr[order])

    print("growth comparison fD")
    print("   z      minimal      floor      delta")
    for zi in [0.0, 0.3, 0.5, 1.0, 2.0]:
        y0 = interp_desc(zi, gmin["z"], gmin["fD"])
        y1 = interp_desc(zi, gflr["z"], gflr["fD"])
        print(f"{zi:6.2f}   {y0:9.6f}   {y1:9.6f}   {y1-y0:+9.6f}")
    print()

# ------------------------------------------------------------
# 7. Run both
# ------------------------------------------------------------

report_model(model_log)
report_model(model_lin)
# Out:
# === LOG loading ===
# z_s    = 0.213648
# z_50   = 0.136589
# z_90   = 0.642727
# z_acc  = 0.8023472779787867
# z_w=-1 = 0.5214789612643969
#
# finite-difference [g(dz)-g(0)]/dz
# dz=   1.0e-02   6.954520
# dz=   1.0e-04   12.230846
# dz=   1.0e-06   20.688870
# dz=   1.0e-08   34.973683
#
#    z        g(z)      E(z)      q(z)      w_DE_eff(z)
#   0.00    0.00000    1.00000   -1.00000      -1.300390
#   0.10    0.41354    1.01569   -0.70731      -1.146602
#   0.20    0.61251    1.05024   -0.53141      -1.077573
#   0.50    0.85410    1.21185   -0.20525      -1.002214
#   1.00    0.95474    1.59493    0.09730      -0.981489
#   2.00    0.99049    2.63607    0.34896      -0.982909
#
# growth comparison fD
#    z      minimal      floor      delta
#   0.00    0.380710    0.385818   +0.005108
#   0.30    0.518783    0.520505   +0.001722
#   0.50    0.549743    0.550386   +0.000643
#   1.00    0.535503    0.535090   -0.000412
#   2.00    0.421932    0.421277   -0.000654
#
# === LINEAR loading ===
# z_s    = 0.193630
# z_50   = 0.128032
# z_90   = 0.496358
# z_acc  = 0.8058049551204687
# z_w=-1 = 0.2884696572871942
#
# finite-difference [g(dz)-g(0)]/dz
# dz=   1.0e-02   6.984169
# dz=   1.0e-04   12.231387
# dz=   1.0e-06   20.688879
# dz=   1.0e-08   34.973684
#
#    z        g(z)      E(z)      q(z)      w_DE_eff(z)
#   0.00    0.00000    1.00000   -1.00000      -1.300390
#   0.10    0.42699    1.01619   -0.69417      -1.133647
#   0.20    0.64267    1.05265   -0.50439      -1.046628
#   0.50    0.90149    1.22253   -0.18325      -0.952201
#   1.00    0.98620    1.61080    0.08623      -0.958545
#   2.00    0.99963    2.64647    0.33693      -0.992941
#
# growth comparison fD
#    z      minimal      floor      delta
#   0.00    0.387821    0.392303   +0.004481
#   0.30    0.524549    0.525542   +0.000993
#   0.50    0.551288    0.551391   +0.000103
#   1.00    0.532387    0.531920   -0.000467
#   2.00    0.420143    0.419711   -0.000432

# %%
# ============================================================
# Compare pure vs regularised Weibull activation kernel
# Background: corrected self-normalised form
# Loading: equality-tied log loading
# Perturbations: bounded survival-floor closure
# ============================================================

import numpy as np
from scipy.integrate import solve_ivp
from scipy.optimize import brentq

# ------------------------------------------------------------
# 1. Shared cosmology utilities
# ------------------------------------------------------------

def u_eq(Om):
    return (1.0 / 3.0) * np.log((1.0 - Om) / Om)

def u_s(Om, alpha):
    return alpha * u_eq(Om)

def u_of_z(z, Om, alpha):
    return np.log(1.0 + z) / u_s(Om, alpha)

def find_root_scan(func, zmin, zmax, n=3000):
    zz = np.linspace(zmin, zmax, n)
    yy = np.array([func(z) for z in zz], dtype=float)
    for i in range(len(zz) - 1):
        y0, y1 = yy[i], yy[i + 1]
        if np.isfinite(y0) and np.isfinite(y1) and y0 == 0.0:
            return zz[i]
        if np.isfinite(y0) and np.isfinite(y1) and y0 * y1 < 0.0:
            return brentq(func, zz[i], zz[i + 1])
    return None

# ------------------------------------------------------------
# 2. Kernel definitions
# ------------------------------------------------------------

def M_pure(u, nu):
    u = np.asarray(u, dtype=float)
    out = np.zeros_like(u)
    mask = u > 0.0
    out[mask] = u[mask] ** nu
    return out

def M_reg(u, nu, u_c):
    u = np.asarray(u, dtype=float)
    return (u*u + u_c*u_c) ** (0.5 * nu) - (u_c ** nu)

def g_from_M(M):
    return 1.0 - np.exp(-M)

def g_pure_u(u, nu):
    return g_from_M(M_pure(u, nu))

def g_reg_u(u, nu, u_c):
    return g_from_M(M_reg(u, nu, u_c))

# ------------------------------------------------------------
# 3. Build model from chosen kernel
# ------------------------------------------------------------

def make_model(label, nu, u_c=None):
    def g_of_z(z, Om, alpha):
        u = u_of_z(np.asarray(z, dtype=float), Om, alpha)
        if label == "pure":
            return g_pure_u(u, nu)
        elif label == "reg":
            return g_reg_u(u, nu, u_c)
        else:
            raise ValueError("unknown label")

    def dM_du(u):
        u = np.asarray(u, dtype=float)
        out = np.zeros_like(u)
        if label == "pure":
            mask = u > 0.0
            out[mask] = nu * u[mask] ** (nu - 1.0)
        elif label == "reg":
            out = nu * u * (u*u + u_c*u_c) ** (0.5 * nu - 1.0)
        else:
            raise ValueError("unknown label")
        return out

    def dg_dz_safe(z, Om, alpha):
        z = np.asarray(z, dtype=float)
        u = u_of_z(z, Om, alpha)
        g = g_of_z(z, Om, alpha)
        du_dz = 1.0 / ((1.0 + z) * u_s(Om, alpha))
        dM = dM_du(u)
        out = (1.0 - g) * dM * du_dz
        # exact safe handling at z=0
        out = np.where(z == 0.0, 0.0 if label == "reg" else out, out)
        return out

    def E2_bg(z, Om, alpha):
        z = np.asarray(z, dtype=float)
        g = g_of_z(z, Om, alpha)
        return 1.0 + Om * g * ((1.0 + z)**3 - 1.0)

    def E_bg(z, Om, alpha):
        return np.sqrt(E2_bg(z, Om, alpha))

    def dE2_dz_safe(z, Om, alpha):
        z = np.asarray(z, dtype=float)
        g = g_of_z(z, Om, alpha)
        dg = dg_dz_safe(z, Om, alpha)
        out = Om * (dg * ((1.0 + z)**3 - 1.0) + g * 3.0 * (1.0 + z)**2)
        out = np.where(z == 0.0, 0.0, out)
        return out

    def q_of_z(z, Om, alpha):
        E2 = E2_bg(z, Om, alpha)
        dE2 = dE2_dz_safe(z, Om, alpha)
        return -1.0 + (1.0 + z) * dE2 / (2.0 * E2)

    def rho_de_eff(z, Om, alpha):
        z = np.asarray(z, dtype=float)
        return E2_bg(z, Om, alpha) - Om * (1.0 + z)**3

    def drho_de_eff_dz(z, Om, alpha):
        z = np.asarray(z, dtype=float)
        return dE2_dz_safe(z, Om, alpha) - 3.0 * Om * (1.0 + z)**2

    def w_de_eff(z, Om, alpha):
        rho = rho_de_eff(z, Om, alpha)
        drho = drho_de_eff_dz(z, Om, alpha)
        return -1.0 + (1.0 + z) * drho / (3.0 * rho)

    def z_at_x_eq_1(Om, alpha):
        return np.exp(u_s(Om, alpha)) - 1.0

    def z_at_activation_fraction(p, Om, alpha):
        if not (0.0 < p < 1.0):
            raise ValueError("p must lie in (0,1)")

        def f(z):
            return g_of_z(z, Om, alpha) - p

        return find_root_scan(f, 0.0, 5.0)

    def z_of_a(a):
        return 1.0 / a - 1.0

    def g_pert_of_z(z, Om, alpha, eps):
        g = g_of_z(z, Om, alpha)
        return eps + (1.0 - eps) * g

    def Omega_m_pert(z, Om, alpha, eps=None):
        z = np.asarray(z, dtype=float)
        g = g_of_z(z, Om, alpha) if eps is None else g_pert_of_z(z, Om, alpha, eps)
        return Om * (1.0 + z)**3 * g / E2_bg(z, Om, alpha)

    def dlnH_dN(a, Om, alpha):
        z = z_of_a(a)
        E2 = E2_bg(z, Om, alpha)
        dE2dz = dE2_dz_safe(z, Om, alpha)
        dE2dN = dE2dz * (-(1.0 + z))
        return 0.5 * dE2dN / E2

    def growth_rhs(N, y, Om, alpha, eps):
        D, Dn = y
        a = np.exp(N)
        src = Omega_m_pert(z_of_a(a), Om, alpha, eps)
        friction = 2.0 + dlnH_dN(a, Om, alpha)
        Dnn = -(friction * Dn) + 1.5 * src * D
        return [Dn, Dnn]

    def solve_growth(Om, alpha, eps=None, a_ini=1e-3, a_fin=1.0, n_eval=700):
        N_ini = np.log(a_ini)
        N_fin = np.log(a_fin)
        N_eval = np.linspace(N_ini, N_fin, n_eval)
        y0 = [a_ini, a_ini]
        sol = solve_ivp(
            growth_rhs, [N_ini, N_fin], y0,
            t_eval=N_eval, args=(Om, alpha, eps),
            rtol=1e-8, atol=1e-10
        )
        N = sol.t
        a = np.exp(N)
        z = z_of_a(a)
        D_raw = sol.y[0].copy()
        Dn_raw = sol.y[1].copy()
        D = D_raw / D_raw[-1]
        Dn = Dn_raw / D_raw[-1]
        f = Dn / D
        return {"z": z, "fD": f * D}

    return {
        "label": label if label == "pure" else f"reg(u_c={u_c})",
        "g": g_of_z,
        "E": E_bg,
        "q": q_of_z,
        "w": w_de_eff,
        "z_s": z_at_x_eq_1,
        "z_p": z_at_activation_fraction,
        "solve_growth": solve_growth,
    }

# ------------------------------------------------------------
# 4. Report block
# ------------------------------------------------------------

def finite_slope_g0(gfunc, Om, alpha, dz):
    return (gfunc(dz, Om, alpha) - gfunc(0.0, Om, alpha)) / dz

def report_model(model, Om, alpha, eps):
    g = model["g"]
    E = model["E"]
    q = model["q"]
    w = model["w"]

    z_s = model["z_s"](Om, alpha)
    z_50 = model["z_p"](0.5, Om, alpha)
    z_90 = model["z_p"](0.9, Om, alpha)
    z_acc = find_root_scan(lambda z: q(z, Om, alpha), 0.0, 3.0)
    z_wm1 = find_root_scan(lambda z: w(z, Om, alpha) + 1.0, 0.0, 3.0)

    print(f"=== {model['label']} ===")
    print(f"z_s    = {z_s:.6f}")
    print(f"z_50   = {z_50:.6f}")
    print(f"z_90   = {z_90:.6f}")
    print(f"z_acc  = {z_acc if z_acc is not None else 'None'}")
    print(f"z_w=-1 = {z_wm1 if z_wm1 is not None else 'None'}")
    print()

    print("finite-difference [g(dz)-g(0)]/dz")
    for dz in [1e-2, 1e-4, 1e-6, 1e-8]:
        print(f"dz={dz:10.1e}   {finite_slope_g0(g, Om, alpha, dz):.6f}")
    print()

    print("   z        g(z)      E(z)      q(z)      w_DE_eff(z)")
    for zi in [0.0, 0.1, 0.2, 0.5, 1.0, 2.0]:
        print(
            f"{zi:6.2f}   "
            f"{g(zi, Om, alpha):8.5f}   "
            f"{E(zi, Om, alpha):8.5f}   "
            f"{q(zi, Om, alpha):8.5f}   "
            f"{w(zi, Om, alpha):12.6f}"
        )
    print()

    gmin = model["solve_growth"](Om, alpha, eps=None)
    gflr = model["solve_growth"](Om, alpha, eps=eps)

    def interp_desc(z_target, z_arr, y_arr):
        order = np.argsort(z_arr)
        return np.interp(z_target, z_arr[order], y_arr[order])

    print("growth comparison fD")
    print("   z      minimal      floor      delta")
    for zi in [0.0, 0.3, 0.5, 1.0, 2.0]:
        y0 = interp_desc(zi, gmin["z"], gmin["fD"])
        y1 = interp_desc(zi, gflr["z"], gflr["fD"])
        print(f"{zi:6.2f}   {y0:9.6f}   {y1:9.6f}   {y1-y0:+9.6f}")
    print()

# ------------------------------------------------------------
# 5. Fiducial parameters
# ------------------------------------------------------------

Om = 0.231
alpha = 0.483
nu = 0.886
eps = 0.08

# ------------------------------------------------------------
# 6. Run pure and regularised cases
# ------------------------------------------------------------

models = [
    make_model("pure", nu),
    make_model("reg", nu, u_c=0.02),
    make_model("reg", nu, u_c=0.05),
    make_model("reg", nu, u_c=0.10),
]

for model in models:
    report_model(model, Om, alpha, eps)
# Out:
# === pure ===
# z_s    = 0.213648
# z_50   = 0.136589
# z_90   = 0.642727
# z_acc  = 0.8023472779788718
# z_w=-1 = 0.521478961264393
#
# finite-difference [g(dz)-g(0)]/dz
# dz=   1.0e-02   6.954520
# dz=   1.0e-04   12.230846
# dz=   1.0e-06   20.688870
# dz=   1.0e-08   34.973683
#
#    z        g(z)      E(z)      q(z)      w_DE_eff(z)
#   0.00    0.00000    1.00000   -1.00000      -1.300390
#   0.10    0.41354    1.01569   -0.70731      -1.146602
#   0.20    0.61251    1.05024   -0.53141      -1.077573
#   0.50    0.85410    1.21185   -0.20525      -1.002214
#   1.00    0.95474    1.59493    0.09730      -0.981489
#   2.00    0.99049    2.63607    0.34896      -0.982909
#
# growth comparison fD
#    z      minimal      floor      delta
#   0.00    0.380710    0.385818   +0.005108
#   0.30    0.518784    0.520506   +0.001722
#   0.50    0.549754    0.550396   +0.000643
#   1.00    0.535503    0.535091   -0.000412
#   2.00    0.421930    0.421276   -0.000654
#
# === reg(u_c=0.02) ===
# z_s    = 0.213648
# z_50   = 0.143973
# z_90   = 0.655247
# z_acc  = 0.7997598234211949
# z_w=-1 = 0.5215575653826365
#
# finite-difference [g(dz)-g(0)]/dz
# dz=   1.0e-02   4.446998
# dz=   1.0e-04   0.092254
# dz=   1.0e-06   0.000923
# dz=   1.0e-08   0.000009
#
#    z        g(z)      E(z)      q(z)      w_DE_eff(z)
#   0.00    0.00000    1.00000   -1.00000      -1.300390
#   0.10    0.39517    1.01500   -0.71185      -1.151587
#   0.20    0.60029    1.04926   -0.53292      -1.080291
#   0.50    0.84948    1.21080   -0.20393      -1.002301
#   1.00    0.95331    1.59421    0.09854      -0.980841
#   2.00    0.99019    2.63573    0.34940      -0.982323
#
# growth comparison fD
#    z      minimal      floor      delta
#   0.00    0.378785    0.384054   +0.005269
#   0.30    0.518602    0.520383   +0.001781
#   0.50    0.549905    0.550569   +0.000664
#   1.00    0.535740    0.535314   -0.000427
#   2.00    0.422055    0.421379   -0.000676
#
# === reg(u_c=0.05) ===
# z_s    = 0.213648
# z_50   = 0.153111
# z_90   = 0.670991
# z_acc  = 0.7964297374584449
# z_w=-1 = 0.521969874408482
#
# finite-difference [g(dz)-g(0)]/dz
# dz=   1.0e-02   2.612336
# dz=   1.0e-04   0.033247
# dz=   1.0e-06   0.000333
# dz=   1.0e-08   0.000003
#
#    z        g(z)      E(z)      q(z)      w_DE_eff(z)
#   0.00    0.00000    1.00000   -1.00000      -1.300390
#   0.10    0.37232    1.01413   -0.71795      -1.158219
#   0.20    0.58476    1.04802   -0.53499      -1.083924
#   0.50    0.84354    1.20946   -0.20226      -1.002450
#   1.00    0.95146    1.59327    0.10014      -0.980008
#   2.00    0.98980    2.63528    0.34996      -0.981563
#
# growth comparison fD
#    z      minimal      floor      delta
#   0.00    0.376473    0.381937   +0.005463
#   0.30    0.518362    0.520219   +0.001857
#   0.50    0.550096    0.550789   +0.000692
#   1.00    0.536045    0.535601   -0.000445
#   2.00    0.422215    0.421511   -0.000704
#
# === reg(u_c=0.1) ===
# z_s    = 0.213648
# z_50   = 0.166768
# z_90   = 0.695113
# z_acc  = 0.7911737457966782
# z_w=-1 = 0.5234374771467558
#
# finite-difference [g(dz)-g(0)]/dz
# dz=   1.0e-02   1.412228
# dz=   1.0e-04   0.015361
# dz=   1.0e-06   0.000154
# dz=   1.0e-08   0.000002
#
#    z        g(z)      E(z)      q(z)      w_DE_eff(z)
#   0.00    0.00000    1.00000   -1.00000      -1.300390
#   0.10    0.33853    1.01286   -0.72825      -1.169268
#   0.20    0.56079    1.04609   -0.53865      -1.090044
#   0.50    0.83416    1.20733   -0.19967      -1.002796
#   1.00    0.94851    1.59177    0.10268      -0.978701
#   2.00    0.98917    2.63457    0.35085      -0.980351
#
# growth comparison fD
#    z      minimal      floor      delta
#   0.00    0.373113    0.378861   +0.005747
#   0.30    0.517967    0.519945   +0.001978
#   0.50    0.550391    0.551130   +0.000738
#   1.00    0.536525    0.536053   -0.000472
#   2.00    0.422466    0.421718   -0.000748

# %%
"""
t5000_weak_cluster_diagnostic.py
================================

Purpose
-------
Target the small weak-geometry cluster found at T=5000.

Previous result:
  strong_geometry     : 139 / 147
  borderline_geometry :   3 / 147
  weak_geometry       :   5 / 147

All weak cases were localized near T=5000:
  - n=20, shift=-3
  - n=20, shift=-2
  - n=20, shift=-1
  - n=20, shift=+3
  - n=16, shift=-3

This script asks whether those weak cases are:

  (A) pool-size artifacts
  (B) edge-window artifacts
  (C) basis-construction artifacts
  (D) local spacing-structure effects
  (E) genuine local softening of the reduced-flow geometry

Unified convention
------------------
Reduced repulsive flow:

    dt_i/ds = +2 * sum_{j!=i} 1/(t_i - t_j),   s >= 0

This is the same convention used in the previous scripts.

Main idea
---------
For each target window, compare two diagnostics:

  1. INTERNAL basis:
     Hadamard/density basis constructed only from the window itself.

  2. CONTEXT basis:
     Hadamard/density basis constructed from an expanded local context,
     then restricted back to the target window.

If weak geometry improves strongly under context basis, the weakness is
probably an edge/basis artifact. If not, it is more likely intrinsic to
that local zero configuration.
"""

import math
import mpmath
import numpy as np
from scipy.linalg import svd

mpmath.mp.dps = 25

# =========================================================
# User controls
# =========================================================

T_TARGET = 5000

# pool sizes to test
POOL_SIZES = [56, 80, 120]

# weak cases identified previously
TARGET_WINDOWS = [
    (16, -3),
    (20, -3),
    (20, -2),
    (20, -1),
    (20, +3),
]

# include neighbouring shifts for comparison
NEIGHBOUR_SHIFTS = [-4, -3, -2, -1, 0, 1, 2, 3, 4]

WINDOW_SIZES = [12, 16, 20, 24]

# context padding on each side for context-basis construction
CONTEXT_PAD = 8

S_MAX = 0.04
N_S = 100

# geometry thresholds
COS1_STRONG = 0.998
R2_STRONG   = 0.997
S1S2_STRONG = 10.0
S2S3_STRONG = 8.0

COS1_BORDER = 0.995
R2_BORDER   = 0.985
S1S2_BORDER = 8.0
S2S3_BORDER = 6.0


# =========================================================
# Zero finding
# =========================================================

def find_zeros_pool(T, n, span=None):
    if span is None:
        span = max(40.0, n * 2.0 * math.pi / math.log(T / (2.0 * math.pi)) * 1.7)

    ts = np.linspace(T - span, T + span, max(16000, int(span * 70)))
    zv = np.array([float(mpmath.siegelz(t)) for t in ts])

    roots = []
    for i in range(len(zv) - 1):
        if zv[i] * zv[i + 1] < 0:
            r = float(mpmath.findroot(mpmath.siegelz, (ts[i], ts[i+1]), solver="illinois"))
            roots.append(r)

    roots = sorted(roots)
    if len(roots) < n:
        raise RuntimeError(f"Only found {len(roots)} zeros near T={T}; needed {n}. Increase span.")

    mid = len(roots) // 2
    start = max(0, mid - n // 2)
    end = start + n
    if end > len(roots):
        end = len(roots)
        start = end - n

    return np.array(roots[start:end], dtype=float)


# =========================================================
# Reduced flow
# =========================================================

def rk4_repulsive(z, ds):
    def vel(x):
        n = len(x)
        v = np.zeros(n, dtype=float)
        for i in range(n):
            for j in range(n):
                if i != j:
                    d = x[i] - x[j]
                    if abs(d) > 1e-12:
                        v[i] += 2.0 / d
        return v

    k1 = vel(z)
    k2 = vel(z + 0.5 * ds * k1)
    k3 = vel(z + 0.5 * ds * k2)
    k4 = vel(z + ds * k3)
    return z + (ds / 6.0) * (k1 + 2*k2 + 2*k3 + k4)

def build_velocity_matrix(z0, s_vals):
    s_full = np.concatenate([[0.0], s_vals])
    hist = np.zeros((len(s_full), len(z0)), dtype=float)
    hist[0] = z0.copy()

    z = z0.copy()
    for k in range(1, len(s_full)):
        z = rk4_repulsive(z, s_full[k] - s_full[k - 1])
        hist[k] = z

    V = np.zeros((len(z0), len(s_vals)), dtype=float)
    for k, s in enumerate(s_vals):
        col = (hist[k+1] - z0) / s
        col -= col.mean()
        V[:, k] = col

    return V


# =========================================================
# Basis construction
# =========================================================

def hadamard_direction(z):
    n = len(z)
    vh = np.zeros(n, dtype=float)
    for i in range(n):
        for j in range(n):
            if i != j:
                vh[i] += 2.0 / (z[i] - z[j])
    vh -= vh.mean()
    nrm = np.linalg.norm(vh)
    if nrm < 1e-15:
        return np.zeros_like(vh)
    return vh / nrm

def density_direction(z, e1):
    n = len(z)
    g = np.diff(z)
    vd = np.zeros(n, dtype=float)

    for i in range(1, n - 1):
        di = 0.5 * (z[i+1] - z[i-1])
        if di > 1e-12:
            vd[i] = -(g[i] - g[i-1]) / (2.0 * di**2)

    if len(g) > 1:
        vd[0]  = -(g[1]  - g[0])  / (2.0 * g[0]**2)
        vd[-1] = -(g[-1] - g[-2]) / (2.0 * g[-1]**2)

    vd -= vd.mean()
    vd -= np.dot(vd, e1) * e1

    nrm = np.linalg.norm(vd)
    if nrm < 1e-15:
        return np.zeros_like(vd)
    return vd / nrm

def internal_basis(z0):
    e1 = hadamard_direction(z0)
    e2 = density_direction(z0, e1)
    return e1, e2

def context_basis(pool, start, end, pad):
    """
    Build e1/e2 on a larger context window, then restrict to target.
    """
    cstart = max(0, start - pad)
    cend = min(len(pool), end + pad)

    zc = pool[cstart:cend]
    e1c = hadamard_direction(zc)
    e2c = density_direction(zc, e1c)

    # restriction indices inside context
    rs = start - cstart
    re = end - cstart

    e1 = e1c[rs:re].copy()
    e2 = e2c[rs:re].copy()

    # re-centre and re-orthonormalise on target window
    e1 -= e1.mean()
    n1 = np.linalg.norm(e1)
    if n1 > 1e-15:
        e1 /= n1

    e2 -= e2.mean()
    e2 -= np.dot(e2, e1) * e1
    n2 = np.linalg.norm(e2)
    if n2 > 1e-15:
        e2 /= n2

    return e1, e2


# =========================================================
# Geometry diagnostics
# =========================================================

def spacing_stats(z0):
    g = np.diff(z0)
    D = g.mean()
    dd = np.diff(g)

    return {
        "D": float(D),
        "gminD": float(g.min() / D),
        "gmaxD": float(g.max() / D),
        "gapCV": float(g.std() / D),
        "rangeD": float((g.max() - g.min()) / D),
        "ddRMSD": float(np.sqrt(np.mean(dd**2)) / D) if len(dd) else 0.0,
        "left_gapD": float(g[0] / D),
        "right_gapD": float(g[-1] / D),
    }

def classify_geom(cos1, R2, S1S2, S2S3):
    strong = (
        cos1 >= COS1_STRONG and
        R2 >= R2_STRONG and
        S1S2 >= S1S2_STRONG and
        S2S3 >= S2S3_STRONG
    )

    borderline_ok = (
        cos1 >= COS1_BORDER and
        R2 >= R2_BORDER and
        S1S2 >= S1S2_BORDER and
        S2S3 >= S2S3_BORDER
    )

    if strong:
        return "strong"
    if borderline_ok:
        return "borderline"
    return "weak"

def geometry_with_basis(z0, e1, e2):
    s_vals = np.exp(np.linspace(np.log(1e-4), np.log(S_MAX), N_S))
    V = build_velocity_matrix(z0, s_vals)

    U, S, _ = svd(V, full_matrices=False)

    cos1 = abs(np.dot(U[:, 0], e1))

    r2s = []
    for k in range(V.shape[1]):
        vk = V[:, k]
        nrm = np.linalg.norm(vk)
        if nrm > 1e-15:
            proj = np.dot(vk, e1) * e1 + np.dot(vk, e2) * e2
            r2s.append(1.0 - (np.linalg.norm(vk - proj) / nrm)**2)

    R2 = float(np.mean(r2s))
    S1S2 = float(S[0] / S[1])
    S2S3 = float(S[1] / S[2])

    return {
        "cos1": float(cos1),
        "R2": R2,
        "S1S2": S1S2,
        "S2S3": S2S3,
        "tier": classify_geom(float(cos1), R2, S1S2, S2S3),
    }


# =========================================================
# Window extraction
# =========================================================

def window_indices(pool_len, n, shift):
    center = pool_len // 2 + shift
    start = center - n // 2
    end = start + n
    if start < 0 or end > pool_len:
        return None, None
    return start, end


# =========================================================
# Reporting
# =========================================================

def print_section(title):
    print()
    print("=" * 120)
    print(title)
    print("-" * 120)

def print_header():
    hdr = (
        f"{'pool':>5} {'n':>4} {'shift':>6} "
        f"{'basis':>9} {'tier':>11} "
        f"{'cos1':>9} {'R²':>9} {'S1/S2':>9} {'S2/S3':>9} "
        f"{'gminD':>8} {'gmaxD':>8} {'gapCV':>8} {'ddRMSD':>8} {'leftD':>8} {'rightD':>8}"
    )
    print(hdr)
    print("-" * len(hdr))

def print_row(pool_size, n, shift, basis_name, geom, sp):
    print(
        f"{pool_size:5d} {n:4d} {shift:6d} "
        f"{basis_name:>9s} {geom['tier']:>11s} "
        f"{geom['cos1']:9.6f} {geom['R2']:9.6f} {geom['S1S2']:9.3f} {geom['S2S3']:9.3f} "
        f"{sp['gminD']:8.4f} {sp['gmaxD']:8.4f} {sp['gapCV']:8.4f} {sp['ddRMSD']:8.4f} "
        f"{sp['left_gapD']:8.4f} {sp['right_gapD']:8.4f}"
    )


# =========================================================
# Main
# =========================================================

if __name__ == "__main__":
    print("t5000_weak_cluster_diagnostic.py")
    print("=" * 120)
    print(f"Target height T = {T_TARGET}")
    print("Reduced flow: dt_i/ds = +2 sum_{j!=i} 1/(t_i-t_j)")

    # -----------------------------------------------------
    # Part 1: test original weak windows across pool sizes
    # -----------------------------------------------------
    print_section("PART 1 — original weak windows across different zero-pool sizes")
    print_header()

    part1_rows = []

    for pool_size in POOL_SIZES:
        pool = find_zeros_pool(T_TARGET, pool_size)

        for n, shift in TARGET_WINDOWS:
            start, end = window_indices(len(pool), n, shift)
            if start is None:
                continue

            z0 = pool[start:end]
            sp = spacing_stats(z0)

            e1i, e2i = internal_basis(z0)
            gi = geometry_with_basis(z0, e1i, e2i)

            e1c, e2c = context_basis(pool, start, end, CONTEXT_PAD)
            gc = geometry_with_basis(z0, e1c, e2c)

            print_row(pool_size, n, shift, "internal", gi, sp)
            print_row(pool_size, n, shift, "context", gc, sp)

            part1_rows.append((pool_size, n, shift, gi, gc, sp))

    # -----------------------------------------------------
    # Part 2: neighbouring shifts and sizes
    # -----------------------------------------------------
    print_section("PART 2 — neighbourhood scan around T=5000")
    print_header()

    part2_rows = []

    pool = find_zeros_pool(T_TARGET, max(POOL_SIZES))

    for n in WINDOW_SIZES:
        for shift in NEIGHBOUR_SHIFTS:
            start, end = window_indices(len(pool), n, shift)
            if start is None:
                continue

            z0 = pool[start:end]
            sp = spacing_stats(z0)

            e1i, e2i = internal_basis(z0)
            gi = geometry_with_basis(z0, e1i, e2i)

            e1c, e2c = context_basis(pool, start, end, CONTEXT_PAD)
            gc = geometry_with_basis(z0, e1c, e2c)

            print_row(len(pool), n, shift, "internal", gi, sp)
            print_row(len(pool), n, shift, "context", gc, sp)

            part2_rows.append((n, shift, gi, gc, sp))

    # -----------------------------------------------------
    # Part 3: compact verdict tables
    # -----------------------------------------------------
    print_section("PART 3 — compact verdict: does context rescue weak geometry?")

    print(f"{'n':>4} {'shift':>6} {'pool':>5} {'internal':>11} {'context':>11} {'Δtier':>10}")
    print("-" * 60)

    tier_rank = {"weak": 0, "borderline": 1, "strong": 2}

    for pool_size, n, shift, gi, gc, sp in part1_rows:
        delta = tier_rank[gc["tier"]] - tier_rank[gi["tier"]]
        if delta > 0:
            dlabel = "rescued"
        elif delta == 0:
            dlabel = "same"
        else:
            dlabel = "worse"

        print(f"{n:4d} {shift:6d} {pool_size:5d} {gi['tier']:>11s} {gc['tier']:>11s} {dlabel:>10s}")

    print()
    print("Interpretation guide")
    print("-" * 80)
    print("If weak internal windows become strong/borderline under context basis:")
    print("  -> likely edge/basis artifact.")
    print("If weak internal windows remain weak under context basis and larger pools:")
    print("  -> likely genuine local softening.")
    print("If changing pool size changes the result:")
    print("  -> pool extraction alignment matters and the weak cluster is not intrinsic.")
# Out:
# t5000_weak_cluster_diagnostic.py
# ========================================================================================================================
# Target height T = 5000
# Reduced flow: dt_i/ds = +2 sum_{j!=i} 1/(t_i-t_j)
#
# ========================================================================================================================
# PART 1 — original weak windows across different zero-pool sizes
# ------------------------------------------------------------------------------------------------------------------------
#  pool    n  shift     basis        tier      cos1        R²     S1/S2     S2/S3    gminD    gmaxD    gapCV   ddRMSD    leftD   rightD
# -------------------------------------------------------------------------------------------------------------------------------------
#    56   16     -3  internal      strong  0.999443  0.999233    23.698    30.760   0.3405   2.0048   0.3616   0.5366   0.7627   2.0048
#    56   16     -3   context        weak  0.016976  0.202439    23.698    30.760   0.3405   2.0048   0.3616   0.5366   0.7627   2.0048
#    56   20     -3  internal        weak  0.991600  0.966839     6.937    16.039   0.1107   2.1365   0.4335   0.7075   1.5302   0.6164
#    56   20     -3   context        weak  0.900810  0.850954     6.937    16.039   0.1107   2.1365   0.4335   0.7075   1.5302   0.6164
#    56   20     -2  internal        weak  0.991595  0.942991     6.993    16.122   0.1155   2.2291   0.4364   0.6511   0.1155   0.7731
#    56   20     -2   context        weak  0.922451  0.871028     6.993    16.122   0.1155   2.2291   0.4364   0.6511   0.1155   0.7731
#    56   20     -1  internal      strong  0.999548  0.999341    26.415    24.260   0.3570   2.1021   0.3643   0.6020   0.7997   1.1919
#    56   20     -1   context        weak  0.113007  0.361572    26.415    24.260   0.3570   2.1021   0.3643   0.6020   0.7997   1.1919
#    56   20      3  internal        weak  0.993380  0.961559     7.839    15.398   0.1305   2.1509   0.4676   0.8352   1.3332   1.5655
#    56   20      3   context        weak  0.926567  0.849217     7.839    15.398   0.1305   2.1509   0.4676   0.8352   1.3332   1.5655
#    80   16     -3  internal      strong  0.999443  0.999233    23.698    30.760   0.3405   2.0048   0.3616   0.5366   0.7627   2.0048
#    80   16     -3   context        weak  0.016976  0.202439    23.698    30.760   0.3405   2.0048   0.3616   0.5366   0.7627   2.0048
#    80   20     -3  internal        weak  0.991600  0.966839     6.937    16.039   0.1107   2.1365   0.4335   0.7075   1.5302   0.6164
#    80   20     -3   context        weak  0.900810  0.850954     6.937    16.039   0.1107   2.1365   0.4335   0.7075   1.5302   0.6164
#    80   20     -2  internal        weak  0.991595  0.942991     6.993    16.122   0.1155   2.2291   0.4364   0.6511   0.1155   0.7731
#    80   20     -2   context        weak  0.922451  0.871028     6.993    16.122   0.1155   2.2291   0.4364   0.6511   0.1155   0.7731
#    80   20     -1  internal      strong  0.999548  0.999341    26.415    24.260   0.3570   2.1021   0.3643   0.6020   0.7997   1.1919
#    80   20     -1   context        weak  0.113007  0.361572    26.415    24.260   0.3570   2.1021   0.3643   0.6020   0.7997   1.1919
#    80   20      3  internal        weak  0.993380  0.961559     7.839    15.398   0.1305   2.1509   0.4676   0.8352   1.3332   1.5655
#    80   20      3   context        weak  0.926567  0.849217     7.839    15.398   0.1305   2.1509   0.4676   0.8352   1.3332   1.5655
#   120   16     -3  internal      strong  0.999443  0.999233    23.698    30.760   0.3405   2.0048   0.3616   0.5366   0.7627   2.0048
#   120   16     -3   context        weak  0.016976  0.202439    23.698    30.760   0.3405   2.0048   0.3616   0.5366   0.7627   2.0048
#   120   20     -3  internal        weak  0.991600  0.966839     6.937    16.039   0.1107   2.1365   0.4335   0.7075   1.5302   0.6164
#   120   20     -3   context        weak  0.900810  0.850954     6.937    16.039   0.1107   2.1365   0.4335   0.7075   1.5302   0.6164
#   120   20     -2  internal        weak  0.991595  0.942991     6.993    16.122   0.1155   2.2291   0.4364   0.6511   0.1155   0.7731
#   120   20     -2   context        weak  0.922451  0.871028     6.993    16.122   0.1155   2.2291   0.4364   0.6511   0.1155   0.7731
#   120   20     -1  internal      strong  0.999548  0.999341    26.415    24.260   0.3570   2.1021   0.3643   0.6020   0.7997   1.1919
#   120   20     -1   context        weak  0.113007  0.361572    26.415    24.260   0.3570   2.1021   0.3643   0.6020   0.7997   1.1919
#   120   20      3  internal        weak  0.993380  0.961559     7.839    15.398   0.1305   2.1509   0.4676   0.8352   1.3332   1.5655
#   120   20      3   context        weak  0.926567  0.849217     7.839    15.398   0.1305   2.1509   0.4676   0.8352   1.3332   1.5655
#
# ========================================================================================================================
# PART 2 — neighbourhood scan around T=5000
# ------------------------------------------------------------------------------------------------------------------------
#  pool    n  shift     basis        tier      cos1        R²     S1/S2     S2/S3    gminD    gmaxD    gapCV   ddRMSD    leftD   rightD
# -------------------------------------------------------------------------------------------------------------------------------------
#   120   12     -4  internal      strong  0.999351  0.999657    21.801    44.277   0.3520   1.2845   0.2689   0.4459   1.2001   1.0875
#   120   12     -4   context        weak  0.719136  0.738621    21.801    44.277   0.3520   1.2845   0.2689   0.4459   1.2001   1.0875
#   120   12     -3  internal      strong  0.999358  0.999730    21.946    43.414   0.3587   1.3090   0.2664   0.4552   1.1723   1.0126
#   120   12     -3   context        weak  0.817510  0.918493    21.946    43.414   0.3587   1.3090   0.2664   0.4552   1.1723   1.0126
#   120   12     -2  internal      strong  0.999401  0.999406    22.708    33.022   0.3761   1.3726   0.2900   0.4912   1.2520   0.6948
#   120   12     -2   context        weak  0.913362  0.964698    22.708    33.022   0.3761   1.3726   0.2900   0.4912   1.2520   0.6948
#   120   12     -1  internal      strong  0.999398  0.999320    22.659    31.627   0.3459   2.0363   0.4161   0.6309   1.2622   2.0363
#   120   12     -1   context        weak  0.799916  0.829701    22.659    31.627   0.3459   2.0363   0.4161   0.6309   1.2622   2.0363
#   120   12      0  internal  borderline  0.999443  0.996719    23.574    26.166   0.3638   2.1416   0.4356   0.7339   0.3638   0.7587
#   120   12      0   context        weak  0.763068  0.768137    23.574    26.166   0.3638   2.1416   0.4356   0.7339   0.3638   0.7587
#   120   12      1  internal      strong  0.999912  0.999755    55.106    55.568   0.6039   2.0932   0.3978   0.6642   1.2234   0.6039
#   120   12      1   context        weak  0.464877  0.752489    55.106    55.568   0.6039   2.0932   0.3978   0.6642   1.2234   0.6039
#   120   12      2  internal      strong  0.999929  0.999967    61.114    49.016   0.6325   2.1924   0.4170   0.6933   1.0617   0.7603
#   120   12      2   context        weak  0.869450  0.869026    61.114    49.016   0.6325   2.1924   0.4170   0.6933   1.0617   0.7603
#   120   12      3  internal      strong  0.999929  0.999967    61.264    46.609   0.6223   2.1568   0.4158   0.6984   1.0293   1.2229
#   120   12      3   context        weak  0.803218  0.908616    61.264    46.609   0.6223   2.1568   0.4158   0.6984   1.0293   1.2229
#   120   12      4  internal      strong  0.999912  0.999648    54.947    48.090   0.6447   2.2345   0.4431   0.7476   1.0052   0.6699
#   120   12      4   context        weak  0.889719  0.907725    54.947    48.090   0.6447   2.2345   0.4431   0.7476   1.0052   0.6699
#   120   16     -4  internal        weak  0.992554  0.943728     7.176    15.522   0.1190   1.4230   0.3638   0.4909   0.1190   0.7203
#   120   16     -4   context        weak  0.939602  0.894987     7.176    15.522   0.1190   1.4230   0.3638   0.4909   0.1190   0.7203
#   120   16     -3  internal      strong  0.999443  0.999233    23.698    30.760   0.3405   2.0048   0.3616   0.5366   0.7627   2.0048
#   120   16     -3   context        weak  0.016976  0.202439    23.698    30.760   0.3405   2.0048   0.3616   0.5366   0.7627   2.0048
#   120   16     -2  internal      strong  0.999447  0.998371    23.749    28.863   0.3417   2.0118   0.3654   0.6317   1.1652   0.7128
#   120   16     -2   context        weak  0.658469  0.653373    23.749    28.863   0.3417   2.0118   0.3654   0.6317   1.1652   0.7128
#   120   16     -1  internal      strong  0.999488  0.999388    24.620    25.104   0.3556   2.0934   0.3920   0.6583   1.1621   0.6040
#   120   16     -1   context        weak  0.823348  0.844211    24.620    25.104   0.3556   2.0934   0.3920   0.6583   1.1621   0.6040
#   120   16      0  internal      strong  0.999516  0.999582    25.423    24.373   0.3662   2.1561   0.4069   0.6788   1.2191   0.7478
#   120   16      0   context        weak  0.889552  0.926641    25.423    24.373   0.3662   2.1561   0.4069   0.6788   1.2191   0.7478
#   120   16      1  internal      strong  0.999519  0.999478    25.577    24.245   0.3661   2.1556   0.4069   0.6897   1.3362   1.2222
#   120   16      1   context        weak  0.861940  0.951307    25.577    24.245   0.3661   2.1556   0.4069   0.6897   1.3362   1.2222
#   120   16      2  internal      strong  0.999549  0.997461    26.372    21.237   0.3838   2.2595   0.4249   0.6891   0.3838   0.6774
#   120   16      2   context        weak  0.917798  0.956448    26.372    21.237   0.3838   2.2595   0.4249   0.6891   0.3838   0.6774
#   120   16      3  internal      strong  0.999914  0.999966    55.844    53.714   0.5965   2.0674   0.3955   0.6461   1.2083   1.6265
#   120   16      3   context        weak  0.045401  0.093301    55.844    53.714   0.5965   2.0674   0.3955   0.6461   1.2083   1.6265
#   120   16      4  internal        weak  0.993753  0.957007     7.793    28.283   0.1352   2.2283   0.4812   0.8175   1.0791   0.1352
#   120   16      4   context        weak  0.924656  0.829133     7.793    28.283   0.1352   2.2283   0.4812   0.8175   1.0791   0.1352
#   120   20     -4  internal        weak  0.991594  0.972547     6.896    16.160   0.1099   2.1207   0.4249   0.7244   0.7525   0.7514
#   120   20     -4   context        weak  0.899352  0.829670     6.896    16.160   0.1099   2.1207   0.4249   0.7244   0.7525   0.7514
#   120   20     -3  internal        weak  0.991600  0.966839     6.937    16.039   0.1107   2.1365   0.4335   0.7075   1.5302   0.6164
#   120   20     -3   context        weak  0.900810  0.850954     6.937    16.039   0.1107   2.1365   0.4335   0.7075   1.5302   0.6164
#   120   20     -2  internal        weak  0.991595  0.942991     6.993    16.122   0.1155   2.2291   0.4364   0.6511   0.1155   0.7731
#   120   20     -2   context        weak  0.922451  0.871028     6.993    16.122   0.1155   2.2291   0.4364   0.6511   0.1155   0.7731
#   120   20     -1  internal      strong  0.999548  0.999341    26.415    24.260   0.3570   2.1021   0.3643   0.6020   0.7997   1.1919
#   120   20     -1   context        weak  0.113007  0.361572    26.415    24.260   0.3570   2.1021   0.3643   0.6020   0.7997   1.1919
#   120   20      0  internal      strong  0.999553  0.999012    26.492    23.065   0.3603   2.1210   0.3745   0.6139   1.2284   0.6358
#   120   20      0   context        weak  0.842912  0.846705    26.492    23.065   0.3603   2.1210   0.3745   0.6139   1.2284   0.6358
#   120   20      1  internal      strong  0.999550  0.999487    26.400    22.734   0.3521   2.0730   0.3915   0.6454   1.1507   1.6309
#   120   20      1   context        weak  0.336323  0.123259    26.400    22.734   0.3521   2.0730   0.3915   0.6454   1.1507   1.6309
#   120   20      2  internal        weak  0.993480  0.960597     7.918    15.040   0.1330   2.1912   0.4600   0.7784   1.2389   0.1330
#   120   20      2   context        weak  0.928286  0.845971     7.918    15.040   0.1330   2.1912   0.4600   0.7784   1.2389   0.1330
#   120   20      3  internal        weak  0.993380  0.961559     7.839    15.398   0.1305   2.1509   0.4676   0.8352   1.3332   1.5655
#   120   20      3   context        weak  0.926567  0.849217     7.839    15.398   0.1305   2.1509   0.4676   0.8352   1.3332   1.5655
#   120   20      4  internal        weak  0.993375  0.971037     7.828    15.733   0.1313   2.1642   0.4668   0.8126   0.3676   1.2234
#   120   20      4   context        weak  0.913759  0.833240     7.828    15.733   0.1313   2.1642   0.4668   0.8126   0.3676   1.2234
#   120   24     -4  internal        weak  0.990772  0.967068     6.789    16.830   0.1129   2.1783   0.4085   0.6777   1.0132   0.7554
#   120   24     -4   context        weak  0.925969  0.852154     6.789    16.830   0.1129   2.1783   0.4085   0.6777   1.0132   0.7554
#   120   24     -3  internal        weak  0.990793  0.963165     6.793    16.805   0.1118   2.1575   0.4074   0.6787   1.0768   1.2233
#   120   24     -3   context        weak  0.910819  0.865164     6.793    16.805   0.1118   2.1575   0.4074   0.6787   1.0768   1.2233
#   120   24     -2  internal        weak  0.990781  0.974058     6.827    16.464   0.1139   2.1986   0.4211   0.6996   0.7801   0.6591
#   120   24     -2   context        weak  0.925270  0.861700     6.827    16.464   0.1139   2.1986   0.4211   0.6996   0.7801   0.6591
#   120   24     -1  internal        weak  0.990908  0.960310     6.848    16.351   0.1094   2.1114   0.4259   0.6877   1.5122   1.6611
#   120   24     -1   context        weak  0.734233  0.587858     6.848    16.351   0.1094   2.1114   0.4259   0.6877   1.5122   1.6611
#   120   24      0  internal        weak  0.993615  0.951992     7.586    15.358   0.1164   2.2466   0.4752   0.7451   0.1164   0.1363
#   120   24      0   context        weak  0.947851  0.901542     7.586    15.358   0.1164   2.2466   0.4752   0.7451   0.1164   0.1363
#   120   24      1  internal        weak  0.993096  0.967770     7.799    15.400   0.1279   2.1074   0.4247   0.7460   0.8018   1.5339
#   120   24      1   context        weak  0.624387  0.644951     7.799    15.400   0.1279   2.1074   0.4247   0.7460   0.8018   1.5339
#   120   24      2  internal        weak  0.993073  0.968417     7.759    15.517   0.1257   2.0723   0.4172   0.7319   1.2002   1.1715
#   120   24      2   context        weak  0.882395  0.803631     7.759    15.517   0.1257   2.0723   0.4172   0.7319   1.2002   1.1715
#   120   24      3  internal        weak  0.993037  0.970484     7.764    15.548   0.1284   2.1159   0.4273   0.7534   1.1746   0.7416
#   120   24      3   context        weak  0.915362  0.830074     7.764    15.548   0.1284   2.1159   0.4273   0.7534   1.1746   0.7416
#   120   24      4  internal        weak  0.993017  0.966552     7.754    15.674   0.1284   2.1156   0.4273   0.7590   1.1962   1.1777
#   120   24      4   context        weak  0.913877  0.840720     7.754    15.674   0.1284   2.1156   0.4273   0.7590   1.1962   1.1777
#
# ========================================================================================================================
# PART 3 — compact verdict: does context rescue weak geometry?
# ------------------------------------------------------------------------------------------------------------------------
#    n  shift  pool    internal     context      Δtier
# ------------------------------------------------------------
#   16     -3    56      strong        weak      worse
#   20     -3    56        weak        weak       same
#   20     -2    56        weak        weak       same
#   20     -1    56      strong        weak      worse
#   20      3    56        weak        weak       same
#   16     -3    80      strong        weak      worse
#   20     -3    80        weak        weak       same
#   20     -2    80        weak        weak       same
#   20     -1    80      strong        weak      worse
#   20      3    80        weak        weak       same
#   16     -3   120      strong        weak      worse
#   20     -3   120        weak        weak       same
#   20     -2   120        weak        weak       same
#   20     -1   120      strong        weak      worse
#   20      3   120        weak        weak       same
#
# Interpretation guide
# --------------------------------------------------------------------------------
# If weak internal windows become strong/borderline under context basis:
#   -> likely edge/basis artifact.
# If weak internal windows remain weak under context basis and larger pools:
#   -> likely genuine local softening.
# If changing pool size changes the result:
#   -> pool extraction alignment matters and the weak cluster is not intrinsic.

# %%
"""
small_gap_geometry_stress_test.py
=================================

Purpose
-------
Test whether weak reduced-flow geometry is predicted by unusually small
local gaps.

Hypothesis
----------
The T=5000 weak-geometry cluster is not random. It is associated with
windows containing a very small normalized gap:

    g_min / Δ̄ ≈ 0.11 - 0.13

This script scans all tested heights/windows and asks:

  1. Do weak-geometry windows have systematically smaller g_min / Δ̄?
  2. Is there a clean threshold below which geometry tends to weaken?
  3. Are there false positives: tiny gaps but still strong geometry?
  4. Are there false negatives: weak geometry without tiny gaps?

Unified convention
------------------
Reduced repulsive flow:

    dt_i/ds = +2 * sum_{j!=i} 1/(t_i - t_j),   s >= 0

This is the same reduced-flow convention used in previous diagnostics.
"""

import math
import mpmath
import numpy as np
from scipy.linalg import svd

mpmath.mp.dps = 25

# =========================================================
# User controls
# =========================================================

T_VALUES = [50, 100, 200, 500, 1000, 5000, 10000]
N_POOL = 56
WINDOW_SIZES = [12, 16, 20, 24]
SHIFTS = [-4, -3, -2, -1, 0, 1, 2, 3, 4]

S_MAX = 0.04
N_S = 100

# geometry tier thresholds
COS1_STRONG = 0.998
R2_STRONG   = 0.997
S1S2_STRONG = 10.0
S2S3_STRONG = 8.0

COS1_BORDER = 0.995
R2_BORDER   = 0.985
S1S2_BORDER = 8.0
S2S3_BORDER = 6.0

# candidate small-gap thresholds
GMIN_THRESHOLDS = [0.10, 0.12, 0.14, 0.16, 0.18, 0.20, 0.25, 0.30]


# =========================================================
# Zero finding
# =========================================================

def find_zeros_pool(T, n, span=None):
    if span is None:
        span = max(40.0, n * 2.0 * math.pi / math.log(T / (2.0 * math.pi)) * 1.7)

    ts = np.linspace(T - span, T + span, max(16000, int(span * 70)))
    zv = np.array([float(mpmath.siegelz(t)) for t in ts])

    roots = []
    for i in range(len(zv) - 1):
        if zv[i] * zv[i + 1] < 0:
            r = float(mpmath.findroot(mpmath.siegelz, (ts[i], ts[i + 1]), solver="illinois"))
            roots.append(r)

    roots = sorted(roots)

    if len(roots) < n:
        raise RuntimeError(f"Only found {len(roots)} zeros near T={T}; needed {n}. Increase span.")

    mid = len(roots) // 2
    start = max(0, mid - n // 2)
    end = start + n
    if end > len(roots):
        end = len(roots)
        start = end - n

    return np.array(roots[start:end], dtype=float)


# =========================================================
# Reduced flow
# =========================================================

def rk4_repulsive(z, ds):
    def vel(x):
        n = len(x)
        v = np.zeros(n, dtype=float)
        for i in range(n):
            for j in range(n):
                if i != j:
                    d = x[i] - x[j]
                    if abs(d) > 1e-12:
                        v[i] += 2.0 / d
        return v

    k1 = vel(z)
    k2 = vel(z + 0.5 * ds * k1)
    k3 = vel(z + 0.5 * ds * k2)
    k4 = vel(z + ds * k3)
    return z + (ds / 6.0) * (k1 + 2*k2 + 2*k3 + k4)

def build_velocity_matrix(z0, s_vals):
    s_full = np.concatenate([[0.0], s_vals])
    hist = np.zeros((len(s_full), len(z0)), dtype=float)
    hist[0] = z0.copy()

    z = z0.copy()
    for k in range(1, len(s_full)):
        z = rk4_repulsive(z, s_full[k] - s_full[k - 1])
        hist[k] = z

    V = np.zeros((len(z0), len(s_vals)), dtype=float)
    for k, s in enumerate(s_vals):
        col = (hist[k+1] - z0) / s
        col -= col.mean()
        V[:, k] = col

    return V


# =========================================================
# Basis and geometry
# =========================================================

def hadamard_direction(z0):
    n = len(z0)
    vh = np.zeros(n, dtype=float)

    for i in range(n):
        for j in range(n):
            if i != j:
                vh[i] += 2.0 / (z0[i] - z0[j])

    vh -= vh.mean()
    nrm = np.linalg.norm(vh)
    if nrm < 1e-15:
        return np.zeros_like(vh)
    return vh / nrm

def density_direction(z0, e1):
    n = len(z0)
    g = np.diff(z0)
    vd = np.zeros(n, dtype=float)

    for i in range(1, n - 1):
        di = 0.5 * (z0[i+1] - z0[i-1])
        if di > 1e-12:
            vd[i] = -(g[i] - g[i-1]) / (2.0 * di**2)

    if len(g) > 1:
        vd[0]  = -(g[1]  - g[0])  / (2.0 * g[0]**2)
        vd[-1] = -(g[-1] - g[-2]) / (2.0 * g[-1]**2)

    vd -= vd.mean()
    vd -= np.dot(vd, e1) * e1

    nrm = np.linalg.norm(vd)
    if nrm < 1e-15:
        return np.zeros_like(vd)
    return vd / nrm

def spacing_stats(z0):
    g = np.diff(z0)
    D = g.mean()
    dd = np.diff(g)

    return {
        "D": float(D),
        "gminD": float(g.min() / D),
        "gmaxD": float(g.max() / D),
        "gapCV": float(g.std() / D),
        "rangeD": float((g.max() - g.min()) / D),
        "ddRMSD": float(np.sqrt(np.mean(dd**2)) / D) if len(dd) else 0.0,
        "leftD": float(g[0] / D),
        "rightD": float(g[-1] / D),
        "min_gap_index": int(np.argmin(g)),
    }

def geometry_diagnostics(z0):
    s_vals = np.exp(np.linspace(np.log(1e-4), np.log(S_MAX), N_S))
    V = build_velocity_matrix(z0, s_vals)

    e1 = hadamard_direction(z0)
    e2 = density_direction(z0, e1)

    U, S, _ = svd(V, full_matrices=False)
    cos1 = abs(np.dot(U[:, 0], e1))

    r2s = []
    for k in range(V.shape[1]):
        vk = V[:, k]
        nrm = np.linalg.norm(vk)
        if nrm > 1e-15:
            proj = np.dot(vk, e1) * e1 + np.dot(vk, e2) * e2
            r2s.append(1.0 - (np.linalg.norm(vk - proj) / nrm)**2)

    R2 = float(np.mean(r2s))
    S1S2 = float(S[0] / S[1])
    S2S3 = float(S[1] / S[2])

    return {
        "cos1": float(cos1),
        "R2": R2,
        "S1S2": S1S2,
        "S2S3": S2S3,
    }

def classify_geometry(out):
    strong = (
        out["cos1"] >= COS1_STRONG and
        out["R2"] >= R2_STRONG and
        out["S1S2"] >= S1S2_STRONG and
        out["S2S3"] >= S2S3_STRONG
    )

    borderline = (
        out["cos1"] >= COS1_BORDER and
        out["R2"] >= R2_BORDER and
        out["S1S2"] >= S1S2_BORDER and
        out["S2S3"] >= S2S3_BORDER
    )

    if strong:
        return "strong"
    if borderline:
        return "borderline"
    return "weak"


# =========================================================
# Window extraction
# =========================================================

def extract_window(pool, n, shift):
    center = len(pool) // 2 + shift
    start = center - n // 2
    end = start + n
    if start < 0 or end > len(pool):
        return None
    return pool[start:end].copy()


# =========================================================
# Analysis helpers
# =========================================================

def summarize_by_tier(rows):
    tiers = ["strong", "borderline", "weak"]

    print()
    print("=" * 100)
    print("SUMMARY BY GEOMETRY TIER")
    print("-" * 100)
    print(f"{'tier':>12} {'N':>5} {'gminD_med':>12} {'gminD_mean':>12} {'gminD_min':>12} {'gminD_max':>12} {'gapCV_med':>12} {'ddRMSD_med':>12}")
    print("-" * 100)

    for tier in tiers:
        sub = [r for r in rows if r["tier"] == tier]
        if not sub:
            continue
        gmin = np.array([r["gminD"] for r in sub])
        gapcv = np.array([r["gapCV"] for r in sub])
        ddr = np.array([r["ddRMSD"] for r in sub])
        print(
            f"{tier:>12s} {len(sub):5d} "
            f"{np.median(gmin):12.4f} {np.mean(gmin):12.4f} "
            f"{gmin.min():12.4f} {gmin.max():12.4f} "
            f"{np.median(gapcv):12.4f} {np.median(ddr):12.4f}"
        )

def threshold_table(rows):
    print()
    print("=" * 100)
    print("SMALL-GAP THRESHOLD TABLE")
    print("-" * 100)
    print("Treat 'weak' as the positive class.")
    print()
    print(f"{'gminD<thr':>10} {'TP':>4} {'FP':>4} {'FN':>4} {'TN':>4} {'precision':>10} {'recall':>10} {'F1':>10}")
    print("-" * 100)

    for thr in GMIN_THRESHOLDS:
        tp = fp = fn = tn = 0
        for r in rows:
            pred = r["gminD"] < thr
            actual = r["tier"] == "weak"

            if pred and actual:
                tp += 1
            elif pred and not actual:
                fp += 1
            elif (not pred) and actual:
                fn += 1
            else:
                tn += 1

        prec = tp / (tp + fp) if (tp + fp) else 0.0
        rec = tp / (tp + fn) if (tp + fn) else 0.0
        f1 = 2 * prec * rec / (prec + rec) if (prec + rec) else 0.0

        print(f"{thr:10.2f} {tp:4d} {fp:4d} {fn:4d} {tn:4d} {prec:10.3f} {rec:10.3f} {f1:10.3f}")

def print_extreme_windows(rows):
    print()
    print("=" * 100)
    print("WINDOWS SORTED BY SMALLEST gminD")
    print("-" * 100)
    print(f"{'T':>6} {'n':>4} {'shift':>6} {'tier':>11} {'gminD':>8} {'gapCV':>8} {'ddRMSD':>8} {'cos1':>9} {'R²':>9} {'S1/S2':>9} {'minidx':>7}")
    print("-" * 100)

    for r in sorted(rows, key=lambda x: x["gminD"])[:40]:
        print(
            f"{r['T']:6d} {r['n']:4d} {r['shift']:6d} {r['tier']:>11s} "
            f"{r['gminD']:8.4f} {r['gapCV']:8.4f} {r['ddRMSD']:8.4f} "
            f"{r['cos1']:9.6f} {r['R2']:9.6f} {r['S1S2']:9.3f} {r['min_gap_index']:7d}"
        )

def correlation_report(rows):
    print()
    print("=" * 100)
    print("CORRELATIONS WITH GEOMETRY QUALITY")
    print("-" * 100)

    # geometry quality score: higher is better
    # use conservative components, normalised loosely
    quality = np.array([
        min(r["cos1"], 1.0)
        + min(r["R2"], 1.0)
        + min(r["S1S2"] / 20.0, 1.0)
        + min(r["S2S3"] / 20.0, 1.0)
        for r in rows
    ])

    keys = ["gminD", "gmaxD", "gapCV", "rangeD", "ddRMSD", "leftD", "rightD"]

    for k in keys:
        x = np.array([r[k] for r in rows])
        if np.std(x) < 1e-15:
            continue
        corr = np.corrcoef(x, quality)[0, 1]
        print(f"corr({k:>8s}, geometry_quality) = {corr:+.4f}")


# =========================================================
# Main
# =========================================================

if __name__ == "__main__":
    print("small_gap_geometry_stress_test.py")
    print("=" * 100)
    print("Reduced flow: dt_i/ds = +2 sum_{j!=i} 1/(t_i-t_j)")
    print()

    rows = []

    for T in T_VALUES:
        pool = find_zeros_pool(T, N_POOL)

        for n in WINDOW_SIZES:
            for shift in SHIFTS:
                z0 = extract_window(pool, n, shift)
                if z0 is None:
                    continue

                sp = spacing_stats(z0)
                gd = geometry_diagnostics(z0)
                tier = classify_geometry(gd)

                row = {
                    "T": T,
                    "n": n,
                    "shift": shift,
                    "tier": tier,
                    **sp,
                    **gd,
                }
                rows.append(row)

    print(f"Total windows scanned: {len(rows)}")

    summarize_by_tier(rows)
    threshold_table(rows)
    print_extreme_windows(rows)
    correlation_report(rows)

    print()
    print("=" * 100)
    print("INTERPRETATION GUIDE")
    print("-" * 100)
    print("If weak windows cluster below gminD≈0.14 with few false positives:")
    print("  -> small-gap compression is a strong diagnostic of geometry softening.")
    print("If many strong windows also have gminD below the same threshold:")
    print("  -> small gaps are not sufficient; another structural variable is needed.")
    print("If weak windows occur at large gminD:")
    print("  -> small-gap hypothesis is incomplete.")
# Out:
# small_gap_geometry_stress_test.py
# ====================================================================================================
# Reduced flow: dt_i/ds = +2 sum_{j!=i} 1/(t_i-t_j)
#
# Total windows scanned: 252
#
# ====================================================================================================
# SUMMARY BY GEOMETRY TIER
# ----------------------------------------------------------------------------------------------------
#         tier     N    gminD_med   gminD_mean    gminD_min    gminD_max    gapCV_med   ddRMSD_med
# ----------------------------------------------------------------------------------------------------
#       strong   230       0.4031       0.4094       0.2887       0.6447       0.3665       0.6183
#   borderline     5       0.3155       0.3262       0.3021       0.3638       0.4025       0.6595
#         weak    17       0.1190       0.1212       0.1094       0.1352       0.4273       0.7319
#
# ====================================================================================================
# SMALL-GAP THRESHOLD TABLE
# ----------------------------------------------------------------------------------------------------
# Treat 'weak' as the positive class.
#
#  gminD<thr   TP   FP   FN   TN  precision     recall         F1
# ----------------------------------------------------------------------------------------------------
#       0.10    0    0   17  235      0.000      0.000      0.000
#       0.12    9    0    8  235      1.000      0.529      0.692
#       0.14   17    0    0  235      1.000      1.000      1.000
#       0.16   17    0    0  235      1.000      1.000      1.000
#       0.18   17    0    0  235      1.000      1.000      1.000
#       0.20   17    0    0  235      1.000      1.000      1.000
#       0.25   17    0    0  235      1.000      1.000      1.000
#       0.30   17    1    0  234      0.944      1.000      0.971
#
# ====================================================================================================
# WINDOWS SORTED BY SMALLEST gminD
# ----------------------------------------------------------------------------------------------------
#      T    n  shift        tier    gminD    gapCV   ddRMSD      cos1        R²     S1/S2  minidx
# ----------------------------------------------------------------------------------------------------
#   5000   24     -1        weak   0.1094   0.4259   0.6877  0.990908  0.960310     6.848       1
#   5000   20     -4        weak   0.1099   0.4249   0.7244  0.991594  0.972547     6.896       2
#   5000   20     -3        weak   0.1107   0.4335   0.7075  0.991600  0.966839     6.937       1
#   5000   24     -3        weak   0.1118   0.4074   0.6787  0.990793  0.963165     6.793       3
#   5000   24     -4        weak   0.1129   0.4085   0.6777  0.990772  0.967068     6.789       4
#   5000   24     -2        weak   0.1139   0.4211   0.6996  0.990781  0.974058     6.827       2
#   5000   20     -2        weak   0.1155   0.4364   0.6511  0.991595  0.942991     6.993       0
#   5000   24      0        weak   0.1164   0.4752   0.7451  0.993615  0.951992     7.586       0
#   5000   16     -4        weak   0.1190   0.3638   0.4909  0.992554  0.943728     7.176       0
#   5000   24      2        weak   0.1257   0.4172   0.7319  0.993073  0.968417     7.759      20
#   5000   24      1        weak   0.1279   0.4247   0.7460  0.993096  0.967770     7.799      21
#   5000   24      4        weak   0.1284   0.4273   0.7590  0.993017  0.966552     7.754      18
#   5000   24      3        weak   0.1284   0.4273   0.7534  0.993037  0.970484     7.764      19
#   5000   20      3        weak   0.1305   0.4676   0.8352  0.993380  0.961559     7.839      17
#   5000   20      4        weak   0.1313   0.4668   0.8126  0.993375  0.971037     7.828      16
#   5000   20      2        weak   0.1330   0.4600   0.7784  0.993480  0.960597     7.918      18
#   5000   16      4        weak   0.1352   0.4812   0.8175  0.993753  0.957007     7.793      14
#  10000   16      4      strong   0.2887   0.3843   0.5988  0.998850  0.998185    17.245       4
#  10000   16      3  borderline   0.3021   0.3908   0.6750  0.998886  0.996825    17.526       5
#  10000   20      2      strong   0.3025   0.3769   0.6087  0.999009  0.998360    18.743       8
#  10000   24      0      strong   0.3038   0.3662   0.5777  0.999104  0.998567    19.717      12
#  10000   24     -1      strong   0.3068   0.3596   0.5815  0.999107  0.998541    19.747      13
#  10000   12     -3      strong   0.3070   0.4162   0.6736  0.998817  0.998042    16.879       9
#  10000   12      2      strong   0.3085   0.4221   0.6643  0.998786  0.998454    16.636       4
#  10000   12      0      strong   0.3087   0.4219   0.7344  0.998797  0.998132    16.640       6
#  10000   20     -4      strong   0.3092   0.3656   0.5957  0.999019  0.998388    18.742      14
#  10000   20      1      strong   0.3092   0.3685   0.6190  0.999017  0.998363    18.833       9
#  10000   20      4      strong   0.3093   0.3946   0.6568  0.999046  0.998345    18.957       6
#  10000   12      1      strong   0.3106   0.4276   0.7387  0.998806  0.997227    16.717       5
#  10000   24     -2      strong   0.3106   0.3608   0.5841  0.999115  0.998193    19.833      14
#  10000   12     -1      strong   0.3108   0.4293   0.7229  0.998821  0.998033    16.856       7
#  10000   16      2      strong   0.3110   0.4017   0.6834  0.998919  0.997703    17.806       6
#  10000   24     -3      strong   0.3114   0.3636   0.5646  0.999123  0.998442    19.932      15
#  10000   20      3  borderline   0.3116   0.4025   0.6595  0.999057  0.996529    19.032       7
#  10000   20     -3      strong   0.3128   0.3747   0.5977  0.999039  0.998677    18.950      13
#  10000   16      1      strong   0.3133   0.4094   0.6573  0.998942  0.998069    18.023       7
#  10000   16     -4      strong   0.3133   0.3996   0.6540  0.998949  0.998041    18.016      12
#  10000   12     -2      strong   0.3146   0.4293   0.7329  0.998829  0.997834    16.947       8
#  10000   24      1  borderline   0.3155   0.3829   0.6276  0.999140  0.996647    19.968      11
#  10000   12      3      strong   0.3158   0.3932   0.6505  0.998789  0.997596    16.668       3
#
# ====================================================================================================
# CORRELATIONS WITH GEOMETRY QUALITY
# ----------------------------------------------------------------------------------------------------
# corr(   gminD, geometry_quality) = +0.8148
# corr(   gmaxD, geometry_quality) = -0.4717
# corr(   gapCV, geometry_quality) = -0.5425
# corr(  rangeD, geometry_quality) = -0.7104
# corr(  ddRMSD, geometry_quality) = -0.4302
# corr(   leftD, geometry_quality) = +0.0938
# corr(  rightD, geometry_quality) = +0.0659
#
# ====================================================================================================
# INTERPRETATION GUIDE
# ----------------------------------------------------------------------------------------------------
# If weak windows cluster below gminD≈0.14 with few false positives:
#   -> small-gap compression is a strong diagnostic of geometry softening.
# If many strong windows also have gminD below the same threshold:
#   -> small gaps are not sufficient; another structural variable is needed.
# If weak windows occur at large gminD:
#   -> small-gap hypothesis is incomplete.

# %%
"""
local_force_decomposition.py
============================

Purpose
-------
Test the mechanism behind weak reduced-flow geometry.

Previous result:
  Weak geometry was perfectly classified by:

      g_min / Δ̄ < 0.14

This script asks WHY.

Hypothesis
----------
When a window contains an unusually small local gap, the reduced-flow
velocity is dominated by the adjacent-pair singular interaction around
that gap. This introduces a local direction that competes with the
global two-mode geometry.

Reduced flow convention
-----------------------
We use:

    dt_i/ds = +2 * sum_{j!=i} 1/(t_i - t_j),   s >= 0

For a very small gap g between t_k and t_{k+1}, the adjacent-pair
contribution scales like:

    4/g

in the gap equation.

What this script computes
-------------------------
For each window:
  1. geometry tier
  2. minimum gap index k
  3. force decomposition at s=0:
       - adjacent-pair contribution
       - local-neighbour contribution
       - background contribution
  4. norm fractions:
       - adjacent_pair_fraction
       - local_4body_fraction
       - background_fraction
  5. gap-equation decomposition:
       dg_min/ds = adjacent + local_tail + background_tail

Outputs compare:
  - strong windows
  - borderline windows
  - weak windows

The key question:
  Do weak windows have much larger adjacent/local dominance than
  healthy windows?
"""

import math
import mpmath
import numpy as np
from scipy.linalg import svd

mpmath.mp.dps = 25

# =========================================================
# User controls
# =========================================================

T_VALUES = [50, 100, 200, 500, 1000, 5000, 10000]
N_POOL = 56
WINDOW_SIZES = [12, 16, 20, 24]
SHIFTS = [-4, -3, -2, -1, 0, 1, 2, 3, 4]

S_MAX = 0.04
N_S = 100

# Geometry tier thresholds
COS1_STRONG = 0.998
R2_STRONG   = 0.997
S1S2_STRONG = 10.0
S2S3_STRONG = 8.0

COS1_BORDER = 0.995
R2_BORDER   = 0.985
S1S2_BORDER = 8.0
S2S3_BORDER = 6.0


# =========================================================
# Zero finding
# =========================================================

def find_zeros_pool(T, n, span=None):
    if span is None:
        span = max(40.0, n * 2.0 * math.pi / math.log(T / (2.0 * math.pi)) * 1.7)

    ts = np.linspace(T - span, T + span, max(16000, int(span * 70)))
    zv = np.array([float(mpmath.siegelz(t)) for t in ts])

    roots = []
    for i in range(len(zv) - 1):
        if zv[i] * zv[i + 1] < 0:
            r = float(mpmath.findroot(mpmath.siegelz, (ts[i], ts[i + 1]), solver="illinois"))
            roots.append(r)

    roots = sorted(roots)

    if len(roots) < n:
        raise RuntimeError(f"Only found {len(roots)} zeros near T={T}; needed {n}. Increase span.")

    mid = len(roots) // 2
    start = max(0, mid - n // 2)
    end = start + n
    if end > len(roots):
        end = len(roots)
        start = end - n

    return np.array(roots[start:end], dtype=float)


# =========================================================
# Reduced flow
# =========================================================

def reduced_velocity(z):
    """
    Full reduced repulsive velocity:

        v_i = 2 sum_{j!=i} 1/(z_i - z_j)
    """
    n = len(z)
    v = np.zeros(n, dtype=float)

    for i in range(n):
        for j in range(n):
            if i != j:
                d = z[i] - z[j]
                if abs(d) > 1e-12:
                    v[i] += 2.0 / d

    return v

def rk4_repulsive(z, ds):
    def vel(x):
        return reduced_velocity(x)

    k1 = vel(z)
    k2 = vel(z + 0.5 * ds * k1)
    k3 = vel(z + 0.5 * ds * k2)
    k4 = vel(z + ds * k3)
    return z + (ds / 6.0) * (k1 + 2*k2 + 2*k3 + k4)

def build_velocity_matrix(z0, s_vals):
    s_full = np.concatenate([[0.0], s_vals])
    hist = np.zeros((len(s_full), len(z0)), dtype=float)
    hist[0] = z0.copy()

    z = z0.copy()
    for k in range(1, len(s_full)):
        z = rk4_repulsive(z, s_full[k] - s_full[k - 1])
        hist[k] = z

    V = np.zeros((len(z0), len(s_vals)), dtype=float)
    for k, s in enumerate(s_vals):
        col = (hist[k+1] - z0) / s
        col -= col.mean()
        V[:, k] = col

    return V


# =========================================================
# Geometry
# =========================================================

def hadamard_direction(z0):
    vh = reduced_velocity(z0)
    vh -= vh.mean()
    nrm = np.linalg.norm(vh)
    if nrm < 1e-15:
        return np.zeros_like(vh)
    return vh / nrm

def density_direction(z0, e1):
    n = len(z0)
    g = np.diff(z0)
    vd = np.zeros(n, dtype=float)

    for i in range(1, n - 1):
        di = 0.5 * (z0[i+1] - z0[i-1])
        if di > 1e-12:
            vd[i] = -(g[i] - g[i-1]) / (2.0 * di**2)

    if len(g) > 1:
        vd[0]  = -(g[1]  - g[0])  / (2.0 * g[0]**2)
        vd[-1] = -(g[-1] - g[-2]) / (2.0 * g[-1]**2)

    vd -= vd.mean()
    vd -= np.dot(vd, e1) * e1

    nrm = np.linalg.norm(vd)
    if nrm < 1e-15:
        return np.zeros_like(vd)
    return vd / nrm

def geometry_diagnostics(z0):
    s_vals = np.exp(np.linspace(np.log(1e-4), np.log(S_MAX), N_S))
    V = build_velocity_matrix(z0, s_vals)

    e1 = hadamard_direction(z0)
    e2 = density_direction(z0, e1)

    U, S, _ = svd(V, full_matrices=False)

    cos1 = abs(np.dot(U[:, 0], e1))

    r2s = []
    for k in range(V.shape[1]):
        vk = V[:, k]
        nrm = np.linalg.norm(vk)
        if nrm > 1e-15:
            proj = np.dot(vk, e1) * e1 + np.dot(vk, e2) * e2
            r2s.append(1.0 - (np.linalg.norm(vk - proj) / nrm)**2)

    R2 = float(np.mean(r2s))
    S1S2 = float(S[0] / S[1])
    S2S3 = float(S[1] / S[2])

    return {
        "cos1": float(cos1),
        "R2": R2,
        "S1S2": S1S2,
        "S2S3": S2S3,
    }

def classify_geometry(out):
    strong = (
        out["cos1"] >= COS1_STRONG and
        out["R2"] >= R2_STRONG and
        out["S1S2"] >= S1S2_STRONG and
        out["S2S3"] >= S2S3_STRONG
    )

    borderline = (
        out["cos1"] >= COS1_BORDER and
        out["R2"] >= R2_BORDER and
        out["S1S2"] >= S1S2_BORDER and
        out["S2S3"] >= S2S3_BORDER
    )

    if strong:
        return "strong"
    if borderline:
        return "borderline"
    return "weak"


# =========================================================
# Spacing stats
# =========================================================

def spacing_stats(z):
    g = np.diff(z)
    D = g.mean()
    k = int(np.argmin(g))

    return {
        "D": float(D),
        "gmin": float(g[k]),
        "gminD": float(g[k] / D),
        "gmaxD": float(g.max() / D),
        "gapCV": float(g.std() / D),
        "min_gap_index": k,
    }


# =========================================================
# Force decomposition
# =========================================================

def contribution_from_set(z, target_indices, source_indices):
    """
    Contribution to velocity on target_indices from source_indices.

    Returns an n-vector with nonzero entries only at target indices.
    """
    n = len(z)
    v = np.zeros(n, dtype=float)

    for i in target_indices:
        for j in source_indices:
            if i == j:
                continue
            d = z[i] - z[j]
            if abs(d) > 1e-12:
                v[i] += 2.0 / d

    return v

def full_contribution_from_sources(z, source_indices):
    """
    Contribution to every particle from a subset of source particles.
    """
    n = len(z)
    v = np.zeros(n, dtype=float)

    for i in range(n):
        for j in source_indices:
            if i == j:
                continue
            d = z[i] - z[j]
            if abs(d) > 1e-12:
                v[i] += 2.0 / d

    v -= v.mean()
    return v

def force_decomposition(z):
    """
    Decompose velocity around the minimum gap.

    Let min gap be between k and k+1.

    Adjacent-pair vector:
      contribution only between k and k+1.

    Local-4 source set:
      {k-1, k, k+1, k+2} intersect window.

    Background:
      all remaining sources.

    We compute:
      - norm fractions of full velocity
      - gap derivative decomposition
    """
    n = len(z)
    g = np.diff(z)
    D = g.mean()
    k = int(np.argmin(g))

    i_left = k
    i_right = k + 1

    pair_set = [i_left, i_right]

    local_set = sorted(set([x for x in [k-1, k, k+1, k+2] if 0 <= x < n]))
    background_set = [j for j in range(n) if j not in local_set]

    full_v = reduced_velocity(z)
    full_v -= full_v.mean()
    full_norm = np.linalg.norm(full_v) + 1e-30

    # Adjacent pair contribution as a source set restricted to the pair
    pair_v = np.zeros(n, dtype=float)
    pair_v[i_left]  = 2.0 / (z[i_left]  - z[i_right])
    pair_v[i_right] = 2.0 / (z[i_right] - z[i_left])
    pair_v -= pair_v.mean()

    local_v = full_contribution_from_sources(z, local_set)
    background_v = full_contribution_from_sources(z, background_set)

    # Orthogonal residual check, not expected to be zero because source
    # partitions include induced velocities on all particles.
    pair_frac = np.linalg.norm(pair_v) / full_norm
    local_frac = np.linalg.norm(local_v) / full_norm
    background_frac = np.linalg.norm(background_v) / full_norm

    # Gap derivative decomposition
    # g = z[k+1] - z[k]
    # dg/ds = v[k+1] - v[k]
    full_gap_deriv = full_v[i_right] - full_v[i_left]

    pair_gap_deriv = (
        2.0 / (z[i_right] - z[i_left])
        -
        2.0 / (z[i_left] - z[i_right])
    )

    # contributions to gap derivative from nearby non-pair neighbours
    local_tail_sources = [j for j in local_set if j not in pair_set]
    bg_sources = [j for j in range(n) if j not in local_set]

    def gap_contribution_from_sources(source_indices):
        vr = 0.0
        vl = 0.0
        for j in source_indices:
            if j != i_right:
                vr += 2.0 / (z[i_right] - z[j])
            if j != i_left:
                vl += 2.0 / (z[i_left] - z[j])
        return vr - vl

    local_tail_gap = gap_contribution_from_sources(local_tail_sources)
    background_gap = gap_contribution_from_sources(bg_sources)

    # theoretical compression coefficient:
    # dg/ds = 4/g - C*g
    gmin = g[k]
    C_tail = (pair_gap_deriv - full_gap_deriv) / (gmin + 1e-30)

    return {
        "min_gap_index": k,
        "gminD": float(gmin / D),
        "pair_frac": float(pair_frac),
        "local4_frac": float(local_frac),
        "background_frac": float(background_frac),
        "full_gap_deriv": float(full_gap_deriv),
        "pair_gap_deriv": float(pair_gap_deriv),
        "local_tail_gap": float(local_tail_gap),
        "background_gap": float(background_gap),
        "tail_total_gap": float(local_tail_gap + background_gap),
        "tail_over_pair": float(abs(local_tail_gap + background_gap) / (abs(pair_gap_deriv) + 1e-30)),
        "C_tail": float(C_tail),
    }


# =========================================================
# Window extraction
# =========================================================

def extract_window(pool, n, shift):
    center = len(pool) // 2 + shift
    start = center - n // 2
    end = start + n
    if start < 0 or end > len(pool):
        return None
    return pool[start:end].copy()


# =========================================================
# Reporting
# =========================================================

def summarize_by_tier(rows):
    print()
    print("=" * 120)
    print("SUMMARY BY GEOMETRY TIER")
    print("-" * 120)

    hdr = (
        f"{'tier':>12} {'N':>5} "
        f"{'gminD_med':>10} {'pairFrac_med':>13} {'local4_med':>11} "
        f"{'bg_med':>9} {'tail/pair_med':>14} {'Ctail_med':>11}"
    )
    print(hdr)
    print("-" * len(hdr))

    for tier in ["strong", "borderline", "weak"]:
        sub = [r for r in rows if r["tier"] == tier]
        if not sub:
            continue

        def med(key):
            return float(np.median([r[key] for r in sub]))

        print(
            f"{tier:>12s} {len(sub):5d} "
            f"{med('gminD'):10.4f} {med('pair_frac'):13.4f} {med('local4_frac'):11.4f} "
            f"{med('background_frac'):9.4f} {med('tail_over_pair'):14.4f} {med('C_tail'):11.4f}"
        )

def threshold_report(rows):
    print()
    print("=" * 120)
    print("PAIR / LOCAL DOMINANCE THRESHOLD CHECK")
    print("-" * 120)

    weak = [r for r in rows if r["tier"] == "weak"]
    nonweak = [r for r in rows if r["tier"] != "weak"]

    for key in ["pair_frac", "local4_frac", "tail_over_pair", "C_tail"]:
        weak_vals = np.array([r[key] for r in weak])
        non_vals = np.array([r[key] for r in nonweak])

        print()
        print(f"{key}:")
        print(f"  weak    median={np.median(weak_vals):.4f}, min={weak_vals.min():.4f}, max={weak_vals.max():.4f}")
        print(f"  nonweak median={np.median(non_vals):.4f}, min={non_vals.min():.4f}, max={non_vals.max():.4f}")

def print_weak_windows(rows):
    print()
    print("=" * 120)
    print("WEAK WINDOWS — LOCAL FORCE DETAILS")
    print("-" * 120)

    hdr = (
        f"{'T':>6} {'n':>4} {'shift':>6} {'k':>4} "
        f"{'gminD':>8} {'cos1':>9} {'R²':>9} {'S1/S2':>9} "
        f"{'pairFrac':>10} {'local4':>9} {'bg':>9} "
        f"{'pairGap':>10} {'tailGap':>10} {'tail/pair':>10} {'Ctail':>10}"
    )
    print(hdr)
    print("-" * len(hdr))

    for r in sorted([x for x in rows if x["tier"] == "weak"], key=lambda x: x["gminD"]):
        print(
            f"{r['T']:6d} {r['n']:4d} {r['shift']:6d} {r['min_gap_index']:4d} "
            f"{r['gminD']:8.4f} {r['cos1']:9.6f} {r['R2']:9.6f} {r['S1S2']:9.3f} "
            f"{r['pair_frac']:10.4f} {r['local4_frac']:9.4f} {r['background_frac']:9.4f} "
            f"{r['pair_gap_deriv']:10.4f} {r['tail_total_gap']:10.4f} "
            f"{r['tail_over_pair']:10.4f} {r['C_tail']:10.4f}"
        )

def correlation_report(rows):
    print()
    print("=" * 120)
    print("CORRELATIONS WITH GEOMETRY QUALITY")
    print("-" * 120)

    quality = np.array([
        min(r["cos1"], 1.0)
        + min(r["R2"], 1.0)
        + min(r["S1S2"] / 20.0, 1.0)
        + min(r["S2S3"] / 20.0, 1.0)
        for r in rows
    ])

    keys = ["gminD", "pair_frac", "local4_frac", "background_frac", "tail_over_pair", "C_tail"]

    for key in keys:
        x = np.array([r[key] for r in rows])
        if np.std(x) < 1e-15:
            continue
        corr = np.corrcoef(x, quality)[0, 1]
        print(f"corr({key:>15s}, geometry_quality) = {corr:+.4f}")


# =========================================================
# Main
# =========================================================

if __name__ == "__main__":
    print("local_force_decomposition.py")
    print("=" * 120)
    print("Reduced flow: dt_i/ds = +2 sum_{j!=i} 1/(t_i-t_j)")
    print()

    rows = []

    for T in T_VALUES:
        pool = find_zeros_pool(T, N_POOL)

        for n in WINDOW_SIZES:
            for shift in SHIFTS:
                z0 = extract_window(pool, n, shift)
                if z0 is None:
                    continue

                sp = spacing_stats(z0)
                gd = geometry_diagnostics(z0)
                tier = classify_geometry(gd)
                fd = force_decomposition(z0)

                row = {
                    "T": T,
                    "n": n,
                    "shift": shift,
                    "tier": tier,
                    **sp,
                    **gd,
                    **fd,
                }
                rows.append(row)

    print(f"Total windows scanned: {len(rows)}")

    summarize_by_tier(rows)
    threshold_report(rows)
    print_weak_windows(rows)
    correlation_report(rows)

    print()
    print("=" * 120)
    print("INTERPRETATION GUIDE")
    print("-" * 120)
    print("If weak windows have much larger pair_frac/local4_frac:")
    print("  -> weak geometry is driven by local singular interaction dominance.")
    print("If weak windows mainly have larger tail_over_pair or C_tail:")
    print("  -> weak geometry comes from tail compression overwhelming the pair mode.")
    print("If force fractions overlap strongly between weak and nonweak:")
    print("  -> small gap is a classifier, but force decomposition needs a better basis.")
# Out:
# local_force_decomposition.py
# ========================================================================================================================
# Reduced flow: dt_i/ds = +2 sum_{j!=i} 1/(t_i-t_j)
#
# Total windows scanned: 252
#
# ========================================================================================================================
# SUMMARY BY GEOMETRY TIER
# ------------------------------------------------------------------------------------------------------------------------
#         tier     N  gminD_med  pairFrac_med  local4_med    bg_med  tail/pair_med   Ctail_med
# --------------------------------------------------------------------------------------------
#       strong   230     0.4031        0.4169      0.6624    0.8561         0.1468      1.2751
#   borderline     5     0.3155        0.5503      0.6928    0.8008         0.1229      6.9304
#         weak    17     0.1190        0.7958      0.8294    0.6300         0.0114      4.1383
#
# ========================================================================================================================
# PAIR / LOCAL DOMINANCE THRESHOLD CHECK
# ------------------------------------------------------------------------------------------------------------------------
#
# pair_frac:
#   weak    median=0.7958, min=0.6617, max=0.8548
#   nonweak median=0.4196, min=0.3087, max=0.6157
#
# local4_frac:
#   weak    median=0.8294, min=0.6791, max=0.8809
#   nonweak median=0.6626, min=0.4243, max=0.9031
#
# tail_over_pair:
#   weak    median=0.0114, min=0.0066, max=0.0157
#   nonweak median=0.1459, min=0.0464, max=0.4999
#
# C_tail:
#   weak    median=4.1383, min=1.7631, max=5.7903
#   nonweak median=1.2806, min=0.2598, max=7.2091
#
# ========================================================================================================================
# WEAK WINDOWS — LOCAL FORCE DETAILS
# ------------------------------------------------------------------------------------------------------------------------
#      T    n  shift    k    gminD      cos1        R²     S1/S2   pairFrac    local4        bg    pairGap    tailGap  tail/pair      Ctail
# -----------------------------------------------------------------------------------------------------------------------------------------
#   5000   24     -1    1   0.1094  0.990908  0.960310     6.848     0.8006    0.8294    0.6300    38.3798    -0.5300     0.0138     5.0849
#   5000   20     -4    2   0.1099  0.991594  0.972547     6.896     0.8315    0.8809    0.5346    38.3798    -0.5696     0.0148     5.4654
#   5000   20     -3    1   0.1107  0.991600  0.966839     6.937     0.8278    0.8570    0.5822    38.3798    -0.5275     0.0137     5.0616
#   5000   24     -3    3   0.1118  0.990793  0.963165     6.793     0.8009    0.8548    0.5750    38.3798    -0.5920     0.0154     5.6799
#   5000   24     -4    4   0.1129  0.990772  0.967068     6.789     0.8000    0.8573    0.5671    38.3798    -0.6035     0.0157     5.7903
#   5000   24     -2    2   0.1139  0.990781  0.974058     6.827     0.7958    0.8432    0.5972    38.3798    -0.5723     0.0149     5.4913
#   5000   20     -2    0   0.1155  0.991595  0.942991     6.993     0.8222    0.8434    0.5952    38.3798    -0.4345     0.0113     4.1694
#   5000   24      0    0   0.1164  0.993615  0.951992     7.586     0.6617    0.6791    0.7683    38.3798    -0.4368     0.0114     4.1906
#   5000   16     -4    0   0.1190  0.992554  0.943728     7.176     0.8548    0.8763    0.5353    38.3798    -0.4313     0.0112     4.1383
#   5000   24      2   20   0.1257  0.993073  0.968417     7.759     0.7592    0.8059    0.6842    32.7800    -0.3601     0.0110     2.9508
#   5000   24      1   21   0.1279  0.993096  0.967770     7.799     0.7559    0.7882    0.7175    32.7800    -0.3262     0.0100     2.6731
#   5000   24      4   18   0.1284  0.993017  0.966552     7.754     0.7541    0.8124    0.6600    32.7800    -0.3924     0.0120     3.2157
#   5000   24      3   19   0.1284  0.993037  0.970484     7.764     0.7545    0.8086    0.6711    32.7800    -0.3810     0.0116     3.1222
#   5000   20      3   17   0.1305  0.993380  0.961559     7.839     0.7767    0.8089    0.6817    32.7800    -0.3234     0.0099     2.6506
#   5000   20      4   16   0.1313  0.993375  0.971037     7.828     0.7773    0.8247    0.6508    32.7800    -0.3570     0.0109     2.9255
#   5000   20      2   18   0.1330  0.993480  0.960597     7.918     0.7764    0.7985    0.6883    32.7800    -0.2191     0.0067     1.7955
#   5000   16      4   14   0.1352  0.993753  0.957007     7.793     0.8283    0.8508    0.6131    32.7800    -0.2151     0.0066     1.7631
#
# ========================================================================================================================
# CORRELATIONS WITH GEOMETRY QUALITY
# ------------------------------------------------------------------------------------------------------------------------
# corr(          gminD, geometry_quality) = +0.8148
# corr(      pair_frac, geometry_quality) = -0.8305
# corr(    local4_frac, geometry_quality) = -0.4266
# corr(background_frac, geometry_quality) = +0.6085
# corr( tail_over_pair, geometry_quality) = +0.5361
# corr(         C_tail, geometry_quality) = -0.4277
#
# ========================================================================================================================
# INTERPRETATION GUIDE
# ------------------------------------------------------------------------------------------------------------------------
# If weak windows have much larger pair_frac/local4_frac:
#   -> weak geometry is driven by local singular interaction dominance.
# If weak windows mainly have larger tail_over_pair or C_tail:
#   -> weak geometry comes from tail compression overwhelming the pair mode.
# If force fractions overlap strongly between weak and nonweak:
#   -> small gap is a classifier, but force decomposition needs a better basis.

# %%
"""
local_rescaled_geometry.py
==========================

Purpose
-------
Test whether weak reduced-flow geometry recovers under local minimum-gap
rescaling.

Previous established results:
  1. Weak geometry occurs exactly when:

         g_min / Δ̄ < 0.14

  2. Weak windows are dynamically local-pair dominated:

         pairFrac ≈ 0.80

  3. Tail contribution is tiny:

         tail/pair ≈ 0.01

Question
--------
Is weak geometry merely a global-scaling artifact?

Test
----
For each window, compare geometry metrics under two coordinate choices:

  A. raw coordinates:
       t_i

  B. local minimum-gap coordinates:
       ttilde_i = (t_i - t_k) / g_min

where g_min = t_{k+1} - t_k.

Important note
--------------
The reduced ODE

    dt_i/ds = 2 Σ 1/(t_i - t_j)

has a scaling symmetry. If all coordinates are scaled by a factor a,
then the natural flow-time scale changes like a^2.

Therefore this script tests both:
  - fixed s-range
  - locally scaled s-range

to avoid mistaking time-scale mismatch for geometry failure.

Reduced flow convention
-----------------------
    dt_i/ds = +2 * sum_{j!=i} 1/(t_i - t_j),   s >= 0
"""

import math
import mpmath
import numpy as np
from scipy.linalg import svd

mpmath.mp.dps = 25

# =========================================================
# User controls
# =========================================================

T_VALUES = [50, 100, 200, 500, 1000, 5000, 10000]
N_POOL = 56
WINDOW_SIZES = [12, 16, 20, 24]
SHIFTS = [-4, -3, -2, -1, 0, 1, 2, 3, 4]

S_MAX = 0.04
N_S = 100

# geometry thresholds
COS1_STRONG = 0.998
R2_STRONG   = 0.997
S1S2_STRONG = 10.0
S2S3_STRONG = 8.0

COS1_BORDER = 0.995
R2_BORDER   = 0.985
S1S2_BORDER = 8.0
S2S3_BORDER = 6.0


# =========================================================
# Zero finding
# =========================================================

def find_zeros_pool(T, n, span=None):
    if span is None:
        span = max(40.0, n * 2.0 * math.pi / math.log(T / (2.0 * math.pi)) * 1.7)

    ts = np.linspace(T - span, T + span, max(16000, int(span * 70)))
    zv = np.array([float(mpmath.siegelz(t)) for t in ts])

    roots = []
    for i in range(len(zv) - 1):
        if zv[i] * zv[i + 1] < 0:
            r = float(mpmath.findroot(mpmath.siegelz, (ts[i], ts[i + 1]), solver="illinois"))
            roots.append(r)

    roots = sorted(roots)

    if len(roots) < n:
        raise RuntimeError(f"Only found {len(roots)} zeros near T={T}; needed {n}. Increase span.")

    mid = len(roots) // 2
    start = max(0, mid - n // 2)
    end = start + n

    if end > len(roots):
        end = len(roots)
        start = end - n

    return np.array(roots[start:end], dtype=float)


# =========================================================
# Reduced flow
# =========================================================

def reduced_velocity(z):
    n = len(z)
    v = np.zeros(n, dtype=float)

    for i in range(n):
        for j in range(n):
            if i != j:
                d = z[i] - z[j]
                if abs(d) > 1e-12:
                    v[i] += 2.0 / d

    return v

def rk4_repulsive(z, ds):
    def vel(x):
        return reduced_velocity(x)

    k1 = vel(z)
    k2 = vel(z + 0.5 * ds * k1)
    k3 = vel(z + 0.5 * ds * k2)
    k4 = vel(z + ds * k3)

    return z + (ds / 6.0) * (k1 + 2*k2 + 2*k3 + k4)

def build_velocity_matrix(z0, s_vals):
    s_full = np.concatenate([[0.0], s_vals])
    hist = np.zeros((len(s_full), len(z0)), dtype=float)
    hist[0] = z0.copy()

    z = z0.copy()
    for k in range(1, len(s_full)):
        z = rk4_repulsive(z, s_full[k] - s_full[k - 1])
        hist[k] = z

    V = np.zeros((len(z0), len(s_vals)), dtype=float)

    for k, s in enumerate(s_vals):
        col = (hist[k + 1] - z0) / s
        col -= col.mean()
        V[:, k] = col

    return V


# =========================================================
# Geometry basis
# =========================================================

def hadamard_direction(z0):
    vh = reduced_velocity(z0)
    vh -= vh.mean()
    nrm = np.linalg.norm(vh)
    if nrm < 1e-15:
        return np.zeros_like(vh)
    return vh / nrm

def density_direction(z0, e1):
    n = len(z0)
    g = np.diff(z0)
    vd = np.zeros(n, dtype=float)

    for i in range(1, n - 1):
        di = 0.5 * (z0[i + 1] - z0[i - 1])
        if di > 1e-12:
            vd[i] = -(g[i] - g[i - 1]) / (2.0 * di**2)

    if len(g) > 1:
        vd[0]  = -(g[1]  - g[0])  / (2.0 * g[0]**2)
        vd[-1] = -(g[-1] - g[-2]) / (2.0 * g[-1]**2)

    vd -= vd.mean()
    vd -= np.dot(vd, e1) * e1

    nrm = np.linalg.norm(vd)
    if nrm < 1e-15:
        return np.zeros_like(vd)

    return vd / nrm


# =========================================================
# Geometry diagnostics
# =========================================================

def classify_geometry(out):
    strong = (
        out["cos1"] >= COS1_STRONG and
        out["R2"] >= R2_STRONG and
        out["S1S2"] >= S1S2_STRONG and
        out["S2S3"] >= S2S3_STRONG
    )

    borderline = (
        out["cos1"] >= COS1_BORDER and
        out["R2"] >= R2_BORDER and
        out["S1S2"] >= S1S2_BORDER and
        out["S2S3"] >= S2S3_BORDER
    )

    if strong:
        return "strong"
    if borderline:
        return "borderline"
    return "weak"

def geometry_diagnostics(z0, s_max):
    s_vals = np.exp(np.linspace(np.log(1e-4), np.log(s_max), N_S))
    V = build_velocity_matrix(z0, s_vals)

    e1 = hadamard_direction(z0)
    e2 = density_direction(z0, e1)

    U, S, _ = svd(V, full_matrices=False)
    cos1 = abs(np.dot(U[:, 0], e1))

    r2s = []

    for k in range(V.shape[1]):
        vk = V[:, k]
        nrm = np.linalg.norm(vk)

        if nrm > 1e-15:
            proj = np.dot(vk, e1) * e1 + np.dot(vk, e2) * e2
            r2s.append(1.0 - (np.linalg.norm(vk - proj) / nrm)**2)

    out = {
        "cos1": float(cos1),
        "R2": float(np.mean(r2s)),
        "S1S2": float(S[0] / S[1]),
        "S2S3": float(S[1] / S[2]),
    }

    out["tier"] = classify_geometry(out)
    return out


# =========================================================
# Spacing and scaling
# =========================================================

def spacing_stats(z):
    g = np.diff(z)
    D = g.mean()
    k = int(np.argmin(g))

    return {
        "D": float(D),
        "gmin": float(g[k]),
        "gminD": float(g[k] / D),
        "min_gap_index": k,
    }

def local_rescale(z):
    """
    Rescale around the minimum gap.

    ttilde_i = (t_i - t_k) / g_min
    """
    g = np.diff(z)
    k = int(np.argmin(g))
    gmin = g[k]

    return (z - z[k]) / gmin, k, gmin


# =========================================================
# Force pair fraction
# =========================================================

def pair_fraction(z):
    g = np.diff(z)
    k = int(np.argmin(g))
    n = len(z)

    full_v = reduced_velocity(z)
    full_v -= full_v.mean()
    full_norm = np.linalg.norm(full_v) + 1e-30

    pair_v = np.zeros(n, dtype=float)
    pair_v[k]     = 2.0 / (z[k]     - z[k + 1])
    pair_v[k + 1] = 2.0 / (z[k + 1] - z[k])

    pair_v -= pair_v.mean()

    return float(np.linalg.norm(pair_v) / full_norm)


# =========================================================
# Window extraction
# =========================================================

def extract_window(pool, n, shift):
    center = len(pool) // 2 + shift
    start = center - n // 2
    end = start + n

    if start < 0 or end > len(pool):
        return None

    return pool[start:end].copy()


# =========================================================
# Reporting helpers
# =========================================================

def print_header():
    hdr = (
        f"{'T':>6} {'n':>4} {'shift':>6} "
        f"{'gminD':>8} {'pairF':>8} "
        f"{'raw':>10} {'loc_fixed':>10} {'loc_scaled':>11} "
        f"{'raw_cos':>9} {'raw_R²':>9} {'raw_S12':>9} "
        f"{'scaled_cos':>10} {'scaled_R²':>10} {'scaled_S12':>10}"
    )
    print(hdr)
    print("-" * len(hdr))

def print_row(r):
    print(
        f"{r['T']:6d} {r['n']:4d} {r['shift']:6d} "
        f"{r['gminD']:8.4f} {r['pair_frac']:8.4f} "
        f"{r['raw_tier']:>10s} {r['local_fixed_tier']:>10s} {r['local_scaled_tier']:>11s} "
        f"{r['raw_cos1']:9.6f} {r['raw_R2']:9.6f} {r['raw_S1S2']:9.3f} "
        f"{r['scaled_cos1']:10.6f} {r['scaled_R2']:10.6f} {r['scaled_S1S2']:10.3f}"
    )

def summarize(rows):
    print()
    print("=" * 120)
    print("SUMMARY")
    print("-" * 120)

    labels = ["strong", "borderline", "weak"]

    for key in ["raw_tier", "local_fixed_tier", "local_scaled_tier"]:
        print()
        print(key)
        counts = {lab: 0 for lab in labels}
        for r in rows:
            counts[r[key]] += 1
        for lab in labels:
            print(f"  {lab:>10s}: {counts[lab]}")

    print()
    print("Transition summary: raw -> local_scaled")
    trans = {}
    for r in rows:
        t = (r["raw_tier"], r["local_scaled_tier"])
        trans[t] = trans.get(t, 0) + 1

    for (a, b), c in sorted(trans.items()):
        print(f"  {a:>10s} -> {b:<10s}: {c}")

    print()
    weak_rows = [r for r in rows if r["raw_tier"] == "weak"]
    if weak_rows:
        rec = sum(1 for r in weak_rows if r["local_scaled_tier"] != "weak")
        print(f"Weak windows rescued by local_scaled geometry: {rec}/{len(weak_rows)}")

        med_raw_s12 = np.median([r["raw_S1S2"] for r in weak_rows])
        med_scaled_s12 = np.median([r["scaled_S1S2"] for r in weak_rows])
        med_raw_r2 = np.median([r["raw_R2"] for r in weak_rows])
        med_scaled_r2 = np.median([r["scaled_R2"] for r in weak_rows])

        print(f"Weak median S1/S2 raw -> scaled: {med_raw_s12:.4f} -> {med_scaled_s12:.4f}")
        print(f"Weak median R² raw -> scaled:    {med_raw_r2:.4f} -> {med_scaled_r2:.4f}")


# =========================================================
# Main
# =========================================================

if __name__ == "__main__":
    print("local_rescaled_geometry.py")
    print("=" * 120)
    print("Reduced flow: dt_i/ds = +2 sum_{j!=i} 1/(t_i-t_j)")
    print()

    rows = []

    for T in T_VALUES:
        pool = find_zeros_pool(T, N_POOL)

        for n in WINDOW_SIZES:
            for shift in SHIFTS:
                z0 = extract_window(pool, n, shift)
                if z0 is None:
                    continue

                sp = spacing_stats(z0)
                pf = pair_fraction(z0)

                raw = geometry_diagnostics(z0, S_MAX)

                zloc, k, gmin = local_rescale(z0)

                # Test 1: same absolute s range after local rescaling
                local_fixed = geometry_diagnostics(zloc, S_MAX)

                # Test 2: scale s range by coordinate scaling symmetry.
                # zloc = z / gmin, so lengths are scaled by 1/gmin.
                # Natural time scale scales as length^2, so s should scale by 1/gmin^2.
                local_scaled_smax = S_MAX / (gmin**2)
                local_scaled = geometry_diagnostics(zloc, local_scaled_smax)

                row = {
                    "T": T,
                    "n": n,
                    "shift": shift,
                    "gminD": sp["gminD"],
                    "pair_frac": pf,

                    "raw_tier": raw["tier"],
                    "raw_cos1": raw["cos1"],
                    "raw_R2": raw["R2"],
                    "raw_S1S2": raw["S1S2"],
                    "raw_S2S3": raw["S2S3"],

                    "local_fixed_tier": local_fixed["tier"],
                    "fixed_cos1": local_fixed["cos1"],
                    "fixed_R2": local_fixed["R2"],
                    "fixed_S1S2": local_fixed["S1S2"],
                    "fixed_S2S3": local_fixed["S2S3"],

                    "local_scaled_tier": local_scaled["tier"],
                    "scaled_cos1": local_scaled["cos1"],
                    "scaled_R2": local_scaled["R2"],
                    "scaled_S1S2": local_scaled["S1S2"],
                    "scaled_S2S3": local_scaled["S2S3"],
                }

                rows.append(row)

    # sort raw weak first, then by gmin
    tier_rank = {"weak": 0, "borderline": 1, "strong": 2}
    rows = sorted(rows, key=lambda r: (tier_rank[r["raw_tier"]], r["gminD"]))

    print_header()
    for r in rows:
        # keep full printout; user can inspect all transitions
        print_row(r)

    summarize(rows)

    print()
    print("=" * 120)
    print("INTERPRETATION GUIDE")
    print("-" * 120)
    print("If weak raw windows become strong/borderline under local_scaled:")
    print("  -> weak geometry was mainly a scaling mismatch.")
    print("If weak raw windows remain weak under local_scaled:")
    print("  -> weak geometry is a true local-pair dominated regime.")
    print("If local_fixed and local_scaled differ strongly:")
    print("  -> time-scale rescaling matters under coordinate scaling.")
# Out:
# local_rescaled_geometry.py
# ========================================================================================================================
# Reduced flow: dt_i/ds = +2 sum_{j!=i} 1/(t_i-t_j)
#
#      T    n  shift    gminD    pairF        raw  loc_fixed  loc_scaled   raw_cos    raw_R²   raw_S12 scaled_cos  scaled_R² scaled_S12
# -------------------------------------------------------------------------------------------------------------------------------------
#   5000   24     -1   0.1094   0.8006       weak     strong        weak  0.990908  0.960310     6.848   0.997828   0.977008      8.181
#   5000   20     -4   0.1099   0.8315       weak     strong        weak  0.991594  0.972547     6.896   0.998051   0.984097      8.363
#   5000   20     -3   0.1107   0.8278       weak     strong        weak  0.991600  0.966839     6.937   0.998046   0.980790      8.395
#   5000   24     -3   0.1118   0.8009       weak     strong        weak  0.990793  0.963165     6.793   0.997801   0.978665      8.118
#   5000   24     -4   0.1129   0.8000       weak     strong        weak  0.990772  0.967068     6.789   0.997795   0.980932      8.111
#   5000   24     -2   0.1139   0.7958       weak     strong        weak  0.990781  0.974058     6.827   0.997789   0.984984      8.139
#   5000   20     -2   0.1155   0.8222       weak     strong        weak  0.991595  0.942991     6.993   0.998034   0.966916      8.434
#   5000   24      0   0.1164   0.6617       weak     strong        weak  0.993615  0.951992     7.586   0.998535   0.972105      9.334
#   5000   16     -4   0.1190   0.8548       weak     strong        weak  0.992554  0.943728     7.176   0.998312   0.967329      8.797
#   5000   24      2   0.1257   0.7592       weak     strong        weak  0.993073  0.968417     7.759   0.998088   0.981140      9.061
#   5000   24      1   0.1279   0.7559       weak     strong        weak  0.993096  0.967770     7.799   0.998090   0.980751      9.096
#   5000   24      4   0.1284   0.7541       weak     strong        weak  0.993017  0.966552     7.754   0.998066   0.980023      9.041
#   5000   24      3   0.1284   0.7545       weak     strong        weak  0.993037  0.970484     7.764   0.998072   0.982376      9.054
#   5000   20      3   0.1305   0.7767       weak     strong        weak  0.993380  0.961559     7.839   0.998197   0.977026      9.210
#   5000   20      4   0.1313   0.7773       weak     strong        weak  0.993375  0.971037     7.828   0.998197   0.982667      9.201
#   5000   20      2   0.1330   0.7764       weak     strong        weak  0.993480  0.960597     7.918   0.998224   0.976424      9.297
#   5000   16      4   0.1352   0.8283       weak     strong        weak  0.993753  0.957007     7.793   0.998350   0.974271      9.290
#  10000   16      3   0.3021   0.5503 borderline     strong      strong  0.998886  0.996825    17.526   0.999474   0.997763     19.149
#  10000   20      3   0.3116   0.4830 borderline     strong      strong  0.999057  0.996529    19.032   0.999553   0.997552     20.781
#  10000   24      1   0.3155   0.4407 borderline     strong      strong  0.999140  0.996647    19.968   0.999590   0.997636     21.779
#  10000   12     -4   0.3381   0.5816 borderline     strong  borderline  0.998947  0.994189    17.883   0.999507   0.995904     19.599
#   5000   12      0   0.3638   0.5573 borderline     strong      strong  0.999443  0.996719    23.574   0.999701   0.997549     25.452
#  10000   16      4   0.2887   0.5601     strong     strong      strong  0.998850  0.998185    17.245   0.999457   0.998723     18.842
#  10000   20      2   0.3025   0.4969     strong     strong      strong  0.999009  0.998360    18.743   0.999529   0.998846     20.425
#  10000   24      0   0.3038   0.4534     strong     strong      strong  0.999104  0.998567    19.717   0.999572   0.998993     21.470
#  10000   24     -1   0.3068   0.4525     strong     strong      strong  0.999107  0.998541    19.747   0.999574   0.998974     21.502
#  10000   12     -3   0.3070   0.6112     strong     strong      strong  0.998817  0.998042    16.879   0.999446   0.998622     18.494
#  10000   12      2   0.3085   0.6089     strong     strong      strong  0.998786  0.998454    16.636   0.999432   0.998912     18.229
#  10000   12      0   0.3087   0.6157     strong     strong      strong  0.998797  0.998132    16.640   0.999438   0.998685     18.253
#  10000   20     -4   0.3092   0.4912     strong     strong      strong  0.999019  0.998388    18.742   0.999534   0.998865     20.445
#  10000   20      1   0.3092   0.4934     strong     strong      strong  0.999017  0.998363    18.833   0.999532   0.998848     20.518
#  10000   20      4   0.3093   0.4870     strong     strong      strong  0.999046  0.998345    18.957   0.999547   0.998836     20.691
#  10000   12      1   0.3106   0.6106     strong     strong      strong  0.998806  0.997227    16.717   0.999442   0.998046     18.333
#  10000   24     -2   0.3106   0.4508     strong     strong      strong  0.999115  0.998193    19.833   0.999577   0.998728     21.597
#  10000   12     -1   0.3108   0.6080     strong     strong      strong  0.998821  0.998033    16.856   0.999449   0.998615     18.481
#  10000   16      2   0.3110   0.5419     strong     strong      strong  0.998919  0.997703    17.806   0.999489   0.998382     19.450
#  10000   24     -3   0.3114   0.4488     strong     strong      strong  0.999123  0.998442    19.932   0.999581   0.998903     21.704
#  10000   20     -3   0.3128   0.4849     strong     strong      strong  0.999039  0.998677    18.950   0.999544   0.999070     20.668
#  10000   16      1   0.3133   0.5348     strong     strong      strong  0.998942  0.998069    18.023   0.999500   0.998640     19.681
#  10000   16     -4   0.3133   0.5314     strong     strong      strong  0.998949  0.998041    18.016   0.999504   0.998621     19.688
#  10000   12     -2   0.3146   0.6043     strong     strong      strong  0.998829  0.997834    16.947   0.999452   0.998475     18.571
#  10000   12      3   0.3158   0.6065     strong     strong      strong  0.998789  0.997596    16.668   0.999433   0.998307     18.260
#  10000   24      4   0.3163   0.4402     strong     strong      strong  0.999154  0.998588    20.256   0.999596   0.999007     22.065
#  10000   24      3   0.3164   0.4410     strong     strong      strong  0.999153  0.998489    20.229   0.999596   0.998936     22.040
#  10000   16     -3   0.3170   0.5302     strong     strong      strong  0.998949  0.998300    18.011   0.999504   0.998804     19.683
#  10000   24      2   0.3174   0.4389     strong     strong      strong  0.999152  0.997589    20.115   0.999596   0.998301     21.939
#  10000   16     -1   0.3177   0.5360     strong     strong      strong  0.998936  0.998597    17.979   0.999497   0.999014     19.632
#  10000   20     -1   0.3177   0.4793     strong     strong      strong  0.999055  0.998493    19.136   0.999551   0.998940     20.862
#  10000   12      4   0.3190   0.6028     strong     strong      strong  0.998818  0.997147    16.883   0.999447   0.997990     18.496
#  10000   20     -2   0.3198   0.4787     strong     strong      strong  0.999056  0.998644    19.154   0.999551   0.999047     20.881
#  10000   20      0   0.3207   0.4781     strong     strong      strong  0.999063  0.997641    19.175   0.999555   0.998337     20.917
#  10000   24     -4   0.3212   0.4432     strong     strong      strong  0.999145  0.998842    20.219   0.999592   0.999186     22.010
#  10000   16     -2   0.3215   0.5270     strong     strong      strong  0.998966  0.997834    18.112   0.999512   0.998473     19.805
#  10000   16      0   0.3225   0.5305     strong     strong      strong  0.998952  0.998477    18.142   0.999504   0.998929     19.802
#   5000   16     -3   0.3405   0.5117     strong     strong      strong  0.999443  0.999233    23.698   0.999699   0.999427     25.538
#   5000   16     -2   0.3417   0.5109     strong     strong      strong  0.999447  0.998371    23.749   0.999701   0.998783     25.599
#   5000   12     -1   0.3459   0.5674     strong     strong      strong  0.999398  0.999320    22.659   0.999677   0.999493     24.461
#   5000   12     -4   0.3520   0.5888     strong     strong      strong  0.999351  0.999657    21.801   0.999651   0.999744     23.536
#   5000   20      1   0.3521   0.4377     strong     strong      strong  0.999550  0.999487    26.400   0.999756   0.999618     28.428
#   5000   16     -1   0.3556   0.4912     strong     strong      strong  0.999488  0.999388    24.620   0.999723   0.999544     26.547
#   5000   20     -1   0.3570   0.4426     strong     strong      strong  0.999548  0.999341    26.415   0.999755   0.999509     28.434
#     50   24     -3   0.3580   0.4014     strong     strong      strong  0.999979  0.999965   111.515   0.999981   0.999967    112.933
#     50   20     -4   0.3586   0.4324     strong     strong      strong  0.999977  0.999954   107.346   0.999980   0.999957    108.715
#   5000   12     -3   0.3587   0.5827     strong     strong      strong  0.999358  0.999730    21.946   0.999655   0.999799     23.686
#   5000   20      0   0.3603   0.4363     strong     strong      strong  0.999553  0.999012    26.492   0.999758   0.999262     28.528
#     50   24     -4   0.3621   0.3988     strong     strong      strong  0.999979  0.999964   112.430   0.999981   0.999965    113.859
#     50   16     -2   0.3624   0.4764     strong     strong      strong  0.999975  0.999956   101.303   0.999977   0.999958    102.599
#     50   20     -1   0.3631   0.4350     strong     strong      strong  0.999977  0.999957   105.903   0.999979   0.999959    107.252
#     50   20     -3   0.3636   0.4274     strong     strong      strong  0.999978  0.999956   107.862   0.999980   0.999959    109.238
#     50   24     -2   0.3640   0.3952     strong     strong      strong  0.999980  0.999956   112.794   0.999982   0.999958    114.230
#     50   12      0   0.3644   0.5452     strong     strong      strong  0.999971  0.999965    94.146   0.999974   0.999967     95.356
#     50   12      3   0.3646   0.5697     strong     strong      strong  0.999968  0.999973    90.344   0.999971   0.999974     91.500
#     50   16     -3   0.3650   0.4777     strong     strong      strong  0.999975  0.999858   101.940   0.999977   0.999865    103.243
#   5000   16      1   0.3661   0.4777     strong     strong      strong  0.999519  0.999478    25.577   0.999740   0.999611     27.553
#   5000   16      0   0.3662   0.4789     strong     strong      strong  0.999516  0.999582    25.423   0.999738   0.999689     27.396
#     50   20      0   0.3682   0.4282     strong     strong      strong  0.999977  0.999947   107.160   0.999980   0.999950    108.526
#     50   24      1   0.3707   0.3882     strong     strong      strong  0.999980  0.999962   114.039   0.999982   0.999964    115.489
#     50   16      2   0.3713   0.4765     strong     strong      strong  0.999974  0.999945   100.485   0.999977   0.999948    101.769
#     50   16      0   0.3722   0.4727     strong     strong      strong  0.999975  0.999962   101.026   0.999977   0.999964    102.318
#     50   24     -1   0.3724   0.3835     strong     strong      strong  0.999980  0.999958   115.292   0.999982   0.999960    116.761
#     50   20     -2   0.3727   0.4246     strong     strong      strong  0.999978  0.999949   108.213   0.999980   0.999952    109.593
#     50   16      1   0.3735   0.4728     strong     strong      strong  0.999975  0.999907   100.961   0.999977   0.999912    102.253
#    100   24      4   0.3746   0.3727     strong     strong      strong  0.999956  0.999735    77.135   0.999964   0.999760     79.040
#     50   24      0   0.3752   0.3826     strong     strong      strong  0.999980  0.999954   115.337   0.999982   0.999957    116.806
#     50   20      2   0.3753   0.4169     strong     strong      strong  0.999978  0.999966   109.134   0.999980   0.999968    110.526
#     50   24      2   0.3756   0.3821     strong     strong      strong  0.999980  0.999961   115.334   0.999982   0.999963    116.802
#   5000   12     -2   0.3761   0.5606     strong     strong      strong  0.999401  0.999406    22.708   0.999678   0.999556     24.511
#   1000   20     -4   0.3779   0.4121     strong     strong      strong  0.999848  0.999847    43.215   0.999901   0.999876     45.545
#     50   20      4   0.3798   0.4155     strong     strong      strong  0.999978  0.999961   109.839   0.999981   0.999963    111.238
#     50   12     -1   0.3802   0.5286     strong     strong      strong  0.999973  0.999840    98.222   0.999976   0.999848     99.487
#     50   16     -1   0.3805   0.4672     strong     strong      strong  0.999975  0.999958   102.438   0.999978   0.999960    103.748
#     50   20      3   0.3809   0.4147     strong     strong      strong  0.999978  0.999926   109.620   0.999981   0.999929    111.019
#   1000   24      1   0.3814   0.3731     strong     strong      strong  0.999864  0.999852    45.588   0.999911   0.999879     48.044
#   1000   16     -2   0.3833   0.4711     strong     strong      strong  0.999835  0.999819    41.667   0.999892   0.999853     43.888
#   5000   16      2   0.3838   0.4646     strong     strong      strong  0.999549  0.997461    26.372   0.999756   0.998103     28.419
#     50   24      3   0.3842   0.3792     strong     strong      strong  0.999981  0.999964   116.053   0.999983   0.999966    117.529
#     50   12      2   0.3851   0.5368     strong     strong      strong  0.999971  0.999891    94.450   0.999974   0.999897     95.665
#     50   12      4   0.3855   0.5494     strong     strong      strong  0.999970  0.999951    93.349   0.999973   0.999953     94.543
#     50   16      4   0.3857   0.4593     strong     strong      strong  0.999976  0.999901   103.361   0.999978   0.999906    104.684
#    200   12      1   0.3868   0.4828     strong     strong      strong  0.999935  0.999966    63.304   0.999947   0.999969     64.958
#   1000   24     -2   0.3876   0.3675     strong     strong      strong  0.999868  0.999862    46.269   0.999914   0.999887     48.765
#   1000   20     -1   0.3877   0.4094     strong     strong      strong  0.999862  0.999734    45.473   0.999910   0.999783     47.904
#   1000   16     -3   0.3879   0.4707     strong     strong      strong  0.999835  0.999678    41.665   0.999892   0.999737     43.886
#     50   20      1   0.3884   0.4116     strong     strong      strong  0.999979  0.999962   110.613   0.999981   0.999964    112.024
#     50   24      4   0.3886   0.3720     strong     strong      strong  0.999981  0.999940   116.002   0.999983   0.999943    117.482
#   1000   20     -2   0.3899   0.4051     strong     strong      strong  0.999850  0.999210    43.337   0.999902   0.999356     45.691
#   1000   20     -3   0.3910   0.4031     strong     strong      strong  0.999853  0.999409    43.798   0.999904   0.999518     46.177
#   1000   24      0   0.3913   0.3613     strong     strong      strong  0.999859  0.999268    44.413   0.999908   0.999403     46.841
#   1000   24      4   0.3916   0.3722     strong     strong      strong  0.999867  0.999856    46.088   0.999913   0.999882     48.567
#     50   12      1   0.3917   0.5312     strong     strong      strong  0.999972  0.999957    95.482   0.999974   0.999959     96.708
#   1000   24     -4   0.3919   0.3717     strong     strong      strong  0.999867  0.999858    46.170   0.999913   0.999885     48.655
#   1000   16     -1   0.3924   0.4613     strong     strong      strong  0.999840  0.999368    42.185   0.999895   0.999485     44.455
#   1000   16     -4   0.3930   0.4579     strong     strong      strong  0.999826  0.999066    40.214   0.999886   0.999239     42.405
#   1000   24      3   0.3938   0.3706     strong     strong      strong  0.999867  0.999868    46.018   0.999913   0.999892     48.495
#   1000   20      0   0.3942   0.4077     strong     strong      strong  0.999863  0.999840    45.607   0.999910   0.999870     48.042
#    200   24      1   0.3944   0.3565     strong     strong      strong  0.999951  0.999951    73.721   0.999960   0.999956     75.599
#   1000   24      2   0.3953   0.3696     strong     strong      strong  0.999867  0.999871    46.006   0.999913   0.999895     48.484
#   1000   16      0   0.3954   0.4580     strong     strong      strong  0.999846  0.999799    43.071   0.999899   0.999837     45.382
#   1000   20      3   0.3957   0.3994     strong     strong      strong  0.999857  0.999173    44.499   0.999907   0.999326     46.909
#   1000   20      2   0.3960   0.3975     strong     strong      strong  0.999857  0.999831    44.462   0.999907   0.999862     46.872
#    200   24     -3   0.3963   0.3536     strong     strong      strong  0.999952  0.999948    74.361   0.999961   0.999953     76.258
#   1000   24     -3   0.3967   0.3651     strong     strong      strong  0.999870  0.999788    46.551   0.999915   0.999828     49.064
#    200   16     -4   0.3968   0.4533     strong     strong      strong  0.999955  0.999887    76.795   0.999964   0.999898     78.753
#    200   20     -1   0.3981   0.3874     strong     strong      strong  0.999947  0.999952    70.232   0.999957   0.999957     72.031
#    200   16     -1   0.3984   0.4247     strong     strong      strong  0.999942  0.999959    66.966   0.999952   0.999963     68.693
#    200   12     -3   0.3984   0.5145     strong     strong      strong  0.999949  0.999947    71.719   0.999958   0.999952     73.559
#   1000   12     -4   0.3985   0.5481     strong     strong      strong  0.999800  0.999804    37.783   0.999869   0.999840     39.820
#     50   16      3   0.3991   0.4539     strong     strong      strong  0.999976  0.999959   104.735   0.999979   0.999961    106.073
#    200   20     -3   0.3996   0.3859     strong     strong      strong  0.999947  0.999953    70.633   0.999957   0.999958     72.442
#    100   12      3   0.3999   0.5167     strong     strong      strong  0.999970  0.999950    92.806   0.999973   0.999953     94.226
#   1000   24     -1   0.4010   0.3561     strong     strong      strong  0.999866  0.999406    45.536   0.999912   0.999516     48.023
#    100   20     -1   0.4018   0.3830     strong     strong      strong  0.999971  0.999964    94.176   0.999974   0.999966     95.622
#   1000   12     -2   0.4018   0.5381     strong     strong      strong  0.999811  0.999805    38.913   0.999877   0.999841     41.009
#    200   20      3   0.4025   0.3805     strong     strong      strong  0.999948  0.999923    71.263   0.999958   0.999930     73.090
#    200   12     -2   0.4026   0.5136     strong     strong      strong  0.999949  0.999952    72.005   0.999959   0.999956     73.852
#    200   24     -4   0.4026   0.3492     strong     strong      strong  0.999953  0.999850    75.000   0.999962   0.999864     76.918
#    200   16      3   0.4028   0.4235     strong     strong      strong  0.999942  0.999956    67.056   0.999953   0.999960     68.785
#    200   12     -4   0.4035   0.5107     strong     strong      strong  0.999950  0.999931    72.292   0.999959   0.999938     74.145
#    200   16     -3   0.4038   0.4262     strong     strong      strong  0.999942  0.999684    67.231   0.999953   0.999714     68.966
#   1000   20      1   0.4043   0.3945     strong     strong      strong  0.999859  0.999380    44.614   0.999908   0.999495     47.034
#    100   16      1   0.4047   0.4237     strong     strong      strong  0.999967  0.999960    88.672   0.999971   0.999963     90.040
#    200   20     -2   0.4050   0.3824     strong     strong      strong  0.999948  0.999876    71.087   0.999958   0.999888     72.912
#    200   16      2   0.4051   0.4236     strong     strong      strong  0.999942  0.999925    67.167   0.999953   0.999932     68.901
#    200   20      4   0.4053   0.3761     strong     strong      strong  0.999948  0.999792    70.929   0.999958   0.999812     72.757
#    200   24     -1   0.4082   0.3531     strong     strong      strong  0.999952  0.999955    74.465   0.999961   0.999959     76.362
#   1000   16      1   0.4085   0.4446     strong     strong      strong  0.999854  0.999148    44.284   0.999905   0.999305     46.666
#    200   20      1   0.4091   0.3823     strong     strong      strong  0.999948  0.999957    70.948   0.999957   0.999961     72.764
#    200   24      2   0.4096   0.3461     strong     strong      strong  0.999952  0.999801    74.246   0.999961   0.999820     76.147
#    100   24     -3   0.4097   0.3489     strong     strong      strong  0.999974  0.999966    99.399   0.999977   0.999968    100.922
#    200   16      1   0.4097   0.4185     strong     strong      strong  0.999943  0.999925    67.995   0.999954   0.999932     69.752
#   1000   12     -3   0.4097   0.5336     strong     strong      strong  0.999812  0.999869    38.929   0.999877   0.999893     41.031
#    200   20      0   0.4103   0.3822     strong     strong      strong  0.999948  0.999949    71.019   0.999958   0.999954     72.837
#    200   12      0   0.4112   0.4758     strong     strong      strong  0.999937  0.999900    64.246   0.999949   0.999909     65.922
#    200   24      3   0.4116   0.3439     strong     strong      strong  0.999953  0.999957    74.967   0.999962   0.999961     76.884
#    200   16      0   0.4117   0.4169     strong     strong      strong  0.999944  0.999867    68.191   0.999954   0.999880     69.951
#    100   24     -4   0.4118   0.3492     strong     strong      strong  0.999974  0.999853    99.713   0.999977   0.999861    101.240
#    200   24      0   0.4128   0.3496     strong     strong      strong  0.999953  0.999902    74.925   0.999962   0.999911     76.837
#    200   12      4   0.4133   0.5039     strong     strong      strong  0.999955  0.999942    76.074   0.999963   0.999948     77.855
#    200   24     -2   0.4138   0.3488     strong     strong      strong  0.999953  0.999940    75.226   0.999962   0.999946     77.145
#    100   12      4   0.4138   0.5014     strong     strong      strong  0.999971  0.999898    94.659   0.999974   0.999904     96.111
#    100   24     -1   0.4146   0.3455     strong     strong      strong  0.999974  0.999968    99.898   0.999977   0.999970    101.431
#    100   24     -2   0.4162   0.3449     strong     strong      strong  0.999974  0.999929    99.881   0.999977   0.999933    101.415
#    100   24      1   0.4163   0.3459     strong     strong      strong  0.999974  0.999966   100.275   0.999977   0.999968    101.810
#    200   16     -2   0.4164   0.4196     strong     strong      strong  0.999943  0.999942    67.792   0.999954   0.999947     69.539
#    100   24      3   0.4165   0.3484     strong     strong      strong  0.999974  0.999962    99.275   0.999977   0.999964    100.795
#    100   20      2   0.4169   0.3794     strong     strong      strong  0.999971  0.999967    94.359   0.999974   0.999969     95.809
#   1000   12     -1   0.4171   0.5258     strong     strong      strong  0.999822  0.998950    40.057   0.999884   0.999144     42.220
#    200   12      3   0.4179   0.4719     strong     strong      strong  0.999939  0.999634    65.342   0.999950   0.999669     67.050
#    200   24      4   0.4187   0.3405     strong     strong      strong  0.999954  0.999956    75.678   0.999963   0.999960     77.612
#    100   24      0   0.4189   0.3438     strong     strong      strong  0.999974  0.999913   100.222   0.999977   0.999918    101.760
#    200   20     -4   0.4194   0.3768     strong     strong      strong  0.999950  0.999928    72.224   0.999959   0.999935     74.073
#    200   20      2   0.4200   0.3756     strong     strong      strong  0.999949  0.999935    72.065   0.999959   0.999941     73.910
#    200   12      2   0.4210   0.4679     strong     strong      strong  0.999939  0.999847    65.301   0.999950   0.999862     67.005
#    100   20      3   0.4220   0.3751     strong     strong      strong  0.999971  0.999965    95.185   0.999975   0.999967     96.646
#    200   12     -1   0.4224   0.4683     strong     strong      strong  0.999940  0.999713    65.965   0.999951   0.999740     67.690
#    100   16      3   0.4226   0.4156     strong     strong      strong  0.999968  0.999968    90.367   0.999972   0.999970     91.762
#    100   20      1   0.4231   0.3750     strong     strong      strong  0.999971  0.999962    95.441   0.999975   0.999964     96.908
#    100   20      0   0.4239   0.3742     strong     strong      strong  0.999972  0.999920    95.710   0.999975   0.999925     97.182
#    100   16     -3   0.4248   0.4252     strong     strong      strong  0.999981  0.999978   115.933   0.999982   0.999979    117.138
#    100   16      0   0.4259   0.4198     strong     strong      strong  0.999968  0.999826    89.835   0.999972   0.999837     91.220
#    100   24      2   0.4264   0.3438     strong     strong      strong  0.999974  0.999973   100.742   0.999977   0.999975    102.283
#    100   16      2   0.4265   0.4129     strong     strong      strong  0.999968  0.999928    90.572   0.999972   0.999933     91.972
#    100   20     -2   0.4265   0.3732     strong     strong      strong  0.999972  0.999851    96.280   0.999975   0.999860     97.760
#    100   12     -1   0.4276   0.4923     strong     strong      strong  0.999977  0.999974   105.793   0.999979   0.999975    106.897
#    100   20      4   0.4290   0.3733     strong     strong      strong  0.999972  0.999946    95.583   0.999975   0.999949     97.050
#    200   16      4   0.4294   0.4120     strong     strong      strong  0.999945  0.999923    68.790   0.999955   0.999930     70.562
#    100   16      4   0.4329   0.4125     strong     strong      strong  0.999969  0.999837    91.161   0.999972   0.999846     92.567
#    500   16     -4   0.4334   0.4035     strong     strong      strong  0.999924  0.999945    59.314   0.999942   0.999952     61.319
#    100   20     -3   0.4358   0.3759     strong     strong      strong  0.999983  0.999979   123.309   0.999984   0.999980    124.591
#    100   12     -2   0.4377   0.4887     strong     strong      strong  0.999977  0.999973   106.626   0.999979   0.999974    107.740
#    500   20      0   0.4378   0.3600     strong     strong      strong  0.999934  0.999957    63.906   0.999950   0.999962     66.047
#    500   24     -2   0.4387   0.3312     strong     strong      strong  0.999940  0.999953    66.724   0.999954   0.999959     68.955
#    100   20     -4   0.4404   0.3728     strong     strong      strong  0.999983  0.999969   123.556   0.999984   0.999970    124.844
#    500   16     -2   0.4408   0.4016     strong     strong      strong  0.999925  0.999952    59.729   0.999943   0.999958     61.748
#    500   24      0   0.4408   0.3215     strong     strong      strong  0.999922  0.999949    58.600   0.999940   0.999955     60.572
#    500   16     -3   0.4411   0.4015     strong     strong      strong  0.999925  0.999931    59.612   0.999943   0.999939     61.628
#    500   20     -4   0.4413   0.3629     strong     strong      strong  0.999932  0.999940    62.847   0.999948   0.999947     64.961
#    100   12      1   0.4425   0.4905     strong     strong      strong  0.999978  0.999975   107.723   0.999979   0.999976    108.844
#    100   16     -4   0.4428   0.4121     strong     strong      strong  0.999981  0.999928   116.886   0.999983   0.999931    118.107
#    500   16      3   0.4434   0.3962     strong     strong      strong  0.999928  0.999568    60.927   0.999945   0.999621     62.975
#    500   20      3   0.4442   0.3595     strong     strong      strong  0.999934  0.999945    63.746   0.999950   0.999952     65.878
#    100   16     -1   0.4454   0.4208     strong     strong      strong  0.999981  0.999969   116.523   0.999983   0.999970    117.736
#    500   24      1   0.4466   0.3200     strong     strong      strong  0.999923  0.999942    58.762   0.999941   0.999949     60.740
#    100   12     -3   0.4470   0.4782     strong     strong      strong  0.999978  0.999959   108.674   0.999980   0.999961    109.811
#    500   16      4   0.4492   0.3940     strong     strong      strong  0.999928  0.999958    60.964   0.999945   0.999963     63.013
#    500   12     -4   0.4494   0.4549     strong     strong      strong  0.999915  0.999778    55.917   0.999935   0.999805     57.831
#    100   16     -2   0.4498   0.4165     strong     strong      strong  0.999981  0.999972   118.090   0.999983   0.999974    119.319
#    500   20     -2   0.4505   0.3567     strong     strong      strong  0.999935  0.999950    64.407   0.999951   0.999956     66.569
#    500   24      2   0.4513   0.3157     strong     strong      strong  0.999924  0.999905    59.103   0.999942   0.999917     61.097
#    500   20     -3   0.4515   0.3571     strong     strong      strong  0.999934  0.999882    63.707   0.999950   0.999897     65.853
#    500   20      4   0.4519   0.3530     strong     strong      strong  0.999935  0.999864    63.927   0.999950   0.999880     66.075
#    500   20     -1   0.4520   0.3557     strong     strong      strong  0.999936  0.999936    64.522   0.999951   0.999944     66.685
#    100   12      0   0.4527   0.4809     strong     strong      strong  0.999978  0.999963   108.405   0.999980   0.999965    109.537
#    500   24     -1   0.4527   0.3167     strong     strong      strong  0.999924  0.999582    59.346   0.999942   0.999633     61.346
#    100   12      2   0.4528   0.4654     strong     strong      strong  0.999966  0.999806    87.242   0.999970   0.999818     88.596
#    500   12     -1   0.4532   0.4689     strong     strong      strong  0.999947  0.999930    70.568   0.999958   0.999938     72.714
#    500   16      2   0.4533   0.4014     strong     strong      strong  0.999955  0.999871    77.223   0.999965   0.999885     79.556
#    500   24     -3   0.4540   0.3248     strong     strong      strong  0.999941  0.999895    67.463   0.999955   0.999908     69.724
#    500   24      3   0.4546   0.3143     strong     strong      strong  0.999924  0.999950    59.450   0.999942   0.999956     61.453
#    500   16     -1   0.4548   0.3928     strong     strong      strong  0.999929  0.999920    61.139   0.999945   0.999929     63.204
#    500   20      1   0.4557   0.3410     strong     strong      strong  0.999919  0.999535    57.471   0.999938   0.999592     59.416
#    500   12      0   0.4561   0.4679     strong     strong      strong  0.999947  0.999873    70.528   0.999958   0.999887     72.676
#    500   12      1   0.4564   0.4649     strong     strong      strong  0.999948  0.999940    71.304   0.999959   0.999947     73.469
#    500   20      2   0.4564   0.3412     strong     strong      strong  0.999919  0.999606    57.544   0.999938   0.999654     59.492
#    500   12     -2   0.4571   0.4436     strong     strong      strong  0.999922  0.999572    58.198   0.999940   0.999624     60.185
#    500   12      4   0.4623   0.4578     strong     strong      strong  0.999948  0.999698    72.037   0.999960   0.999732     74.216
#    100   12     -4   0.4625   0.4687     strong     strong      strong  0.999979  0.999971   111.529   0.999981   0.999972    112.695
#    500   24     -4   0.4649   0.3192     strong     strong      strong  0.999943  0.999952    68.706   0.999957   0.999958     71.011
#    500   24      4   0.4660   0.3108     strong     strong      strong  0.999926  0.999672    60.159   0.999943   0.999712     62.186
#    500   16      1   0.4692   0.3957     strong     strong      strong  0.999957  0.999964    78.644   0.999966   0.999968     81.017
#    500   12     -3   0.4699   0.4403     strong     strong      strong  0.999921  0.999943    58.096   0.999940   0.999950     60.079
#    500   16      0   0.4743   0.3838     strong     strong      strong  0.999933  0.999647    63.034   0.999949   0.999690     65.160
#    500   12      3   0.4886   0.4450     strong     strong      strong  0.999953  0.999966    75.121   0.999963   0.999970     77.394
#    500   12      2   0.4898   0.4451     strong     strong      strong  0.999952  0.999959    74.718   0.999963   0.999963     76.983
#     50   12     -2   0.5101   0.4236     strong     strong      strong  0.999994  0.999997   202.999   0.999993   0.999996    199.981
#   1000   20      4   0.5124   0.3231     strong     strong      strong  0.999948  0.999957    71.445   0.999960   0.999962     73.812
#     50   12     -4   0.5137   0.4276     strong     strong      strong  0.999994  0.999990   198.138   0.999993   0.999989    195.189
#     50   16     -4   0.5177   0.3584     strong     strong      strong  0.999994  0.999984   210.141   0.999994   0.999983    207.013
#   1000   16      3   0.5215   0.3529     strong     strong      strong  0.999944  0.999674    68.984   0.999957   0.999713     71.275
#   1000   16      4   0.5263   0.3512     strong     strong      strong  0.999944  0.999971    69.024   0.999957   0.999974     71.319
#     50   12     -3   0.5529   0.4095     strong     strong      strong  0.999994  0.999994   207.812   0.999993   0.999994    204.719
#   1000   16      2   0.5964   0.3153     strong     strong      strong  0.999970  0.999959    92.247   0.999974   0.999963     94.163
#   5000   16      3   0.5965   0.3087     strong     strong      strong  0.999914  0.999966    55.844   0.999938   0.999971     58.183
#   1000   12      1   0.6031   0.3688     strong     strong      strong  0.999968  0.999808    89.800   0.999972   0.999822     91.431
#   5000   12      1   0.6039   0.3671     strong     strong      strong  0.999912  0.999755    55.106   0.999936   0.999790     57.423
#   1000   12      4   0.6181   0.3532     strong     strong      strong  0.999967  0.999925    88.255   0.999972   0.999931     90.101
#   5000   12      3   0.6223   0.3539     strong     strong      strong  0.999929  0.999967    61.264   0.999949   0.999972     63.853
#   5000   12      2   0.6325   0.3524     strong     strong      strong  0.999929  0.999967    61.114   0.999949   0.999972     63.704
#   1000   12      2   0.6381   0.3556     strong     strong      strong  0.999973  0.999993    97.708   0.999977   0.999993     99.495
#   1000   12      0   0.6421   0.3505     strong     strong      strong  0.999980  0.999962   113.806   0.999982   0.999963    115.078
#   1000   12      3   0.6429   0.3491     strong     strong      strong  0.999968  0.999901    90.260   0.999973   0.999909     92.146
#   5000   12      4   0.6447   0.3415     strong     strong      strong  0.999912  0.999648    54.947   0.999936   0.999699     57.281
#
# ========================================================================================================================
# SUMMARY
# ------------------------------------------------------------------------------------------------------------------------
#
# raw_tier
#       strong: 230
#   borderline: 5
#         weak: 17
#
# local_fixed_tier
#       strong: 252
#   borderline: 0
#         weak: 0
#
# local_scaled_tier
#       strong: 234
#   borderline: 1
#         weak: 17
#
# Transition summary: raw -> local_scaled
#   borderline -> borderline: 1
#   borderline -> strong    : 4
#       strong -> strong    : 230
#         weak -> weak      : 17
#
# Weak windows rescued by local_scaled geometry: 0/17
# Weak median S1/S2 raw -> scaled: 7.5860 -> 9.0410
# Weak median R² raw -> scaled:    0.9666 -> 0.9800
#
# ========================================================================================================================
# INTERPRETATION GUIDE
# ------------------------------------------------------------------------------------------------------------------------
# If weak raw windows become strong/borderline under local_scaled:
#   -> weak geometry was mainly a scaling mismatch.
# If weak raw windows remain weak under local_scaled:
#   -> weak geometry is a true local-pair dominated regime.
# If local_fixed and local_scaled differ strongly:
#   -> time-scale rescaling matters under coordinate scaling.

# %%
"""
local_minimum_barrier_check.py
==============================

Purpose
-------
Directly test the corrected finite-model small-gap barrier.

Finite reduced model:
    dt_i/ds = +2 * sum_{j!=i} 1/(t_i - t_j)

For a neighbouring gap:
    g_i = t_{i+1} - t_i

Exact finite-model identity:
    g_i' = 4/g_i - C_i g_i

where the nonlocal tail is compressive.

Corrected infinite-tail sufficient condition
--------------------------------------------
Let:
    g_min = η Δbar
    g_second = a Δbar

If all other gaps are at least a Δbar and:

    η < a

then the minimum gap is in the reopening regime:
    g_min' > 0

This script checks, for every window:
  - g_min / Δbar
  - g_second / Δbar
  - rho = g_min / g_second
  - actual g_min'
  - pair term 4/g_min
  - tail term
  - whether η < a predicts reopening
  - whether actual g_min' confirms reopening

Key question
------------
Are the weak-geometry windows actually protected by a local-minimum
barrier rather than dangerous collapse windows?
"""

import math
import mpmath
import numpy as np
from scipy.linalg import svd

mpmath.mp.dps = 25

# =========================================================
# User controls
# =========================================================

T_VALUES = [50, 100, 200, 500, 1000, 5000, 10000]
N_POOL = 56
WINDOW_SIZES = [12, 16, 20, 24]
SHIFTS = [-4, -3, -2, -1, 0, 1, 2, 3, 4]

S_MAX = 0.04
N_S = 100

# Geometry tier thresholds
COS1_STRONG = 0.998
R2_STRONG   = 0.997
S1S2_STRONG = 10.0
S2S3_STRONG = 8.0

COS1_BORDER = 0.995
R2_BORDER   = 0.985
S1S2_BORDER = 8.0
S2S3_BORDER = 6.0


# =========================================================
# Zero finding
# =========================================================

def find_zeros_pool(T, n, span=None):
    if span is None:
        span = max(40.0, n * 2.0 * math.pi / math.log(T / (2.0 * math.pi)) * 1.7)

    ts = np.linspace(T - span, T + span, max(16000, int(span * 70)))
    zv = np.array([float(mpmath.siegelz(t)) for t in ts])

    roots = []
    for i in range(len(zv) - 1):
        if zv[i] * zv[i + 1] < 0:
            r = float(mpmath.findroot(mpmath.siegelz, (ts[i], ts[i + 1]), solver="illinois"))
            roots.append(r)

    roots = sorted(roots)

    if len(roots) < n:
        raise RuntimeError(f"Only found {len(roots)} zeros near T={T}; needed {n}. Increase span.")

    mid = len(roots) // 2
    start = max(0, mid - n // 2)
    end = start + n

    if end > len(roots):
        end = len(roots)
        start = end - n

    return np.array(roots[start:end], dtype=float)


# =========================================================
# Reduced flow
# =========================================================

def reduced_velocity(z):
    n = len(z)
    v = np.zeros(n, dtype=float)

    for i in range(n):
        for j in range(n):
            if i != j:
                d = z[i] - z[j]
                if abs(d) > 1e-12:
                    v[i] += 2.0 / d

    return v

def rk4_repulsive(z, ds):
    def vel(x):
        return reduced_velocity(x)

    k1 = vel(z)
    k2 = vel(z + 0.5 * ds * k1)
    k3 = vel(z + 0.5 * ds * k2)
    k4 = vel(z + ds * k3)

    return z + (ds / 6.0) * (k1 + 2*k2 + 2*k3 + k4)

def build_velocity_matrix(z0, s_vals):
    s_full = np.concatenate([[0.0], s_vals])
    hist = np.zeros((len(s_full), len(z0)), dtype=float)
    hist[0] = z0.copy()

    z = z0.copy()
    for k in range(1, len(s_full)):
        z = rk4_repulsive(z, s_full[k] - s_full[k-1])
        hist[k] = z

    V = np.zeros((len(z0), len(s_vals)), dtype=float)
    for k, s in enumerate(s_vals):
        col = (hist[k+1] - z0) / s
        col -= col.mean()
        V[:, k] = col

    return V


# =========================================================
# Geometry
# =========================================================

def hadamard_direction(z0):
    vh = reduced_velocity(z0)
    vh -= vh.mean()
    nrm = np.linalg.norm(vh)
    if nrm < 1e-15:
        return np.zeros_like(vh)
    return vh / nrm

def density_direction(z0, e1):
    n = len(z0)
    g = np.diff(z0)
    vd = np.zeros(n, dtype=float)

    for i in range(1, n - 1):
        di = 0.5 * (z0[i+1] - z0[i-1])
        if di > 1e-12:
            vd[i] = -(g[i] - g[i-1]) / (2.0 * di**2)

    if len(g) > 1:
        vd[0]  = -(g[1]  - g[0])  / (2.0 * g[0]**2)
        vd[-1] = -(g[-1] - g[-2]) / (2.0 * g[-1]**2)

    vd -= vd.mean()
    vd -= np.dot(vd, e1) * e1

    nrm = np.linalg.norm(vd)
    if nrm < 1e-15:
        return np.zeros_like(vd)

    return vd / nrm

def geometry_diagnostics(z0):
    s_vals = np.exp(np.linspace(np.log(1e-4), np.log(S_MAX), N_S))
    V = build_velocity_matrix(z0, s_vals)

    e1 = hadamard_direction(z0)
    e2 = density_direction(z0, e1)

    U, S, _ = svd(V, full_matrices=False)
    cos1 = abs(np.dot(U[:, 0], e1))

    r2s = []
    for k in range(V.shape[1]):
        vk = V[:, k]
        nrm = np.linalg.norm(vk)
        if nrm > 1e-15:
            proj = np.dot(vk, e1) * e1 + np.dot(vk, e2) * e2
            r2s.append(1.0 - (np.linalg.norm(vk - proj) / nrm)**2)

    return {
        "cos1": float(cos1),
        "R2": float(np.mean(r2s)),
        "S1S2": float(S[0] / S[1]),
        "S2S3": float(S[1] / S[2]),
    }

def classify_geometry(out):
    strong = (
        out["cos1"] >= COS1_STRONG and
        out["R2"] >= R2_STRONG and
        out["S1S2"] >= S1S2_STRONG and
        out["S2S3"] >= S2S3_STRONG
    )

    borderline = (
        out["cos1"] >= COS1_BORDER and
        out["R2"] >= R2_BORDER and
        out["S1S2"] >= S1S2_BORDER and
        out["S2S3"] >= S2S3_BORDER
    )

    if strong:
        return "strong"
    if borderline:
        return "borderline"
    return "weak"


# =========================================================
# Gap barrier diagnostics
# =========================================================

def gap_barrier_diagnostics(z):
    g = np.diff(z)
    D = float(g.mean())

    order = np.argsort(g)
    k_min = int(order[0])
    k_second = int(order[1]) if len(order) > 1 else None

    gmin = float(g[k_min])
    gsecond = float(g[k_second]) if k_second is not None else np.inf

    eta = gmin / D
    a = gsecond / D
    rho = gmin / gsecond if np.isfinite(gsecond) else 0.0

    v = reduced_velocity(z)

    # actual minimum-gap derivative
    gprime = float(v[k_min + 1] - v[k_min])

    # pair term in exact gap equation
    pair_term = float(4.0 / gmin)

    # tail term is actual minus pair contribution
    tail_term = float(gprime - pair_term)

    # C_tail from g' = 4/g - C g
    C_tail = float((pair_term - gprime) / (gmin + 1e-30))

    # finite-model sufficient condition from corrected lemma
    predicts_reopen = bool(eta < a)

    actual_reopen = bool(gprime > 0.0)

    # margin in the lemma
    margin = float(a - eta)

    # direct barrier margin: 4/g - Cg
    # same as gprime, but useful as named output
    barrier_margin = gprime

    return {
        "D": D,
        "k_min": k_min,
        "k_second": k_second,
        "gminD": eta,
        "gsecondD": a,
        "rho": rho,
        "margin_eta_a": margin,
        "gprime": gprime,
        "pair_term": pair_term,
        "tail_term": tail_term,
        "tail_over_pair": abs(tail_term) / (abs(pair_term) + 1e-30),
        "C_tail": C_tail,
        "predicts_reopen": predicts_reopen,
        "actual_reopen": actual_reopen,
        "barrier_margin": barrier_margin,
    }


# =========================================================
# Window extraction
# =========================================================

def extract_window(pool, n, shift):
    center = len(pool) // 2 + shift
    start = center - n // 2
    end = start + n

    if start < 0 or end > len(pool):
        return None

    return pool[start:end].copy()


# =========================================================
# Reporting
# =========================================================

def summarize(rows):
    print()
    print("=" * 120)
    print("SUMMARY BY GEOMETRY TIER")
    print("-" * 120)

    hdr = (
        f"{'tier':>12} {'N':>5} "
        f"{'gminD_med':>10} {'g2D_med':>10} {'rho_med':>10} "
        f"{'gprime_med':>12} {'tail/pair_med':>14} "
        f"{'pred_ok':>8} {'actual_ok':>10}"
    )
    print(hdr)
    print("-" * len(hdr))

    for tier in ["strong", "borderline", "weak"]:
        sub = [r for r in rows if r["tier"] == tier]
        if not sub:
            continue

        def med(key):
            return float(np.median([r[key] for r in sub]))

        pred_ok = sum(1 for r in sub if r["predicts_reopen"])
        actual_ok = sum(1 for r in sub if r["actual_reopen"])

        print(
            f"{tier:>12s} {len(sub):5d} "
            f"{med('gminD'):10.4f} {med('gsecondD'):10.4f} {med('rho'):10.4f} "
            f"{med('gprime'):12.4f} {med('tail_over_pair'):14.4f} "
            f"{pred_ok:8d} {actual_ok:10d}"
        )

def print_weak(rows):
    print()
    print("=" * 120)
    print("WEAK WINDOWS — LOCAL-MINIMUM BARRIER DETAILS")
    print("-" * 120)

    hdr = (
        f"{'T':>6} {'n':>4} {'shift':>6} {'k':>4} "
        f"{'gminD':>8} {'g2D':>8} {'rho':>8} {'η<a':>5} "
        f"{'gprime':>10} {'pair':>10} {'tail':>10} {'tail/pair':>10} {'Ctail':>10}"
    )
    print(hdr)
    print("-" * len(hdr))

    for r in sorted([x for x in rows if x["tier"] == "weak"], key=lambda x: x["gminD"]):
        print(
            f"{r['T']:6d} {r['n']:4d} {r['shift']:6d} {r['k_min']:4d} "
            f"{r['gminD']:8.4f} {r['gsecondD']:8.4f} {r['rho']:8.4f} "
            f"{str(r['predicts_reopen']):>5s} "
            f"{r['gprime']:10.4f} {r['pair_term']:10.4f} {r['tail_term']:10.4f} "
            f"{r['tail_over_pair']:10.4f} {r['C_tail']:10.4f}"
        )

def prediction_confusion(rows):
    print()
    print("=" * 120)
    print("PREDICTION CHECK: η < a  VS  ACTUAL g_min' > 0")
    print("-" * 120)

    tp = fp = fn = tn = 0

    for r in rows:
        pred = r["predicts_reopen"]
        act = r["actual_reopen"]

        if pred and act:
            tp += 1
        elif pred and not act:
            fp += 1
        elif (not pred) and act:
            fn += 1
        else:
            tn += 1

    print(f"TP pred reopen / actual reopen     : {tp}")
    print(f"FP pred reopen / actual not reopen : {fp}")
    print(f"FN pred no / actual reopen         : {fn}")
    print(f"TN pred no / actual no             : {tn}")

    total = len(rows)
    acc = (tp + tn) / total if total else 0.0
    print(f"accuracy: {acc:.4f}")

def print_counterexamples(rows):
    bad = [r for r in rows if r["predicts_reopen"] and not r["actual_reopen"]]

    print()
    print("=" * 120)
    print("COUNTEREXAMPLES TO SUFFICIENT CONDITION")
    print("-" * 120)

    if not bad:
        print("None found.")
        return

    for r in bad:
        print(
            f"T={r['T']}, n={r['n']}, shift={r['shift']}, tier={r['tier']}, "
            f"gminD={r['gminD']:.4f}, g2D={r['gsecondD']:.4f}, "
            f"rho={r['rho']:.4f}, gprime={r['gprime']:.4f}"
        )


# =========================================================
# Main
# =========================================================

if __name__ == "__main__":
    print("local_minimum_barrier_check.py")
    print("=" * 120)
    print("Reduced flow: dt_i/ds = +2 sum_{j!=i} 1/(t_i-t_j)")
    print("Testing corrected finite-model condition: η < a")
    print()

    rows = []

    for T in T_VALUES:
        pool = find_zeros_pool(T, N_POOL)

        for n in WINDOW_SIZES:
            for shift in SHIFTS:
                z0 = extract_window(pool, n, shift)
                if z0 is None:
                    continue

                gd = geometry_diagnostics(z0)
                tier = classify_geometry(gd)
                bd = gap_barrier_diagnostics(z0)

                row = {
                    "T": T,
                    "n": n,
                    "shift": shift,
                    "tier": tier,
                    **gd,
                    **bd,
                }

                rows.append(row)

    print(f"Total windows scanned: {len(rows)}")

    summarize(rows)
    print_weak(rows)
    prediction_confusion(rows)
    print_counterexamples(rows)

    print()
    print("=" * 120)
    print("INTERPRETATION GUIDE")
    print("-" * 120)
    print("If every weak window satisfies η<a and gprime>0:")
    print("  -> weak small-gap windows are local barrier / reopening cases.")
    print("If η<a ever predicts reopen but actual gprime<=0:")
    print("  -> the finite-model sufficient condition was stated too strongly or implemented incorrectly.")
    print("If many windows reopen even without η<a:")
    print("  -> η<a is sufficient, not necessary.")
# Out:
# local_minimum_barrier_check.py
# ========================================================================================================================
# Reduced flow: dt_i/ds = +2 sum_{j!=i} 1/(t_i-t_j)
# Testing corrected finite-model condition: η < a
#
# Total windows scanned: 252
#
# ========================================================================================================================
# SUMMARY BY GEOMETRY TIER
# ------------------------------------------------------------------------------------------------------------------------
#         tier     N  gminD_med    g2D_med    rho_med   gprime_med  tail/pair_med  pred_ok  actual_ok
# ---------------------------------------------------------------------------------------------------
#       strong   230     0.4031     0.5412     0.7491       4.7780         0.1468      230        230
#   borderline     5     0.3155     0.6119     0.5692      13.1310         0.1229        5          5
#         weak    17     0.1190     0.3653     0.3051      37.7763         0.0114       17         17
#
# ========================================================================================================================
# WEAK WINDOWS — LOCAL-MINIMUM BARRIER DETAILS
# ------------------------------------------------------------------------------------------------------------------------
#      T    n  shift    k    gminD      g2D      rho   η<a     gprime       pair       tail  tail/pair      Ctail
# ---------------------------------------------------------------------------------------------------------------
#   5000   24     -1    1   0.1094   0.3586   0.3051  True    37.8498    38.3798    -0.5300     0.0138     5.0849
#   5000   20     -4    2   0.1099   0.3602   0.3051  True    37.8102    38.3798    -0.5696     0.0148     5.4654
#   5000   20     -3    1   0.1107   0.3629   0.3051  True    37.8523    38.3798    -0.5275     0.0137     5.0616
#   5000   24     -3    3   0.1118   0.3665   0.3051  True    37.7878    38.3798    -0.5920     0.0154     5.6799
#   5000   24     -4    4   0.1129   0.3700   0.3051  True    37.7763    38.3798    -0.6035     0.0157     5.7903
#   5000   24     -2    2   0.1139   0.3734   0.3051  True    37.8075    38.3798    -0.5723     0.0149     5.4913
#   5000   20     -2    0   0.1155   0.3786   0.3051  True    37.9452    38.3798    -0.4345     0.0113     4.1694
#   5000   24      0    0   0.1164   0.1363   0.8541  True    37.9430    38.3798    -0.4368     0.0114     4.1906
#   5000   16     -4    0   0.1190   0.3899   0.3051  True    37.9485    38.3798    -0.4313     0.0112     4.1383
#   5000   24      2   20   0.1257   0.3520   0.3572  True    32.4199    32.7800    -0.3601     0.0110     2.9508
#   5000   24      1   21   0.1279   0.3580   0.3572  True    32.4538    32.7800    -0.3262     0.0100     2.6731
#   5000   24      4   18   0.1284   0.3594   0.3572  True    32.3876    32.7800    -0.3924     0.0120     3.2157
#   5000   24      3   19   0.1284   0.3594   0.3572  True    32.3990    32.7800    -0.3810     0.0116     3.1222
#   5000   20      3   17   0.1305   0.3653   0.3572  True    32.4566    32.7800    -0.3234     0.0099     2.6506
#   5000   20      4   16   0.1313   0.3676   0.3572  True    32.4230    32.7800    -0.3570     0.0109     2.9255
#   5000   20      2   18   0.1330   0.3722   0.3572  True    32.5609    32.7800    -0.2191     0.0067     1.7955
#   5000   16      4   14   0.1352   0.6429   0.2103  True    32.5649    32.7800    -0.2151     0.0066     1.7631
#
# ========================================================================================================================
# PREDICTION CHECK: η < a  VS  ACTUAL g_min' > 0
# ------------------------------------------------------------------------------------------------------------------------
# TP pred reopen / actual reopen     : 252
# FP pred reopen / actual not reopen : 0
# FN pred no / actual reopen         : 0
# TN pred no / actual no             : 0
# accuracy: 1.0000
#
# ========================================================================================================================
# COUNTEREXAMPLES TO SUFFICIENT CONDITION
# ------------------------------------------------------------------------------------------------------------------------
# None found.
#
# ========================================================================================================================
# INTERPRETATION GUIDE
# ------------------------------------------------------------------------------------------------------------------------
# If every weak window satisfies η<a and gprime>0:
#   -> weak small-gap windows are local barrier / reopening cases.
# If η<a ever predicts reopen but actual gprime<=0:
#   -> the finite-model sufficient condition was stated too strongly or implemented incorrectly.
# If many windows reopen even without η<a:
#   -> η<a is sufficient, not necessary.
